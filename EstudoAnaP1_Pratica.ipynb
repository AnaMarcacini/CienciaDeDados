# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Aquisição dos dados

# %%
Affairs = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv')
Affairs.head()
# Out:
#    rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 0         4        0    male  37.0         10.00       no              3
# 1         5        0  female  27.0          4.00       no              4
# 2        11        0  female  32.0         15.00      yes              1
# 3        16        0    male  57.0         15.00      yes              5
# 4        23        0    male  22.0          0.75       no              2
#
#    education  occupation  rating
# 0         18           7       4
# 1         14           6       4
# 2         12           1       4
# 3         18           6       5
# 4         17           6       3

# %%
carros = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv',index_col='rownames')
carros.index.name = 'Veiculo'
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros2 = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/MASS/Cars93.csv',index_col=0)
carros2.index.name = ''
carros2.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 1        Acura  Integra    Small       12.9   15.9       18.8        25
# 2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 3         Audi       90  Compact       25.9   29.1       32.3        20
# 4         Audi      100  Midsize       30.8   37.7       44.6        19
# 5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
#                                                ...
# 1           31                None      Front  ...          5     177
# 2           25  Driver & Passenger      Front  ...          5     195
# 3           26         Driver only      Front  ...          5     180
# 4           26  Driver & Passenger      Front  ...          6     193
# 5           30         Driver only       Rear  ...          4     186
#
# ...

# %%
filme = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/movie.csv')
filme.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
inspecao= pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/restaurant_inspections2.csv')
inspecao.head()
# Out:
#                 Name        Date         Info  \
# 0  E & E Grill House  2017-08-08      Borough
# 1  E & E Grill House  2017-08-08      Cuisine
# 2  E & E Grill House  2017-08-08  Description
# 3  E & E Grill House  2017-08-08        Grade
# 4  E & E Grill House  2017-08-08        Score
#
#                                                Value
# 0                                          MANHATTAN
# 1                                           American
# 2  Non-food contact surface improperly constructe...
# 3                                                  A
# 4                                                9.0

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
seguro = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/insurance.csv')
seguro.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
filmes = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/movies.csv')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_mean = ratings.groupby('movieId').rating.mean().reset_index()
ratings_mean.head()
# Out:
#    movieId    rating
# 0        1  3.920930
# 1        2  3.431818
# 2        3  3.259615
# 3        4  2.357143
# 4        5  3.071429

# %%
# %%capture
# !pip install yfinance

# %%
import yfinance as yf

financas = yf.download(['^BVSP', 'PETR4.SA', 'ITUB4.SA', 'VALE3.SA', 'BRL=X'],'2023-01-01','2024-01-01')
financas.head()
# Out:
# [*********************100%%**********************]  5 of 5 completed
# Price      Adj Close                                                Close  \
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP     BRL=X
# Date
# 2023-01-02  5.285500  22.452349  17.709476  80.482170  106376.0  5.285500
# 2023-01-03  5.360131  21.984779  17.261332  80.338135  104166.0  5.360131
# 2023-01-04  5.478500  22.048956  17.809925  80.482170  105334.0  5.478500
# 2023-01-05  5.430100  22.736551  18.451235  81.832550  107518.0  5.430100
# 2023-01-06  5.349800  23.130779  18.343063  83.128899  108836.0  5.349800
#
# Price                                                  ...      Open  \
# Ticker       ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP  ...     BRL=X
# Date                                                   ...
# 2023-01-02  24.490000  22.920000  89.400002  106376.0  ...  5.285500
# 2023-01-03  23.980000  22.340000  89.239998  104166.0  ...  5.360131
# ...

# %%
print(financas.columns)
# Out:
# MultiIndex([('Adj Close',    'BRL=X'),
#             ('Adj Close', 'ITUB4.SA'),
#             ('Adj Close', 'PETR4.SA'),
#             ('Adj Close', 'VALE3.SA'),
#             ('Adj Close',    '^BVSP'),
#             (    'Close',    'BRL=X'),
#             (    'Close', 'ITUB4.SA'),
#             (    'Close', 'PETR4.SA'),
#             (    'Close', 'VALE3.SA'),
#             (    'Close',    '^BVSP'),
#             (     'High',    'BRL=X'),
#             (     'High', 'ITUB4.SA'),
#             (     'High', 'PETR4.SA'),
#             (     'High', 'VALE3.SA'),
#             (     'High',    '^BVSP'),
#             (      'Low',    'BRL=X'),
#             (      'Low', 'ITUB4.SA'),
#             (      'Low', 'PETR4.SA'),
#             (      'Low', 'VALE3.SA'),
#             (      'Low',    '^BVSP'),
#             (     'Open',    'BRL=X'),
#             (     'Open', 'ITUB4.SA'),
#             (     'Open', 'PETR4.SA'),
#             (     'Open', 'VALE3.SA'),
# ...

# %%
energia = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/energy_types.csv')

energia.head()
# Out:
#   country country_name                  type    level     2016     2017  \
# 0      BE      Belgium  Conventional thermal  Level 1  30728.0  31316.0
# 1      BE      Belgium               Nuclear  Level 1  41430.0  40128.5
# 2      BE      Belgium                 Hydro  Level 1   1476.0   1360.9
# 3      BE      Belgium    Pumped hydro power  Level 2   1110.0   1093.2
# 4      BE      Belgium                  Wind  Level 1   5340.0   6387.9
#
#         2018
# 0  30092.635
# 1  26995.628
# 2   1239.248
# 3    983.190
# 4   7177.346

# %% [markdown]
# ### Criando um pd.Series e um pd.DataFrame

# %%
# Séries
student_names = pd.Series(['Adriana', 'Carol', 'Daniel'])
age = pd.Series([18, 19, 19])

# DataFrame
students = pd.DataFrame({ 'Student Name': student_names, 'Age': age })
students
# Out:
#   Student Name  Age
# 0      Adriana   18
# 1        Carol   19
# 2       Daniel   19

# %%
testeGroupby = pd.DataFrame({'data': [1, 2, 3, 4, 5, 6]},
                   index=['A', 'B', 'C', 'A', 'B', 'C'])
testeGroupby.index.name = 'key'
testeGroupby
# Out:
#      data
# key
# A       1
# B       2
# C       3
# A       4
# B       5
# C       6

# %%
pedidos = pd.DataFrame( {'Pedido': pd.Series([ 1, 1, 1, 2, 2, 2, 2, 3, 3]),
                         'Itens': pd.Series([ 'Tênis Corrida', 'Tênis Caminhada', 'Camiseta', 'Tênis Caminhada', 'Camiseta', 'Boné' , 'Keds' ,'Tênis Caminhada', 'Camiseta' ]),
                         'Preco Unidade': pd.Series([ 300, 250, 90, 250, 90, 60, 250, 250, 90]),
                         'Quantidade': pd.Series([ 1, 2, 3, 2, 1, 1, 3, 2, 1]) } )
pedidos
# Out:
#    Pedido            Itens  Preco Unidade  Quantidade
# 0       1    Tênis Corrida            300           1
# 1       1  Tênis Caminhada            250           2
# 2       1         Camiseta             90           3
# 3       2  Tênis Caminhada            250           2
# 4       2         Camiseta             90           1
# 5       2             Boné             60           1
# 6       2             Keds            250           3
# 7       3  Tênis Caminhada            250           2
# 8       3         Camiseta             90           1

# %% [markdown]
# # Operações Basicas

# %%
display(Affairs.head(1)) # primeiros 1 valores
display(Affairs.tail(1)) # ultimos 1 valores
# Out:
#    rownames  affairs gender   age  yearsmarried children  religiousness  \
# 0         4        0   male  37.0          10.0       no              3
#
#    education  occupation  rating
# 0         18           7       4
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 600         14           1       5

# %%
Affairs.iloc[0]
# Out:
# rownames            4
# affairs             0
# gender           male
# age              37.0
# yearsmarried     10.0
# children           no
# religiousness       3
# education          18
# occupation          7
# rating              4
# Name: 0, dtype: object

# %%
Affairs.iloc[-2]
# Out:
# rownames         1959
# affairs             2
# gender           male
# age              22.0
# yearsmarried      7.0
# children          yes
# religiousness       3
# education          18
# occupation          6
# rating              2
# Name: 599, dtype: object

# %% [markdown]
# ##### Ver formato

# %%
Affairs.shape # nr de linhas e colunas
# Out:
# (601, 10)

# %% [markdown]
# ##### Ver numero de dados (linhas)

# %%
len(Affairs) # linhas
# Out:
# 601

# %% [markdown]
# ##### Descrição de tudo

# %%
Affairs.describe()
# Out:
#           rownames     affairs         age  yearsmarried  religiousness  \
# count   601.000000  601.000000  601.000000    601.000000     601.000000
# mean   1059.722130    1.455907   32.487521      8.177696       3.116473
# std     914.904611    3.298758    9.288762      5.571303       1.167509
# min       4.000000    0.000000   17.500000      0.125000       1.000000
# 25%     528.000000    0.000000   27.000000      4.000000       2.000000
# 50%    1009.000000    0.000000   32.000000      7.000000       3.000000
# 75%    1453.000000    0.000000   37.000000     15.000000       4.000000
# max    9029.000000   12.000000   57.000000     15.000000       5.000000
#
#         education  occupation      rating
# count  601.000000  601.000000  601.000000
# mean    16.166389    4.194676    3.931780
# std      2.402555    1.819443    1.103179
# min      9.000000    1.000000    1.000000
# 25%     14.000000    3.000000    3.000000
# 50%     16.000000    5.000000    4.000000
# ...

# %% [markdown]
# ##### Descrição mais detalhada

# %%
Affairs.describe(include='all')
# Out:
#            rownames     affairs  gender         age  yearsmarried children  \
# count    601.000000  601.000000     601  601.000000    601.000000      601
# unique          NaN         NaN       2         NaN           NaN        2
# top             NaN         NaN  female         NaN           NaN      yes
# freq            NaN         NaN     315         NaN           NaN      430
# mean    1059.722130    1.455907     NaN   32.487521      8.177696      NaN
# std      914.904611    3.298758     NaN    9.288762      5.571303      NaN
# min        4.000000    0.000000     NaN   17.500000      0.125000      NaN
# 25%      528.000000    0.000000     NaN   27.000000      4.000000      NaN
# 50%     1009.000000    0.000000     NaN   32.000000      7.000000      NaN
# 75%     1453.000000    0.000000     NaN   37.000000     15.000000      NaN
# max     9029.000000   12.000000     NaN   57.000000     15.000000      NaN
#
#         religiousness   education  occupation      rating
# ...

# %% [markdown]
# ##### Ver informações da tabela

# %%
Affairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rownames       601 non-null    int64
#  1   affairs        601 non-null    int64
#  2   gender         601 non-null    object
#  3   age            601 non-null    float64
#  4   yearsmarried   601 non-null    float64
#  5   children       601 non-null    object
#  6   religiousness  601 non-null    int64
#  7   education      601 non-null    int64
#  8   occupation     601 non-null    int64
#  9   rating         601 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 47.1+ KB

# %% [markdown]
# ##### Ver os tipos de variavel de cada coluna

# %%
Affairs.dtypes
# Out:
# rownames           int64
# affairs            int64
# gender            object
# age              float64
# yearsmarried     float64
# children          object
# religiousness      int64
# education          int64
# occupation         int64
# rating             int64
# dtype: object

# %% [markdown]
# ##### Ver rotulo colunas

# %%
Affairs.columns
# Out:
# Index(['rownames', 'affairs', 'gender', 'age', 'yearsmarried', 'children',
#        'religiousness', 'education', 'occupation', 'rating'],
#       dtype='object')

# %%
Affairs.columns.to_list()
# Out:
# ['rownames',
#  'affairs',
#  'gender',
#  'age',
#  'yearsmarried',
#  'children',
#  'religiousness',
#  'education',
#  'occupation',
#  'rating']

# %%
seguro.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# ##### outros

# %%
carros.keys()
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
for column in carros:
  print(column)
# Out:
# mpg
# cyl
# disp
# hp
# drat
# wt
# qsec
# vs
# am
# gear
# carb

# %%
carros.index
# Out:
# Index(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D', 'Merc 230',
#        'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL', 'Merc 450SLC',
#        'Cadillac Fleetwood', 'Lincoln Continental', 'Chrysler Imperial',
#        'Fiat 128', 'Honda Civic', 'Toyota Corolla', 'Toyota Corona',
#        'Dodge Challenger', 'AMC Javelin', 'Camaro Z28', 'Pontiac Firebird',
#        'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa', 'Ford Pantera L',
#        'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype='object', name='Veiculo')

# %%
for line in carros.index:
  print(line)
# Out:
# Mazda RX4
# Mazda RX4 Wag
# Datsun 710
# Hornet 4 Drive
# Hornet Sportabout
# Valiant
# Duster 360
# Merc 240D
# Merc 230
# Merc 280
# Merc 280C
# Merc 450SE
# Merc 450SL
# Merc 450SLC
# Cadillac Fleetwood
# Lincoln Continental
# Chrysler Imperial
# Fiat 128
# Honda Civic
# Toyota Corolla
# Toyota Corona
# Dodge Challenger
# AMC Javelin
# Camaro Z28
# Pontiac Firebird
# Fiat X1-9
# Porsche 914-2
# Lotus Europa
# Ford Pantera L
# Ferrari Dino
# Maserati Bora
# Volvo 142E

# %%
carros.items()
# Out:
# <generator object DataFrame.items at 0x7f32eea6e890>

# %%
for col, data in carros.items():
  print(col, data)
# Out:
# mpg Veiculo
# Mazda RX4              21.0
# Mazda RX4 Wag          21.0
# Datsun 710             22.8
# Hornet 4 Drive         21.4
# Hornet Sportabout      18.7
# Valiant                18.1
# Duster 360             14.3
# Merc 240D              24.4
# Merc 230               22.8
# Merc 280               19.2
# Merc 280C              17.8
# Merc 450SE             16.4
# Merc 450SL             17.3
# Merc 450SLC            15.2
# Cadillac Fleetwood     10.4
# Lincoln Continental    10.4
# Chrysler Imperial      14.7
# Fiat 128               32.4
# Honda Civic            30.4
# Toyota Corolla         33.9
# Toyota Corona          21.5
# Dodge Challenger       15.5
# AMC Javelin            15.2
# Camaro Z28             13.3
# Pontiac Firebird       19.2
# Fiat X1-9              27.3
# Porsche 914-2          26.0
# Lotus Europa           30.4
# Ford Pantera L         15.8
# Ferrari Dino           19.7
# Maserati Bora          15.0
# Volvo 142E             21.4
# ...

# %% [markdown]
# # Seleção de Dados

# %% [markdown]
# Affairs.education *OU* Affairs['education'] - > retorna serie
# <br>Affairs[['education']] -> retorna DF

# %%
Affairs.education
# Out:
# 0      18
# 1      14
# 2      12
# 3      18
# 4      17
#        ..
# 596    12
# 597    18
# 598    17
# 599    18
# 600    14
# Name: education, Length: 601, dtype: int64

# %%
Affairs['education']
# Out:
# 0      18
# 1      14
# 2      12
# 3      18
# 4      17
#        ..
# 596    12
# 597    18
# 598    17
# 599    18
# 600    14
# Name: education, Length: 601, dtype: int64

# %%
Affairs[['education']]
# Out:
#      education
# 0           18
# 1           14
# 2           12
# 3           18
# 4           17
# ..         ...
# 596         12
# 597         18
# 598         17
# 599         18
# 600         14
#
# [601 rows x 1 columns]

# %%
type(Affairs[['education']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(Affairs['education'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### MultiIndex

# %%
financas.head(2)
# Out:
# Price      Adj Close                                                Close  \
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP     BRL=X
# Date
# 2023-01-02  5.285500  22.452349  17.709476  80.482170  106376.0  5.285500
# 2023-01-03  5.360131  21.984779  17.261332  80.338135  104166.0  5.360131
#
# Price                                              ...      Open           \
# Ticker     ITUB4.SA PETR4.SA   VALE3.SA     ^BVSP  ...     BRL=X ITUB4.SA
# Date                                               ...
# 2023-01-02    24.49    22.92  89.400002  106376.0  ...  5.285500    24.43
# 2023-01-03    23.98    22.34  89.239998  104166.0  ...  5.360131    24.49
#
# Price                                      Volume                          \
# Ticker       PETR4.SA   VALE3.SA     ^BVSP  BRL=X    ITUB4.SA    PETR4.SA
# Date
# 2023-01-02  23.540001  88.680000  109734.0      0  23340700.0  78424700.0
# 2023-01-03  22.940001  89.400002  106377.0      0  29873800.0  96750300.0
#
# ...

# %%
financas.columns
# Out:
# MultiIndex([('Adj Close',    'BRL=X'),
#             ('Adj Close', 'ITUB4.SA'),
#             ('Adj Close', 'PETR4.SA'),
#             ('Adj Close', 'VALE3.SA'),
#             ('Adj Close',    '^BVSP'),
#             (    'Close',    'BRL=X'),
#             (    'Close', 'ITUB4.SA'),
#             (    'Close', 'PETR4.SA'),
#             (    'Close', 'VALE3.SA'),
#             (    'Close',    '^BVSP'),
#             (     'High',    'BRL=X'),
#             (     'High', 'ITUB4.SA'),
#             (     'High', 'PETR4.SA'),
#             (     'High', 'VALE3.SA'),
#             (     'High',    '^BVSP'),
#             (      'Low',    'BRL=X'),
#             (      'Low', 'ITUB4.SA'),
#             (      'Low', 'PETR4.SA'),
#             (      'Low', 'VALE3.SA'),
#             (      'Low',    '^BVSP'),
#             (     'Open',    'BRL=X'),
#             (     'Open', 'ITUB4.SA'),
#             (     'Open', 'PETR4.SA'),
#             (     'Open', 'VALE3.SA'),
# ...

# %%
financas.columns[0:5]
# Out:
# MultiIndex([('Adj Close',    'BRL=X'),
#             ('Adj Close', 'ITUB4.SA'),
#             ('Adj Close', 'PETR4.SA'),
#             ('Adj Close', 'VALE3.SA'),
#             ('Adj Close',    '^BVSP')],
#            names=['Price', 'Ticker'])

# %%
# %%script echo skipping alternative solution
financas2 = financas[[('Adj Close',    'BRL=X'),
            ('Adj Close', 'ITUB4.SA'),
            ('Adj Close', 'PETR4.SA'),
            ('Adj Close', 'VALE3.SA'),
            ('Adj Close',    '^BVSP')]]

financas2.head()
# Out:
# Price      Adj Close
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.452349  17.709476  80.482170  106376.0
# 2023-01-03  5.360131  21.984779  17.261332  80.338135  104166.0
# 2023-01-04  5.478500  22.048956  17.809925  80.482170  105334.0
# 2023-01-05  5.430100  22.736551  18.451235  81.832550  107518.0
# 2023-01-06  5.349800  23.130779  18.343063  83.128899  108836.0

# %%
financas = financas['Adj Close']
financas
# Out:
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.452349  17.709476  80.482170  106376.0
# 2023-01-03  5.360131  21.984779  17.261332  80.338135  104166.0
# 2023-01-04  5.478500  22.048956  17.809925  80.482170  105334.0
# 2023-01-05  5.430100  22.736551  18.451235  81.832550  107518.0
# 2023-01-06  5.349800  23.130779  18.343063  83.128899  108836.0
# ...              ...        ...        ...        ...       ...
# 2023-12-25  4.869844        NaN        NaN        NaN       NaN
# 2023-12-26  4.869744  32.286663  37.330002  73.377686  133533.0
# 2023-12-27  4.813500  32.507343  37.360001  74.085999  134194.0
# 2023-12-28  4.826100  32.593700  37.240002  73.894554  134185.0
# 2023-12-29  4.850200        NaN        NaN        NaN       NaN
#
# [260 rows x 5 columns]

# %%
financas.sum()
# Out:
# Ticker
# BRL=X       1.298500e+03
# ITUB4.SA    6.348924e+03
# PETR4.SA    6.615076e+03
# VALE3.SA    1.699367e+04
# ^BVSP       2.832012e+07
# dtype: float64

# %%
financas.sum().sum()
# Out:
# 28351374.169801235

# %%
financas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 260 entries, 2023-01-02 to 2023-12-29
# Freq: B
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BRL=X     260 non-null    float64
#  1   ITUB4.SA  248 non-null    float64
#  2   PETR4.SA  248 non-null    float64
#  3   VALE3.SA  248 non-null    float64
#  4   ^BVSP     248 non-null    float64
# dtypes: float64(5)
# memory usage: 12.2 KB

# %% [markdown]
# ## Tratamento de Nulos

# %%
financas.isnull() # gera tabelas de vdd e falso para cada coluna
# Out:
# Ticker      BRL=X  ITUB4.SA  PETR4.SA  VALE3.SA  ^BVSP
# Date
# 2023-01-02  False     False     False     False  False
# 2023-01-03  False     False     False     False  False
# 2023-01-04  False     False     False     False  False
# 2023-01-05  False     False     False     False  False
# 2023-01-06  False     False     False     False  False
# ...           ...       ...       ...       ...    ...
# 2023-12-25  False      True      True      True   True
# 2023-12-26  False     False     False     False  False
# 2023-12-27  False     False     False     False  False
# 2023-12-28  False     False     False     False  False
# 2023-12-29  False      True      True      True   True
#
# [260 rows x 5 columns]

# %%
financas.isnull().sum()
# Out:
# Ticker
# BRL=X        0
# ITUB4.SA    12
# PETR4.SA    12
# VALE3.SA    12
# ^BVSP       12
# dtype: int64

# %%
financas[financas["ITUB4.SA"].isnull() ]
# Out:
# Ticker         BRL=X  ITUB4.SA  PETR4.SA  VALE3.SA  ^BVSP
# Date
# 2023-02-20  5.165169       NaN       NaN       NaN    NaN
# 2023-02-21  5.166700       NaN       NaN       NaN    NaN
# 2023-04-07  5.058300       NaN       NaN       NaN    NaN
# 2023-04-21  5.047700       NaN       NaN       NaN    NaN
# 2023-05-01  4.986000       NaN       NaN       NaN    NaN
# 2023-06-08  4.922400       NaN       NaN       NaN    NaN
# 2023-09-07  4.977000       NaN       NaN       NaN    NaN
# 2023-10-12  5.049600       NaN       NaN       NaN    NaN
# 2023-11-02  4.953700       NaN       NaN       NaN    NaN
# 2023-11-15  4.864500       NaN       NaN       NaN    NaN
# 2023-12-25  4.869844       NaN       NaN       NaN    NaN
# 2023-12-29  4.850200       NaN       NaN       NaN    NaN

# %%
# energia

energia.type.unique()
# Out:
# array(['Conventional thermal', 'Nuclear', 'Hydro', 'Pumped hydro power',
#        'Wind', 'Solar', 'Geothermal', 'Other'], dtype=object)

# %%
energia.groupby('type').groups.keys()
# Out:
# dict_keys(['Conventional thermal', 'Geothermal', 'Hydro', 'Nuclear', 'Other', 'Pumped hydro power', 'Solar', 'Wind'])

# %%
f"{energia.country_name.unique() } \n tAMANHO {len( energia.country_name.unique() )}"
# Out:
# "['Belgium' 'Bulgaria' 'Czechia' 'Denmark' 'Germany' 'Estonia' 'Ireland'\n 'Greece' 'Spain' 'France' 'Croatia' 'Italy' 'Cyprus' 'Latvia' 'Lithuania'\n 'Luxembourg' 'Hungary' 'Malta' 'Netherlands' 'Austria' 'Poland'\n 'Portugal' 'Romania' 'Slovenia' 'Slovakia' 'Finland' 'Sweden' nan\n 'Norway' 'Montenegro' 'North Macedonia' 'Albania' 'Serbia' 'Turkey'\n 'Bosnia & Herzegovina' 'Ukraine' 'Georgia'] \n tAMANHO 37"

# %%
len( energia.country_name.unique() )
# Out:
# 37

# %%
energia.country_name.nunique()
# Out:
# 36

# %%
len( energia.groupby('country_name').groups.keys() )
# Out:
# 36

# %%
energia.isnull()
# Out:
#      country  country_name   type  level   2016   2017   2018
# 0      False         False  False  False  False  False  False
# 1      False         False  False  False  False  False  False
# 2      False         False  False  False  False  False  False
# 3      False         False  False  False  False  False  False
# 4      False         False  False  False  False  False  False
# ..       ...           ...    ...    ...    ...    ...    ...
# 291    False         False  False  False  False  False  False
# 292    False         False  False  False  False  False  False
# 293    False         False  False  False  False  False  False
# 294    False         False  False  False  False  False  False
# 295    False         False  False  False  False  False  False
#
# [296 rows x 7 columns]

# %%
energia.isnull().sum()
# Out:
# country         0
# country_name    8
# type            0
# level           0
# 2016            0
# 2017            0
# 2018            0
# dtype: int64

# %%
energia[ energia.country_name.isnull() ]
# Out:
#     country country_name                  type    level        2016  \
# 216      UK          NaN  Conventional thermal  Level 1  203165.188
# 217      UK          NaN               Nuclear  Level 1   65149.080
# 218      UK          NaN                 Hydro  Level 1    8286.510
# 219      UK          NaN    Pumped hydro power  Level 2    2948.890
# 220      UK          NaN                  Wind  Level 1   37262.699
# 221      UK          NaN                 Solar  Level 1   10410.948
# 222      UK          NaN            Geothermal  Level 1       0.000
# 223      UK          NaN                 Other  Level 1       0.000
#
#            2017        2018
# 216  189296.528  180837.905
# 217   63886.860   59097.753
# 218    8723.430    7678.659
# 219    2862.010    2515.998
# 220   50003.654   56903.961
# 221   11524.870   12857.349
# 222       0.000       0.000
# 223       0.000       0.000

# %% [markdown]
# ## Contagem de dados do tipo x

# %%
dias = tips.day # series
dias = dias.to_list() # lista
dias.count('Sat')
# Out:
# 87

# %% [markdown]
# ## Seleção dos maiores e menores valores (nlargest, nsmallest)

# %%
tips.nsmallest(5,'total_bill')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2

# %%
tips_top3 = tips.nlargest(3,'total_bill')
tips_top3
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4
# 59        48.27   6.73  Male     No  Sat  Dinner     4

# %%
less10 = seguro.nsmallest(10,'age')
less10.charges.mean() #Qual a média dos pagamentos efetuados para os 10 casos com menor idade dos segurados? Aqui, empregue a função `nsmallest()`.
# Out:
# 11968.654240000002

# %% [markdown]
# Existem 69 indivíduos com a menor idade (18 anos) e o cálculo dos valores para as 10 menores idades deveria considerar esses 69 valores.

# %%
seguro.age.value_counts()
#Existem 69 indivíduos com a menor idade (18 anos) e o cálculo dos valores para as 10 menores idades deveria considerar esses 69 valores.
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %% [markdown]
# ## Calculos Estátisticos

# %%
f"{Affairs['education'].mean():.2f} - {Affairs['education'].sum()}"
# Out:
# '16.17 - 9716'

# %%
display(testeGroupby.groupby(testeGroupby.index).agg(['mean', 'std', 'min',"max",'count']))
display( testeGroupby.groupby(testeGroupby.index).mean() )
display( testeGroupby.groupby(testeGroupby.index).std() )
display( testeGroupby.groupby(testeGroupby.index).min() )
display( testeGroupby.groupby(testeGroupby.index).max() )
display( testeGroupby.groupby(testeGroupby.index).count() )
display(testeGroupby.groupby(testeGroupby.index).sum())
# Out:
#     data
#     mean      std min max count
# key
# A    2.5  2.12132   1   4     2
# B    3.5  2.12132   2   5     2
# C    4.5  2.12132   3   6     2
#      data
# key
# A     2.5
# B     3.5
# C     4.5
#         data
# key
# A    2.12132
# B    2.12132
# C    2.12132
#      data
# key
# A       1
# B       2
# C       3
#      data
# key
# A       4
# B       5
# C       6
#      data
# key
# A       2
# B       2
# C       2
#      data
# key
# A       5
# B       7
# C       9

# %%
carros2[['Min.Price', 'Price', 'Max.Price']].head(2)
# Out:
#    Min.Price  Price  Max.Price
#
# 1       12.9   15.9       18.8
# 2       29.2   33.9       38.7

# %%
carros2[['Min.Price', 'Price', 'Max.Price']].mean() # .mean(axis=0)
# Out:
# Min.Price    17.125806
# Price        19.509677
# Max.Price    21.898925
# dtype: float64

# %%
carros2[['Min.Price', 'Price', 'Max.Price']].mean(axis=1) # ('Min.Price' + 'Price' + 'Max.Price')/3
# Out:
# 1     15.866667
# 2     33.933333
# 3     29.100000
# 4     37.700000
# 5     29.966667
#         ...
# 89    19.666667
# 90    20.000000
# 91    23.300000
# 92    22.666667
# 93    26.666667
# Length: 93, dtype: float64

# %% [markdown]
# `count()`... Calcula a contagem do grupo, excluindo os valores ausentes...

# %%
seguroIncompleto = seguro.copy()

# %%
seguroIncompleto.groupby('sex').sex.count()
# Out:
# sex
# female    662
# male      676
# Name: sex, dtype: int64

# %%
seguroIncompleto.loc[0,'sex'] = None

seguroIncompleto.groupby('sex').sex.count()
# Out:
# sex
# female    661
# male      676
# Name: sex, dtype: int64

# %%
seguroIncompleto.groupby('sex',dropna=False).sex.count()
# Out:
# sex
# female    661
# male      676
# NaN         0
# Name: sex, dtype: int64

# %%
f"{seguroIncompleto.sex.unique()} tamanho {len(seguroIncompleto.sex.unique())} nunique desconsidera nulos {seguroIncompleto.sex.nunique()}|| { seguro.groupby('sex').groups.keys() } {len( seguro.groupby('sex').groups.keys() )}"
# Out:
# "[None 'male' 'female'] tamanho 3 nunique desconsidera nulos 2|| dict_keys(['female', 'male']) 2"

# %%
seguroIncompleto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
seguro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
fem = sum( seguro[seguro.sex == 'female'].charges )
print(f'Total dos Seguros (Mulheres):  {fem:.2f}')

masc = sum( seguro[seguro.sex == 'male'].charges )
print(f'Total dos Seguros (Homens):  {masc:.2f}')

seguro.groupby('sex').charges.sum()
# Out:
# Total dos Seguros (Mulheres):  8321061.19
# Total dos Seguros (Homens):  9434763.80
# sex
# female    8.321061e+06
# male      9.434764e+06
# Name: charges, dtype: float64

# %%
'{:.2f}'.format(8.321061e+06)
# Out:
# '8321061.00'

# %%
seguro.groupby('sex').charges.sum().apply(lambda x: '{:.2f}'.format(x))
# Out:
# sex
# female    8321061.19
# male      9434763.80
# Name: charges, dtype: object

# %% [markdown]
# #### Percorrendo varias variaveis

# %%
for c in [ 'age', 'yearsmarried', 'education']:
  print(Affairs[c].mean())
# Out:
# 32.48752079866888
# 8.17769550748752
# 16.16638935108153

# %%
financas[['ITUB4.SA', 'PETR4.SA', 'VALE3.SA']].mean()
# Out:
# Ticker
# ITUB4.SA    25.600500
# PETR4.SA    26.673692
# VALE3.SA    68.522865
# dtype: float64

# %%
financas.sum()
# Out:
# Ticker
# BRL=X       1.298500e+03
# ITUB4.SA    6.348924e+03
# PETR4.SA    6.615076e+03
# VALE3.SA    1.699367e+04
# ^BVSP       2.832012e+07
# dtype: float64

# %%
financas.sum().sum()
# Out:
# 28351374.169801235

# %%
# 
fem = len( seguro[seguro.sex == 'female'] ) / len(seguro)
print(f'Percentual de Mulheres seguradas: {fem:.4f}')

masc = len( seguro[seguro.sex == 'male'] ) / len(seguro)
print(f'Percentual de Homens segurados: {masc:.4f}')
# Out:
# Percentual de Mulheres seguradas: 0.4948
# Percentual de Homens segurados: 0.5052

# %%
seguro.groupby('sex').sex.count() / seguro.sex.count()
# Out:
# sex
# female    0.494768
# male      0.505232
# Name: sex, dtype: float64

# %%
fem = sum( seguro[seguro.sex == 'female'].charges ) / sum( seguro.charges )
print(f'Total dos Seguros (Mulheres):  {fem:.2f}')

masc = sum( seguro[seguro.sex == 'male'].charges ) / sum( seguro.charges )
print(f'Total dos Seguros (Homens):  {masc:.2f}')
# Out:
# Total dos Seguros (Mulheres):  0.47
# Total dos Seguros (Homens):  0.53

# %%
seguro.groupby('sex').charges.sum() / seguro.charges.sum()
# Out:
# sex
# female    0.468638
# male      0.531362
# Name: charges, dtype: float64

# %% [markdown]
# Não fumantes apresentam em média mais filhos?

# %%
seguro.groupby('smoker').children.mean()
# Out:
# smoker
# no     1.090226
# yes    1.113139
# Name: children, dtype: float64

# %%
seguro.groupby('smoker').children.mean().max()
# Out:
# 1.1131386861313868

# %%
seguro.groupby('smoker').children.mean() >= seguro.groupby('smoker').children.mean().max()
# Out:
# smoker
# no     False
# yes     True
# Name: children, dtype: bool

# %% [markdown]
# ## Metodos de uma serie

# %%
type(Affairs.children)
# Out:
# pandas.core.series.Series

# %%
Affairs.children
# Out:
# 0       no
# 1       no
# 2      yes
# 3      yes
# 4       no
#       ...
# 596    yes
# 597    yes
# 598    yes
# 599    yes
# 600    yes
# Name: children, Length: 601, dtype: object

# %%
Affairs.children.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
Affairs.children.nunique()
# Out:
# 2

# %%
Affairs.children.value_counts()
# Out:
# yes    430
# no     171
# Name: children, dtype: int64

# %%
seguro.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
seguro.charges.describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
seguro.region.describe()
# Out:
# count          1338
# unique            4
# top       southeast
# freq            364
# Name: region, dtype: object

# %%
seguro.age.value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %% [markdown]
# ## Seleção de Colunas

# %%
Affairs.columns
# Out:
# Index(['rownames', 'affairs', 'gender', 'age', 'yearsmarried', 'children',
#        'religiousness', 'education', 'occupation', 'rating'],
#       dtype='object')

# %%
Affairs[['affairs', 'education']]
# Out:
#      affairs  education
# 0          0         18
# 1          0         14
# 2          0         12
# 3          0         18
# 4          0         17
# ..       ...        ...
# 596        1         12
# 597        7         18
# 598        2         17
# 599        2         18
# 600        1         14
#
# [601 rows x 2 columns]

# %%
Affairs[['affairs', 'education']].mean()
# Out:
# affairs       1.455907
# education    16.166389
# dtype: float64

# %%
Affairs[['affairs', 'education']].head()
# Out:
#    affairs  education
# 0        0         18
# 1        0         14
# 2        0         12
# 3        0         18
# 4        0         17

# %%
Affairs2 = Affairs[['affairs', 'education']]
Affairs2.shape
# Out:
# (601, 2)

# %% [markdown]
# ## Seleção de Linhas

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_images/03_subset_rows.svg" width=320, align="center">
#
# A seleção de linhas é mais interessante por que podemos especificar condições para os valores que buscamos. Por exemplo, você pode selecionar o tipo de peças que deseja ver em um `DataFrame` com dados de vários componentes, ou selecionar a as unidades de fábrica de uma certa cidade que você tem os dados de produção.
#
# O critério de seleção é um predicado lógico e você deve empregar a seguinte sintaxe:
#
# ```
# df [ <critério de seleção> ]
# ```
#
# Exemplos
#
# ```
# df [ nome_coluna == valor ]
# df [ nome_coluna != valor ]
# df [ nome_coluna > valor ]
# ```

# %% [markdown]
# ###### Gera uma serie de true (aceita a condição ) e false

# %%
Affairs.children == 'yes'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 596     True
# 597     True
# 598     True
# 599     True
# 600     True
# Name: children, Length: 601, dtype: bool

# %% [markdown]
# ou

# %%
Affairs.children.isin(["yes"]) # esta em (is in)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 596     True
# 597     True
# 598     True
# 599     True
# 600     True
# Name: children, Length: 601, dtype: bool

# %% [markdown]
# ###### Pega os valores que estão em true da serie

# %%
Affairs[Affairs.children == 'yes']
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 2          11        0  female  32.0          15.0      yes              1
# 3          16        0    male  57.0          15.0      yes              5
# 7          45        0    male  57.0          15.0      yes              2
# 8          47        0  female  32.0          15.0      yes              4
# 10         50        0    male  37.0          15.0      yes              2
# ..        ...      ...     ...   ...           ...      ...            ...
# 596      1938        1    male  22.0           1.5      yes              1
# 597      1941        7  female  32.0          10.0      yes              2
# 598      1954        2    male  32.0          10.0      yes              2
# 599      1959        2    male  22.0           7.0      yes              3
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# ...

# %% [markdown]
# OU

# %%
Affairs[Affairs.children.isin(["yes"])]
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 2          11        0  female  32.0          15.0      yes              1
# 3          16        0    male  57.0          15.0      yes              5
# 7          45        0    male  57.0          15.0      yes              2
# 8          47        0  female  32.0          15.0      yes              4
# 10         50        0    male  37.0          15.0      yes              2
# ..        ...      ...     ...   ...           ...      ...            ...
# 596      1938        1    male  22.0           1.5      yes              1
# 597      1941        7  female  32.0          10.0      yes              2
# 598      1954        2    male  32.0          10.0      yes              2
# 599      1959        2    male  22.0           7.0      yes              3
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# ...

# %%
Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 18) ]
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 80        412        0    male  17.5          1.50      yes              3
# 540      1138       12  female  17.5          0.75      yes              2
# 571      1674       12  female  17.5          0.75      yes              2
#
#      education  occupation  rating
# 80          18           6       5
# 540         12           1       3
# 571         12           3       5

# %%
tips_nao_fumantes = tips[ tips.smoker == 'No' ]
tips_fumantes = tips[ tips.smoker == 'Yes' ]
print(f'Percentual de Clientes Fumantes {len( tips_fumantes ) / len( tips ) :.2f} %')
# Out:
# Percentual de Clientes Fumantes 0.38 %

# %%
# Considerando somente os finais de semana, quem tem média de participantes na mesa maior, fumantes ou não fumantes? 
print('Não fumantes tem média de participantes na mesa maior que fumantes? ',
      tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean() <
      tips[ (tips.smoker == 'No') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean())
# Out:
# Não fumantes tem média de participantes na mesa maior que fumantes?  True

# %%
f"Não fumantes {tips[ (tips.smoker == 'No') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean()} \
    fumantes {tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean()} \
        "
# Out:
# 'Não fumantes 2.764705882352941     fumantes 2.5081967213114753         '

# %%
tips[ tips.day.isin(['Sat','Sun']) ].groupby('smoker')['size'].mean()
# Out:
# smoker
# No     2.764706
# Yes    2.508197
# Name: size, dtype: float64

# %%
tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ].groupby(["day","smoker"]).count()
# Out:
#             total_bill  tip  sex  time  size
# day smoker
# Sat Yes             42   42   42    42    42
# Sun Yes             19   19   19    19    19

# %%
tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ].groupby(["day","smoker"])[["smoker"]].count()
# Out:
#             smoker
# day smoker
# Sat Yes         42
# Sun Yes         19

# %% [markdown]
# ## Seleção de Linhas e Colunas

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns_rows.svg" width=320, align="center">
#
# O uso mais geral das seleções é quando fazemos seleções de linhas e colunas dos dados, e às vezes nos referimos a esse subconjunto dos dados de *slice* (fatia) dos dados.
#
# A boa prática indica que sempre faremos primeiro a seleção das linhas,
#
# ```
# df [ <critério de seleção> ] ...
#
# ...Selecionando uma coluna
# df [ <critério de seleção> ].nome_coluna                  pd.Series
# df [ <critério de seleção> ]['nome_coluna']
#
# ...Selecionando uma ou mais colunas
# df [ <critério de seleção> ][ [<lista-de-colunas>] ]      pd.DataFrame
#
# ```

# %%
Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 18) ].education.mean()
# Out:
# 14.0

# %%
Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 30) ][['affairs', 'education']]
# Out:
#      affairs  education
# 11         0         18
# 19         0         14
# 22         0         16
# 28         0         16
# 29         0         17
# ..       ...        ...
# 580        1         18
# 590        7         16
# 593       12         17
# 596        1         12
# 599        2         18
#
# [135 rows x 2 columns]

# %%
tips[ tips.smoker == 'Yes' ]['tip'].mean() > tips[ tips.smoker == 'No' ]['tip'].mean()
# Out:
# True

# %%
tips[ tips.sex == 'Female' ]['tip'].mean() > tips[ tips.sex == 'Male' ]['tip'].mean()
# Out:
# False

# %%
import matplotlib.pyplot as plt
plt.hist(tips[ tips.sex == 'Male' ]['tip'], label='Homens')
plt.hist(tips[ tips.sex == 'Female' ]['tip'], label='Mulheres')

plt.xlabel('Valor das Gorjetas')
plt.ylabel('Quantidades Pagas')
plt.title('Distribuição das Gorjetas', fontsize=14, weight='bold')
plt.legend(title='$\\bf{Gorjetas}$')
plt.show()

# %% [markdown]
# ### Porcentagem

# %%
len( Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 30) ] ) / len(Affairs) * 100
# Out:
# 22.462562396006653

# %% [markdown]
# # Acessando valores por índice .loc, .iloc, .at, .iat
# i - pega pelo indice numero
#
# sem i - pega pelo valor nome

# %% [markdown]
# `DataFrame.loc`
#
# Access a group of rows and columns by label(s).
#
# `DataFrame.iloc`
#
# Access a group of rows and columns by integer position(s).
#
# `DataFrame.at`
#
# Access a single value for a row/column label pair.
#
# `DataFrame.iat`
#
# Access a single value for a row/column pair by integer position.

# %%
carros.mpg
# Out:
# Veiculo
# Mazda RX4              21.0
# Mazda RX4 Wag          21.0
# Datsun 710             22.8
# Hornet 4 Drive         21.4
# Hornet Sportabout      18.7
# Valiant                18.1
# Duster 360             14.3
# Merc 240D              24.4
# Merc 230               22.8
# Merc 280               19.2
# Merc 280C              17.8
# Merc 450SE             16.4
# Merc 450SL             17.3
# Merc 450SLC            15.2
# Cadillac Fleetwood     10.4
# Lincoln Continental    10.4
# Chrysler Imperial      14.7
# Fiat 128               32.4
# Honda Civic            30.4
# Toyota Corolla         33.9
# Toyota Corona          21.5
# Dodge Challenger       15.5
# AMC Javelin            15.2
# Camaro Z28             13.3
# Pontiac Firebird       19.2
# Fiat X1-9              27.3
# Porsche 914-2          26.0
# Lotus Europa           30.4
# Ford Pantera L         15.8
# Ferrari Dino           19.7
# Maserati Bora          15.0
# Volvo 142E             21.4
# Name: mpg, dtype: float64

# %%
carros.mpg['Porsche 914-2']
# Out:
# 26.0

# %% [markdown]
# df['Porsche 914-2'] --> erro não pode buscar linhas como se fossem colunas - usar o loc

# %%
# Dataframe
carros.loc['Porsche 914-2']
# Out:
# mpg      26.00
# cyl       4.00
# disp    120.30
# hp       91.00
# drat      4.43
# wt        2.14
# qsec     16.70
# vs        0.00
# am        1.00
# gear      5.00
# carb      2.00
# Name: Porsche 914-2, dtype: float64

# %%
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros.loc['Datsun 710',['mpg','cyl']]
# Out:
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64

# %%
carros.loc['Datsun 710'][['mpg','cyl']]
# Out:
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64

# %%
carros.iloc[2,0:2]
# Out:
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64

# %% [markdown]
# # Ordenar

# %%
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros = carros.sort_index()
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %% [markdown]
# # Acessando valores por índice .loc, .iloc, .at, .iat

# %%
carros.loc['Camaro Z28':'Datsun 710'] # pegando valores do camaro até datsun
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Camaro Z28         13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                    carb
# Veiculo
# Camaro Z28            4
# Chrysler Imperial     4
# Datsun 710            1

# %%
carros.loc['Camaro Z28':'Datsun 710' , 'hp':'am'] # pegando valores do camaro até datsun e as colunas hp até am
# Out:
#                     hp  drat     wt   qsec  vs  am
# Veiculo
# Camaro Z28         245  3.73  3.840  15.41   0   0
# Chrysler Imperial  230  3.23  5.345  17.42   0   0
# Datsun 710          93  3.85  2.320  18.61   1   1

# %%
carros.iloc[2:5 , 3:9] # pegando valores do camaro até datsun e as colunas hp até am
# Out:
#                     hp  drat     wt   qsec  vs  am
# Veiculo
# Camaro Z28         245  3.73  3.840  15.41   0   0
# Chrysler Imperial  230  3.23  5.345  17.42   0   0
# Datsun 710          93  3.85  2.320  18.61   1   1

# %% [markdown]
# df.at['Datsun 710',['mpg','cyl']] --> erro

# %%
carros.at['Datsun 710','mpg']
# Out:
# 22.8

# %%
carros.iat[2,0]
# Out:
# 13.3

# %% [markdown]
# df.ix[2:5,'mpg'] - ERRO

# %%
carros.iloc[2:5]['mpg']
# Out:
# Veiculo
# Camaro Z28           13.3
# Chrysler Imperial    14.7
# Datsun 710           22.8
# Name: mpg, dtype: float64

# %% [markdown]
# # Atualizando Valores

# %%
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %%
carros['kmpg'] = 1.6 * carros['mpg']
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
carros['hp'] = carros['hp'] * 10
carros.head()
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dolar_real_rate = 5.8
tips['total_bill'] = tips['total_bill'] * dolar_real_rate         # alterando
tips['tip'] = tips['tip'] * dolar_real_rate                       # alterando

tips['total_bill_minus_tips'] = tips['total_bill'] - tips['tip']    # incluindo um novo atributo
tips['bill_by_head'] = tips['total_bill'] / tips['size']            # incluindo um novo atributo
tips.head()
# Out:
#    total_bill     tip     sex smoker  day    time  size  \
# 0      98.542   5.858  Female     No  Sun  Dinner     2
# 1      59.972   9.628    Male     No  Sun  Dinner     3
# 2     121.858  20.300    Male     No  Sun  Dinner     3
# 3     137.344  19.198    Male     No  Sun  Dinner     2
# 4     142.622  20.938  Female     No  Sun  Dinner     4
#
#    total_bill_minus_tips  bill_by_head
# 0                 92.684     49.271000
# 1                 50.344     19.990667
# 2                101.558     40.619333
# 3                118.146     68.672000
# 4                121.684     35.655500

# %% [markdown]
# ### Atualizando Valores especificos

# %%
carros.loc[ 'Cadillac Fleetwood' , 'am' ] = 1 # atualizando dado especifico
carros.head()
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
carros.iloc[ 1 , 8 ] = 0  # atualizando dado especifico
carros.head()
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
carros.head(11)
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
# Dodge Challenger    15.5    8  318.0  1500  2.76  3.520  16.87   0   0     3
# Duster 360          14.3    8  360.0  2450  3.21  3.570  15.84   0   0     3
# Ferrari Dino        19.7    6  145.0  1750  3.62  2.770  15.50   0   1     5
# Fiat 128            32.4    4   78.7   660  4.08  2.200  19.47   1   1     4
# Fiat X1-9           27.3    4   79.0   660  4.08  1.935  18.90   1   1     4
# Ford Pantera L      15.8    8  351.0  2640  4.22  3.170  14.50   0   1     5
#
#                     carb   kmpg
# ...

# %%
carros.iloc[ 0:10 , 8 ] = 1 # linhas da 0-10 coluna 8 tudo fica = 1
carros.head(12)
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
# Dodge Challenger    15.5    8  318.0  1500  2.76  3.520  16.87   0   1     3
# Duster 360          14.3    8  360.0  2450  3.21  3.570  15.84   0   1     3
# Ferrari Dino        19.7    6  145.0  1750  3.62  2.770  15.50   0   1     5
# Fiat 128            32.4    4   78.7   660  4.08  2.200  19.47   1   1     4
# Fiat X1-9           27.3    4   79.0   660  4.08  1.935  18.90   1   1     4
# Ford Pantera L      15.8    8  351.0  2640  4.22  3.170  14.50   0   1     5
# ...

# %% [markdown]
# ### Atualizar varias colunas ao mesmo tempo

# %%
financas.head()
# Out:
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.452349  17.709476  80.482170  106376.0
# 2023-01-03  5.360131  21.984779  17.261332  80.338135  104166.0
# 2023-01-04  5.478500  22.048956  17.809925  80.482170  105334.0
# 2023-01-05  5.430100  22.736551  18.451235  81.832550  107518.0
# 2023-01-06  5.349800  23.130779  18.343063  83.128899  108836.0

# %% [markdown]
# Converta os valores cabíves para reais.

# %%
for column in ['ITUB4.SA', 'PETR4.SA', 'VALE3.SA']:
  financas[column] = financas[column] * financas['BRL=X']

financas.head()
# Out:
# Ticker         BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  118.671890   93.603439  425.388514  106376.0
# 2023-01-03  5.360131  117.841293   92.522995  430.622910  104166.0
# 2023-01-04  5.478500  120.795203   97.571673  440.921560  105334.0
# 2023-01-05  5.430100  123.461746  100.192050  444.358927  107518.0
# 2023-01-06  5.349800  123.745045   98.131722  444.722991  108836.0

# %% [markdown]
# # Iterando sobre as linhas
# ## `iterrows()`

# %%
for index, row in carros.iterrows():

  if row['disp'] > 450:
    print(row)
# Out:
# mpg       10.40
# cyl        8.00
# disp     472.00
# hp      2050.00
# drat       2.93
# wt         5.25
# qsec      17.98
# vs         0.00
# am         1.00
# gear       3.00
# carb       4.00
# kmpg      16.64
# Name: Cadillac Fleetwood, dtype: float64
# mpg       10.400
# cyl        8.000
# disp     460.000
# hp      2150.000
# drat       3.000
# wt         5.424
# qsec      17.820
# vs         0.000
# am         0.000
# gear       3.000
# carb       4.000
# kmpg      16.640
# Name: Lincoln Continental, dtype: float64

# %%
print(carros.mpg.sum())

for _, row in carros.iterrows():

  # print('before',row['mpg'])
  row['mpg'] = row['mpg'] + 1
  # print('after',row['mpg'])

print(carros.mpg.sum())
# Out:
# 642.9
# 642.9

# %%
carros.head()
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
for index, row in carros.iterrows():

  if row['disp'] > 450:
    print(row.name, 'mpg = ', row.mpg)
# Out:
# Cadillac Fleetwood mpg =  10.4
# Lincoln Continental mpg =  10.4

# %% [markdown]
# # Acessando valores por índice .loc, .iloc, .at, .iat
# ## iloc

# %%
display(Affairs.head(1)) # primeiros 1 valores
display(Affairs.tail(1)) # ultimos 1 valores
# Out:
#    rownames  affairs gender   age  yearsmarried children  religiousness  \
# 0         4        0   male  37.0          10.0       no              3
#
#    education  occupation  rating
# 0         18           7       4
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 600         14           1       5

# %%
display(Affairs.iloc[1])
display(Affairs.iloc[-1])
# Out:
# rownames              5
# affairs               0
# gender           female
# age                27.0
# yearsmarried        4.0
# children             no
# religiousness         4
# education            14
# occupation            6
# rating                4
# Name: 1, dtype: object
# rownames           9010
# affairs               1
# gender           female
# age                32.0
# yearsmarried       15.0
# children            yes
# religiousness         3
# education            14
# occupation            1
# rating                5
# Name: 600, dtype: object

# %%
for line in range(0,len(carros)):
  print( carros.iloc[line] )
# Out:
# mpg       15.200
# cyl        8.000
# disp     304.000
# hp      1500.000
# drat       3.150
# wt         3.435
# qsec      17.300
# vs         0.000
# am         1.000
# gear       3.000
# carb       2.000
# kmpg      24.320
# Name: AMC Javelin, dtype: float64
# mpg       10.40
# cyl        8.00
# disp     472.00
# hp      2050.00
# drat       2.93
# wt         5.25
# qsec      17.98
# vs         0.00
# am         1.00
# gear       3.00
# carb       4.00
# kmpg      16.64
# Name: Cadillac Fleetwood, dtype: float64
# mpg       13.30
# cyl        8.00
# disp     350.00
# hp      2450.00
# drat       3.73
# wt         3.84
# qsec      15.41
# vs         0.00
# am         1.00
# gear       3.00
# carb       4.00
# kmpg      21.28
# Name: Camaro Z28, dtype: float64
# mpg       14.700
# cyl        8.000
# disp     440.000
# hp      2300.000
# drat       3.230
# wt         5.345
# qsec      17.420
# vs         0.000
# am         1.000
# gear       3.000
# carb       4.000
# ...

# %%
for line in range(0,len(carros)):
  print( carros.iloc[line, 0:2] )
# Out:
# mpg    15.2
# cyl     8.0
# Name: AMC Javelin, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Cadillac Fleetwood, dtype: float64
# mpg    13.3
# cyl     8.0
# Name: Camaro Z28, dtype: float64
# mpg    14.7
# cyl     8.0
# Name: Chrysler Imperial, dtype: float64
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64
# mpg    15.5
# cyl     8.0
# Name: Dodge Challenger, dtype: float64
# mpg    14.3
# cyl     8.0
# Name: Duster 360, dtype: float64
# mpg    19.7
# cyl     6.0
# Name: Ferrari Dino, dtype: float64
# mpg    32.4
# cyl     4.0
# Name: Fiat 128, dtype: float64
# mpg    27.3
# cyl     4.0
# Name: Fiat X1-9, dtype: float64
# mpg    15.8
# cyl     8.0
# Name: Ford Pantera L, dtype: float64
# mpg    30.4
# cyl     4.0
# Name: Honda Civic, dtype: float64
# mpg    21.4
# cyl     6.0
# Name: Hornet 4 Drive, dtype: float64
# mpg    18.7
# cyl     8.0
# Name: Hornet Sportabout, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Lincoln Continental, dtype: float64
# ...

# %%
for line in range(0,len(carros)):
  print( carros.iloc[line][['mpg','cyl']] )
# Out:
# mpg    15.2
# cyl     8.0
# Name: AMC Javelin, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Cadillac Fleetwood, dtype: float64
# mpg    13.3
# cyl     8.0
# Name: Camaro Z28, dtype: float64
# mpg    14.7
# cyl     8.0
# Name: Chrysler Imperial, dtype: float64
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64
# mpg    15.5
# cyl     8.0
# Name: Dodge Challenger, dtype: float64
# mpg    14.3
# cyl     8.0
# Name: Duster 360, dtype: float64
# mpg    19.7
# cyl     6.0
# Name: Ferrari Dino, dtype: float64
# mpg    32.4
# cyl     4.0
# Name: Fiat 128, dtype: float64
# mpg    27.3
# cyl     4.0
# Name: Fiat X1-9, dtype: float64
# mpg    15.8
# cyl     8.0
# Name: Ford Pantera L, dtype: float64
# mpg    30.4
# cyl     4.0
# Name: Honda Civic, dtype: float64
# mpg    21.4
# cyl     6.0
# Name: Hornet 4 Drive, dtype: float64
# mpg    18.7
# cyl     8.0
# Name: Hornet Sportabout, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Lincoln Continental, dtype: float64
# ...

# %%
display(carros.head())

for i in range(0,len(carros)):

  carros.iloc[i]['mpg'] = carros.iloc[i]['mpg'] + 10 # NÃO ALTERA --> Gera uma copia do df quando eu seleciono a coluna

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
# /tmp/ipykernel_91298/4206193782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
display(carros.head())

for line in range(0,len(carros)):
  carros.iloc[line,0] = carros.iloc[line,0] + 10 # Gera a copia -- não estou selecionando a coluna

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         25.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  20.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# ...

# %%
display(carros.head())

for line in range(0,len(carros)):
  for column in range(0,carros.shape[1]):
    carros.iloc[line,column] = carros.iloc[line,column] + 10 # somando mais 10 em todas as linhas e colunas do df

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         25.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  20.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          23.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   24.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          32.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
#                      mpg  cyl   disp    hp   drat      wt   qsec  vs  am  \
# Veiculo
# AMC Javelin         35.2   18  314.0  1510  13.15  13.435  27.30  10  11
# Cadillac Fleetwood  30.4   18  482.0  2060  12.93  15.250  27.98  10  11
# ...

# %% [markdown]
# ## LOC

# %%
carros.keys()
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb', 'kmpg'],
#       dtype='object')

# %%
for column in carros:
  print(column)
# Out:
# mpg
# cyl
# disp
# hp
# drat
# wt
# qsec
# vs
# am
# gear
# carb
# kmpg

# %%
carros.index
# Out:
# Index(['AMC Javelin', 'Cadillac Fleetwood', 'Camaro Z28', 'Chrysler Imperial',
#        'Datsun 710', 'Dodge Challenger', 'Duster 360', 'Ferrari Dino',
#        'Fiat 128', 'Fiat X1-9', 'Ford Pantera L', 'Honda Civic',
#        'Hornet 4 Drive', 'Hornet Sportabout', 'Lincoln Continental',
#        'Lotus Europa', 'Maserati Bora', 'Mazda RX4', 'Mazda RX4 Wag',
#        'Merc 230', 'Merc 240D', 'Merc 280', 'Merc 280C', 'Merc 450SE',
#        'Merc 450SL', 'Merc 450SLC', 'Pontiac Firebird', 'Porsche 914-2',
#        'Toyota Corolla', 'Toyota Corona', 'Valiant', 'Volvo 142E'],
#       dtype='object', name='Veiculo')

# %%
for line in carros.index:
  print(line)
# Out:
# AMC Javelin
# Cadillac Fleetwood
# Camaro Z28
# Chrysler Imperial
# Datsun 710
# Dodge Challenger
# Duster 360
# Ferrari Dino
# Fiat 128
# Fiat X1-9
# Ford Pantera L
# Honda Civic
# Hornet 4 Drive
# Hornet Sportabout
# Lincoln Continental
# Lotus Europa
# Maserati Bora
# Mazda RX4
# Mazda RX4 Wag
# Merc 230
# Merc 240D
# Merc 280
# Merc 280C
# Merc 450SE
# Merc 450SL
# Merc 450SLC
# Pontiac Firebird
# Porsche 914-2
# Toyota Corolla
# Toyota Corona
# Valiant
# Volvo 142E

# %%
display(carros.head())

for line in carros.index:
  for column in carros:
    carros.loc[line,column] = carros.loc[line,column] + 10 # somar + 10 em todas as linhas e colunas

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp   drat      wt   qsec  vs  am  \
# Veiculo
# AMC Javelin         35.2   18  314.0  1510  13.15  13.435  27.30  10  11
# Cadillac Fleetwood  30.4   18  482.0  2060  12.93  15.250  27.98  10  11
# Camaro Z28          33.3   18  360.0  2460  13.73  13.840  25.41  10  11
# Chrysler Imperial   34.7   18  450.0  2310  13.23  15.345  27.42  10  11
# Datsun 710          42.8   14  118.0   940  13.85  12.320  28.61  11  11
#
#                     gear  carb   kmpg
# Veiculo
# AMC Javelin           13    12  34.32
# Cadillac Fleetwood    13    14  26.64
# Camaro Z28            13    14  31.28
# Chrysler Imperial     13    14  33.52
# Datsun 710            14    11  46.48
#                      mpg  cyl   disp    hp   drat      wt   qsec  vs  am  \
# Veiculo
# AMC Javelin         45.2   28  324.0  1520  23.15  23.435  37.30  20  21
# Cadillac Fleetwood  40.4   28  492.0  2070  22.93  25.250  37.98  20  21
# ...

# %% [markdown]
# # Agregações de linhas ou colunas

# %%
testeGroupby
# Out:
#      data
# key
# A       1
# B       2
# C       3
# A       4
# B       5
# C       6

# %%
testeGroupby.groupby(testeGroupby.index).sum()
# Out:
#      data
# key
# A       5
# B       7
# C       9

# %%
display( testeGroupby.groupby(testeGroupby.index).mean() )
display( testeGroupby.groupby(testeGroupby.index).std() )
display( testeGroupby.groupby(testeGroupby.index).min() )
display(testeGroupby.groupby(testeGroupby.index).sum())
# Out:
#      data
# key
# A     2.5
# B     3.5
# C     4.5
#         data
# key
# A    2.12132
# B    2.12132
# C    2.12132
#      data
# key
# A       1
# B       2
# C       3
#      data
# key
# A       5
# B       7
# C       9

# %%
carros2.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
#        'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
#        'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
#        'Make'],
#       dtype='object')

# %%
seguro.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
seguro.groupby('region').groups.keys()
# Out:
# dict_keys(['northeast', 'northwest', 'southeast', 'southwest'])

# %% [markdown]
# ## Agregação de 1 nível

# %%
carros2.Type.value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
carros2.groupby('Type').Price.mean()
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
carros2.groupby('Type').Price.count()
# Out:
# Type
# Compact    16
# Large      11
# Midsize    22
# Small      21
# Sporty     14
# Van         9
# Name: Price, dtype: int64

# %%
carros2.groupby('Type')[['Price','MPG.city']].mean()
# Out:
#              Price   MPG.city
# Type
# Compact  18.212500  22.687500
# Large    24.300000  18.363636
# Midsize  27.218182  19.545455
# Small    10.166667  29.857143
# Sporty   19.392857  21.785714
# Van      19.100000  17.000000

# %%
carros2.groupby('Type').mean()
# Out:
#          Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# Type
# Compact  15.693750  18.212500  20.725000  22.687500    29.875000    2.331250
# Large    22.936364  24.300000  25.672727  18.363636    26.727273    4.209091
# Midsize  24.113636  27.218182  30.313636  19.545455    26.727273    3.059091
# Small     8.428571  10.166667  11.904762  29.857143    35.476190    1.595238
# Sporty   16.857143  19.392857  21.957143  21.785714    28.785714    2.492857
# Van      16.200000  19.100000  22.033333  17.000000    21.888889    3.200000
#
#          Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# Type
# Compact  131.000000  5362.500000   2475.625000           16.068750
# Large    179.454545  4672.727273   1626.818182           19.090909
# Midsize  173.090909  5336.363636   2221.363636           18.450000
# Small     91.000000  5633.333333   2817.380952           12.619048
# Sporty   160.142857  5392.857143   2314.285714           15.950000
# ...

# %% [markdown]
# ## Agregação de mais níveis

# %%
carros2.groupby(['Type','DriveTrain']).Price.mean()
# Out:
# Type     DriveTrain
# Compact  4WD           19.500000
#          Front         16.715385
#          Rear          27.300000
# Large    Front         23.971429
#          Rear          24.875000
# Midsize  Front         24.052941
#          Rear          37.980000
# Small    4WD            9.650000
#          Front         10.221053
# Sporty   4WD           20.100000
#          Front         16.014286
#          Rear          23.840000
# Van      4WD           19.460000
#          Front         18.650000
# Name: Price, dtype: float64

# %% [markdown]
# ### Acessando o grupo por chave

# %%
carros2.groupby(['Type','DriveTrain']).Price.mean()['Compact']
# Out:
# DriveTrain
# 4WD      19.500000
# Front    16.715385
# Rear     27.300000
# Name: Price, dtype: float64

# %% [markdown]
# ## Unstack faz o filtro (groupby) ficar em coluna

# %%
carros2.groupby(['Type','DriveTrain']).Price.mean().unstack()
# Out:
# DriveTrain    4WD      Front    Rear
# Type
# Compact     19.50  16.715385  27.300
# Large         NaN  23.971429  24.875
# Midsize       NaN  24.052941  37.980
# Small        9.65  10.221053     NaN
# Sporty      20.10  16.014286  23.840
# Van         19.46  18.650000     NaN

# %% [markdown]
# ## Função de agragação .agg()

# %%
display(testeGroupby.groupby(testeGroupby.index).agg(['mean', 'std', 'min']))
display( testeGroupby.groupby(testeGroupby.index).mean() )
display( testeGroupby.groupby(testeGroupby.index).std() )
display( testeGroupby.groupby(testeGroupby.index).min() )
display(testeGroupby.groupby(testeGroupby.index).sum())
# Out:
#     data
#     mean      std min
# key
# A    2.5  2.12132   1
# B    3.5  2.12132   2
# C    4.5  2.12132   3
#      data
# key
# A     2.5
# B     3.5
# C     4.5
#         data
# key
# A    2.12132
# B    2.12132
# C    2.12132
#      data
# key
# A       1
# B       2
# C       3
#      data
# key
# A       5
# B       7
# C       9

# %%
display( pedidos.groupby('Itens')['Quantidade'].agg(['mean', 'std', 'min', 'count']) )
# Out:
#                      mean       std  min  count
# Itens
# Boné             1.000000       NaN    1      1
# Camiseta         1.666667  1.154701    1      3
# Keds             3.000000       NaN    3      1
# Tênis Caminhada  2.000000  0.000000    2      3
# Tênis Corrida    1.000000       NaN    1      1

# %%
carros2.groupby('Type').Price.agg(['mean','std'])
# Out:
#               mean        std
# Type
# Compact  18.212500   6.686890
# Large    24.300000   6.337507
# Midsize  27.218182  12.264841
# Small    10.166667   1.953288
# Sporty   19.392857   7.974716
# Van      19.100000   1.878164

# %%
display( pedidos.groupby('Pedido').agg(['mean', 'std', 'min']) )
# Out:
# /tmp/ipykernel_91298/2441365180.py:1: FutureWarning: ['Itens'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   display( pedidos.groupby('Pedido').agg(['mean', 'std', 'min']) )
#        Preco Unidade                 Quantidade
#                 mean         std min       mean       std min
# Pedido
# 1         213.333333  109.696551  90       2.00  1.000000   1
# 2         162.500000  101.775898  60       1.75  0.957427   1
# 3         170.000000  113.137085  90       1.50  0.707107   1

# %%
carros2.groupby('Type').Price.agg(['mean','std'])
# Out:
#               mean        std
# Type
# Compact  18.212500   6.686890
# Large    24.300000   6.337507
# Midsize  27.218182  12.264841
# Small    10.166667   1.953288
# Sporty   19.392857   7.974716
# Van      19.100000   1.878164

# %%
display( pedidos.groupby( ['Itens','Pedido'] ).agg(['min','max']) )
# Out:
#                        Preco Unidade      Quantidade
#                                  min  max        min max
# Itens           Pedido
# Boné            2                 60   60          1   1
# Camiseta        1                 90   90          3   3
#                 2                 90   90          1   1
#                 3                 90   90          1   1
# Keds            2                250  250          3   3
# Tênis Caminhada 1                250  250          2   2
#                 2                250  250          2   2
#                 3                250  250          2   2
# Tênis Corrida   1                300  300          1   1

# %% [markdown]
# ### Diferentes Agregadores

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'Price': 'mean', 'MPG.city': 'max' })
# Out:
#              Price  MPG.city
# Type
# Compact  18.212500        26
# Large    24.300000        20
# Midsize  27.218182        23
# Small    10.166667        46
# Sporty   19.392857        30
# Van      19.100000        18

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'Price': ['mean', 'std'], 'MPG.city': 'max' })
# Out:
#              Price            MPG.city
#               mean        std      max
# Type
# Compact  18.212500   6.686890       26
# Large    24.300000   6.337507       20
# Midsize  27.218182  12.264841       23
# Small    10.166667   1.953288       46
# Sporty   19.392857   7.974716       30
# Van      19.100000   1.878164       18

# %% [markdown]
# ### Mode

# %%
pd.Series.mode
# Out:
# <function pandas.core.series.Series.mode(self, dropna: 'bool' = True) -> 'Series'>

# %%
carros2.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 1        Acura  Integra    Small       12.9   15.9       18.8        25
# 2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 3         Audi       90  Compact       25.9   29.1       32.3        20
# 4         Audi      100  Midsize       30.8   37.7       44.6        19
# 5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
#                                                ...
# 1           31                None      Front  ...          5     177
# 2           25  Driver & Passenger      Front  ...          5     195
# 3           26         Driver only      Front  ...          5     180
# 4           26  Driver & Passenger      Front  ...          6     193
# 5           30         Driver only       Rear  ...          4     186
#
# ...

# %% [markdown]
# .agg(pd.Series.mode): agg() é uma função de agregação que recebe uma função como argumento. Neste caso, a função passada é pd.Series.mode, que calcula a moda (valor mais comum) de uma série do Pandas. Então, para cada grupo de 'DriveTrain', esta função retorna o valor que ocorre com maior frequência.
#
# Resumindo, este código agrupa os dados pelo tipo de veículo ('Type') e então encontra o tipo de tração ('DriveTrain') mais comum dentro de cada grupo.

# %%
carros2.groupby('Type').DriveTrain.agg( pd.Series.mode )
# Out:
# Type
# Compact    Front
# Large      Front
# Midsize    Front
# Small      Front
# Sporty     Front
# Van          4WD
# Name: DriveTrain, dtype: object

# %% [markdown]
# ### Aggregate user functions

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'Price': ['mean', 'std'], 'MPG.city': lambda x: x.max() - x.min() })
# Out:
#              Price            MPG.city
#               mean        std <lambda>
# Type
# Compact  18.212500   6.686890        6
# Large    24.300000   6.337507        4
# Midsize  27.218182  12.264841        7
# Small    10.166667   1.953288       24
# Sporty   19.392857   7.974716       13
# Van      19.100000   1.878164        3

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'MPG.city': ["max","min",lambda x: x.max() - x.min() ]})
# Out:
#         MPG.city
#              max min <lambda_0>
# Type
# Compact       26  20          6
# Large         20  16          4
# Midsize       23  16          7
# Small         46  22         24
# Sporty        30  17         13
# Van           18  15          3

# %% [markdown]
# ### Iteração sobre os grupos

# %%
for (Type, group) in carros2.groupby('Type'):
    print("{0:30s} shape={1}".format(Type, group.shape))
# Out:
# Compact                        shape=(16, 27)
# Large                          shape=(11, 27)
# Midsize                        shape=(22, 27)
# Small                          shape=(21, 27)
# Sporty                         shape=(14, 27)
# Van                            shape=(9, 27)

# %%
group_list = []

for (Type, group) in carros2.groupby('Type'):
    group_list.append(group)

# %%
group_list[0]
# Out:
#      Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 3            Audi        90  Compact       25.9   29.1       32.3        20
# 12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 13      Chevrolet   Corsica  Compact       11.4   11.4       11.4        25
# 21       Chrysler   LeBaron  Compact       14.5   15.8       17.1        23
# 25          Dodge    Spirit  Compact       11.9   13.3       14.7        22
# 33           Ford     Tempo  Compact       10.4   11.3       12.2        22
# 43          Honda    Accord  Compact       13.8   17.5       21.2        24
# 55          Mazda       626  Compact       14.3   16.5       18.7        26
# 58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9        20
# 65         Nissan    Altima  Compact       13.0   15.7       18.3        24
# 68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# ...

# %%
group_list[1]
# Out:
#    Manufacturer           Model   Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 7         Buick         LeSabre  Large       19.9   20.8       21.7        19
# 8         Buick      Roadmaster  Large       22.6   23.7       24.9        16
# 10     Cadillac         DeVille  Large       33.0   34.7       36.3        16
# 18    Chevrolet         Caprice  Large       18.0   18.8       19.6        17
# 20     Chrylser        Concorde  Large       18.4   18.4       18.4        20
# 22     Chrysler        Imperial  Large       29.5   29.5       29.5        20
# 30        Eagle          Vision  Large       17.5   19.3       21.2        20
# 38         Ford  Crown_Victoria  Large       20.1   20.9       21.7        18
# 52      Lincoln        Town_Car  Large       34.4   36.1       37.8        18
# 71   Oldsmobile    Eighty-Eight  Large       19.5   20.7       21.9        19
# 77      Pontiac      Bonneville  Large       19.4   24.4       29.4        19
#
# ...

# %%
grupos_itens = carros2.groupby('Type')
print ( grupos_itens )
print ( grupos_itens.groups )
# Out:
# ...
# {'Compact': [3, 12, 13, 21, 25, 33, 43, 55, 58, 65, 68, 74, 78, 82, 90, 92], 'Large': [7, 8, 10, 18, 20, 22, 30, 38, 52, 71, 77], 'Midsize': [2, 4, 5, 6, 9, 11, 15, 27, 37, 47, 48, 49, 50, 51, 59, 61, 63, 67, 69, 76, 86, 93], 'Small': [1, 23, 24, 29, 31, 32, 39, 42, 44, 45, 53, 54, 62, 64, 73, 79, 80, 81, 83, 84, 88], 'Sporty': [14, 19, 28, 34, 35, 40, 41, 46, 57, 60, 72, 75, 85, 91], 'Van': [16, 17, 26, 36, 56, 66, 70, 87, 89]}

# %%
print ( grupos_itens.groups.keys() )
print ( grupos_itens.groups.values() )
# Out:
# dict_keys(['Compact', 'Large', 'Midsize', 'Small', 'Sporty', 'Van'])
# dict_values([Int64Index([3, 12, 13, 21, 25, 33, 43, 55, 58, 65, 68, 74, 78, 82, 90, 92], dtype='int64', name=''), Int64Index([7, 8, 10, 18, 20, 22, 30, 38, 52, 71, 77], dtype='int64', name=''), Int64Index([ 2,  4,  5,  6,  9, 11, 15, 27, 37, 47, 48, 49, 50, 51, 59, 61, 63,
#             67, 69, 76, 86, 93],
#            dtype='int64', name=''), Int64Index([ 1, 23, 24, 29, 31, 32, 39, 42, 44, 45, 53, 54, 62, 64, 73, 79, 80,
#             81, 83, 84, 88],
#            dtype='int64', name=''), Int64Index([14, 19, 28, 34, 35, 40, 41, 46, 57, 60, 72, 75, 85, 91], dtype='int64', name=''), Int64Index([16, 17, 26, 36, 56, 66, 70, 87, 89], dtype='int64', name='')])

# %% [markdown]
# Cuidado! O filter, transform... criam uma seleção de todos os dados não um novo grupo... não acho que você vai precisar desse tipo de comandos

# %%
grupos_itens.Type.count()
# Out:
# Type
# Compact    16
# Large      11
# Midsize    22
# Small      21
# Sporty     14
# Van         9
# Name: Type, dtype: int64

# %%
grupos_itens15up = carros2.groupby('Type').filter(lambda x: len(x) > 15)
# grupos_itens15up
grupos_itens15up.groupby('Type').Type.count()
# Out:
# Type
# Compact    16
# Midsize    22
# Small      21
# Name: Type, dtype: int64

# %%
a = carros2.groupby('Type').Type.count() > 15
a[ a ].index
# Out:
# Index(['Compact', 'Midsize', 'Small'], dtype='object', name='Type')

# %%
for chave in pedidos.groupby('Itens').groups.keys():
  print(chave)

# que é o mesmo que,
#
# for chave in grupos_itens.groups.keys():
#  print(chave)
print("--------------------------")
for chave, grupo in pedidos.groupby('Itens'):
  print(chave)
  print(grupo)
# Out:
# Boné
# Camiseta
# Keds
# Tênis Caminhada
# Tênis Corrida
# --------------------------
# Boné
#    Pedido Itens  Preco Unidade  Quantidade
# 5       2  Boné             60           1
# Camiseta
#    Pedido     Itens  Preco Unidade  Quantidade
# 2       1  Camiseta             90           3
# 4       2  Camiseta             90           1
# 8       3  Camiseta             90           1
# Keds
#    Pedido Itens  Preco Unidade  Quantidade
# 6       2  Keds            250           3
# Tênis Caminhada
#    Pedido            Itens  Preco Unidade  Quantidade
# 1       1  Tênis Caminhada            250           2
# 3       2  Tênis Caminhada            250           2
# 7       3  Tênis Caminhada            250           2
# Tênis Corrida
#    Pedido          Itens  Preco Unidade  Quantidade
# 0       1  Tênis Corrida            300           1

# %%
pedidos.groupby('Itens').Quantidade.sum() # total de quantidades por item

# que é o mesmo que,
# grupos_itens.Quantidade.sum() # total de quantidades por item
# Out:
# Itens
# Boné               1
# Camiseta           5
# Keds               3
# Tênis Caminhada    6
# Tênis Corrida      1
# Name: Quantidade, dtype: int64

# %% [markdown]
# ### Formato do groupby

# %%
pedidos.groupby('Itens')

# %%
grupos_itens = pedidos.groupby('Itens')
print ( grupos_itens )
print ( grupos_itens.groups )
print ( grupos_itens.groups.keys() )
print ( grupos_itens.groups.values() )
# Out:
# ...
# {'Boné': [5], 'Camiseta': [2, 4, 8], 'Keds': [6], 'Tênis Caminhada': [1, 3, 7], 'Tênis Corrida': [0]}
# dict_keys(['Boné', 'Camiseta', 'Keds', 'Tênis Caminhada', 'Tênis Corrida'])
# dict_values([Int64Index([5], dtype='int64'), Int64Index([2, 4, 8], dtype='int64'), Int64Index([6], dtype='int64'), Int64Index([1, 3, 7], dtype='int64'), Int64Index([0], dtype='int64')])

# %% [markdown]
# ## Transformar um agrupamento em DF

# %%
pedidos.head()
# Out:
#    Pedido            Itens  Preco Unidade  Quantidade
# 0       1    Tênis Corrida            300           1
# 1       1  Tênis Caminhada            250           2
# 2       1         Camiseta             90           3
# 3       2  Tênis Caminhada            250           2
# 4       2         Camiseta             90           1

# %%
df_do_agrupamento = pd.DataFrame( pedidos.groupby('Itens')[['Quantidade','Preco Unidade']].sum() ).reset_index()
df_do_agrupamento.head()
# Out:
#              Itens  Quantidade  Preco Unidade
# 0             Boné           1             60
# 1         Camiseta           5            270
# 2             Keds           3            250
# 3  Tênis Caminhada           6            750
# 4    Tênis Corrida           1            300

# %% [markdown]
# # Strings no DF

# %%
filme.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# ...

# %%
filme.director_name.str.upper()
# Out:
# 0           JAMES CAMERON
# 1          GORE VERBINSKI
# 2              SAM MENDES
# 3       CHRISTOPHER NOLAN
# 4             DOUG WALKER
#               ...
# 4911          SCOTT SMITH
# 4912                  NaN
# 4913     BENJAMIN ROBERDS
# 4914          DANIEL HSIA
# 4915             JON GUNN
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.len()
# Out:
# 0       13.0
# 1       14.0
# 2       10.0
# 3       17.0
# 4       11.0
#         ...
# 4911    11.0
# 4912     NaN
# 4913    16.0
# 4914    11.0
# 4915     8.0
# Name: director_name, Length: 4916, dtype: float64

# %%
texto= "ana|helena|Marcacini"
len(texto.split("|"))
# Out:
# 3

# %%
texto.split("|")
# Out:
# ['ana', 'helena', 'Marcacini']

# %%
filmes.head(1)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
filmes['genres'].str.count("\|")
# Out:
# 0       4
# 1       2
# 2       1
# 3       2
# 4       0
#        ..
# 9713    3
# 9714    2
# 9715    0
# 9716    1
# 9717    0
# Name: genres, Length: 9718, dtype: int64

# %% [markdown]
# ## Linhas com director_name LIKE %Chris%

# %%
filme[ filme.director_name.str.contains('Chris',na=False) ]
# Out:
#       color             director_name  num_critic_for_reviews  duration  \
# 3     Color         Christopher Nolan                   813.0     164.0
# 24    Color               Chris Weitz                   251.0     113.0
# 66    Color         Christopher Nolan                   645.0     152.0
# 96    Color         Christopher Nolan                   712.0     169.0
# 97    Color         Christopher Nolan                   642.0     148.0
# ...     ...                       ...                     ...       ...
# 4576  Color        Christopher Hutson                     8.0      95.0
# 4586  Color  Christopher Scott Cherot                    25.0      84.0
# 4589  Color              Chris Atkins                    21.0     103.0
# 4614  Color              Chris Kentis                   235.0      79.0
# 4791  Color              Chris Marker                    16.0      59.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# ...

# %%
filme.director_name.str.find('Chris')
# Out:
# 0      -1.0
# 1      -1.0
# 2      -1.0
# 3       0.0
# 4      -1.0
#        ...
# 4911   -1.0
# 4912    NaN
# 4913   -1.0
# 4914   -1.0
# 4915   -1.0
# Name: director_name, Length: 4916, dtype: float64

# %%
filme[ filme.director_name.str.find('Chris') >= 0 ]
# Out:
#       color             director_name  num_critic_for_reviews  duration  \
# 3     Color         Christopher Nolan                   813.0     164.0
# 24    Color               Chris Weitz                   251.0     113.0
# 66    Color         Christopher Nolan                   645.0     152.0
# 96    Color         Christopher Nolan                   712.0     169.0
# 97    Color         Christopher Nolan                   642.0     148.0
# ...     ...                       ...                     ...       ...
# 4576  Color        Christopher Hutson                     8.0      95.0
# 4586  Color  Christopher Scott Cherot                    25.0      84.0
# 4589  Color              Chris Atkins                    21.0     103.0
# 4614  Color              Chris Kentis                   235.0      79.0
# 4791  Color              Chris Marker                    16.0      59.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# ...

# %% [markdown]
# ## Split

# %%
filme.director_name.str.split()
# Out:
# 0           [James, Cameron]
# 1          [Gore, Verbinski]
# 2              [Sam, Mendes]
# 3       [Christopher, Nolan]
# 4             [Doug, Walker]
#                 ...
# 4911          [Scott, Smith]
# 4912                     NaN
# 4913     [Benjamin, Roberds]
# 4914          [Daniel, Hsia]
# 4915             [Jon, Gunn]
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.split(expand=True)
# Out:
#                 0          1     2     3
# 0           James    Cameron  None  None
# 1            Gore  Verbinski  None  None
# 2             Sam     Mendes  None  None
# 3     Christopher      Nolan  None  None
# 4            Doug     Walker  None  None
# ...           ...        ...   ...   ...
# 4911        Scott      Smith  None  None
# 4912          NaN        NaN   NaN   NaN
# 4913     Benjamin    Roberds  None  None
# 4914       Daniel       Hsia  None  None
# 4915          Jon       Gunn  None  None
#
# [4916 rows x 4 columns]

# %%
filme.director_name.str.split(expand=True)[0]
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912            NaN
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: 0, Length: 4916, dtype: object

# %%
filme['director_first_name'] = filme.director_name.str.split(expand=True)[0]
filme.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
filmes.head(1)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    decada2  year  decade  decade_com_Map
# 0     1990  1995    1990            1990

# %%
filmes['genres'].str.count("\|")
# Out:
# 0       4
# 1       2
# 2       1
# 3       2
# 4       0
#        ..
# 9713    3
# 9714    2
# 9715    0
# 9716    1
# 9717    0
# Name: genres, Length: 9718, dtype: int64

# %%
filmes["decade_jeito_Feio"] = filmes["year2"].str[:3] + "0"
filmes["decade_jeito_Feio"].value_counts()
# Out:
# 2000    2847
# 1990    2201
# 2010    1927
# 1980    1174
# 1970     494
# 1960     401
# 1950     279
# 1940     198
# 1930     136
# 1920      37
# 1910       7
# 1900       5
# 3000       3
# 2040       3
# 1130       1
# 1490       1
# 1600       1
# 1000       1
# 1770       1
# 1400       1
# Name: decade_jeito_Feio, dtype: int64

# %% [markdown]
# # Apply -- funções personalizadas

# %%
filme.duration / 60
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
def converte_horas(minutos):
  return minutos / 60

# %%
filme.duration.apply(converte_horas)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
filme.duration.apply(lambda x: x/60)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
display('{:.2f}'.format(8.321061e+06))
print("__________________")
display(seguro.groupby('sex').charges.sum())
print("__________________")
display(seguro.groupby('sex').charges.sum().apply(lambda x: '{:.2f}'.format(x)))
# Out:
# '8321061.00'
# __________________
# sex
# female    8.321061e+06
# male      9.434764e+06
# Name: charges, dtype: float64
# __________________
# sex
# female    8321061.19
# male      9434763.80
# Name: charges, dtype: object

# %%
def pega_ano(lista):
  try:
    return lista[-1]
  except:
    return None

# %%
def pega_ano2(string):
  anos = set(["2016","2017","2018"])
  try:
    if string[-5:-1] in anos:
      return string[-5:-1]
  except:
    return None

# %%
filmes.title.apply(pega_ano2)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 9713    2017
# 9714    2017
# 9715    2017
# 9716    2018
# 9717    None
# Name: title, Length: 9718, dtype: object

# %%
filmes.title.apply(pega_ano2).count() #Qual a soma total dos títulos de 2016, 2017 e 2018?
# Out:
# 406

# %%
filmes.title.str.split().apply(pega_ano)
# Out:
# 0       (1995)
# 1       (1995)
# 2       (1995)
# 3       (1995)
# 4       (1995)
#          ...
# 9713    (2017)
# 9714    (2017)
# 9715    (2017)
# 9716    (2018)
# 9717    (1991)
# Name: title, Length: 9718, dtype: object

# %%
def decada(string):
  try:
    ano = int( string[-5:-1])
    divisaoInteira = ano//10
    return divisaoInteira*10
  except:
    return None

# %%
filmes["decada2"] = filmes.title.apply(decada)
filmes.groupby("decada2").count()
# Out:
#          movieId  title  genres
# decada2
# 1900           3      3       3
# 1910           7      7       7
# 1920          37     37      37
# 1930         136    136     136
# 1940         197    197     197
# 1950         279    279     279
# 1960         401    401     401
# 1970         499    499     499
# 1980        1177   1177    1177
# 1990        2209   2209    2209
# 2000        2846   2846    2846
# 2010        1927   1927    1927

# %% [markdown]
# ### Apply over row

# %%
filme.apply(lambda x: x.duration/60,axis=1)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Length: 4916, dtype: float64

# %%
def score_director(num_critic_for_reviews,director_facebook_likes):

  if director_facebook_likes > 0:
    return num_critic_for_reviews * director_facebook_likes
  else:
    return num_critic_for_reviews

# %%
filme.apply(lambda row: score_director(row.num_critic_for_reviews,row.director_facebook_likes), axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %%
def score_director(row):

  if row.director_facebook_likes > 0:
    return row.num_critic_for_reviews * row.director_facebook_likes
  else:
    return row.num_critic_for_reviews

# %%
filme.apply(lambda row: score_director(row), axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %%
filme.apply(score_director,axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %% [markdown]
# ##### gerar coluna do primeiro nome com apply

# %%
filme.director_name.str.split()
# Out:
# 0           [James, Cameron]
# 1          [Gore, Verbinski]
# 2              [Sam, Mendes]
# 3       [Christopher, Nolan]
# 4             [Doug, Walker]
#                 ...
# 4911          [Scott, Smith]
# 4912                     NaN
# 4913     [Benjamin, Roberds]
# 4914          [Daniel, Hsia]
# 4915             [Jon, Gunn]
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.split().isnull().sum()
# Out:
# 102

# %%
def extrai_primeiro(lista):
  if isinstance(lista,list):
    return lista[0]
  else:
    return None

# %%
def extrai_primeiro(lista):
  try:
    return lista[0]
  except:
    return None

# %%
filme.director_name.str.split().apply(extrai_primeiro)
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912           None
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.split().apply(lambda lista: lista[0] if isinstance(lista, list) else None)
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912           None
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: director_name, Length: 4916, dtype: object

# %% [markdown]
# # Expressão Regular

# %%
inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") # Selecionar somente os registros com date no formato 9999-99-99
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Date, Length: 500, dtype: bool

# %%
inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$").unique()
# Out:
# array([ True, False])

# %%
inspecao[(inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") == False)]
# Out:
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %%
inspecao[ inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ] # datas no formato correto
# Out:
#                               Name        Date         Info  \
# 0                E & E Grill House  2017-08-08      Borough
# 1                E & E Grill House  2017-08-08      Cuisine
# 2                E & E Grill House  2017-08-08  Description
# 3                E & E Grill House  2017-08-08        Grade
# 4                E & E Grill House  2017-08-08        Score
# ..                             ...         ...          ...
# 495  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01      Borough
# 496  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01      Cuisine
# 497  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01  Description
# 498  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01        Grade
# 499  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01        Score
#
#                                                  Value
# 0                                            MANHATTAN
# 1                                             American
# 2    Non-food contact surface improperly constructe...
# ...

# %%
inspecao[ ~ inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ] # datas incorretas
# Out:
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %% [markdown]
# _______________________

# %%
year_regex_pattern = '([(])([0-9]{4})([)]$)'

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990
# 1                   Adventure|Children|Fantasy     1990
# 2                               Comedy|Romance     1990
# 3                         Comedy|Drama|Romance     1990
# 4                                       Comedy     1990

# %%
year_regex_pattern = '([(])([0-9]{4})([)]$)'

# %%
filmes['year'] = filmes.title.str.extract(year_regex_pattern)[1]
filmes['year'] = filmes['year'].astype('int')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995

# %%
filmes[filmes.year > 2015 ].groupby('year').year.count().sum() #Qual a soma total dos títulos de 2016, 2017 e 2018?
# Out:
# 406

# %%
regex = r"(\d{4})"

filmes["year2"] = filmes["title"].str.extract(regex)
len(filmes[filmes['year2'].isin(["2016", "2017", "2018"])])
# Out:
# 404

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  decade  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                   Adventure|Children|Fantasy     1990  1995    1990
# 2                               Comedy|Romance     1990  1995    1990
# 3                         Comedy|Drama|Romance     1990  1995    1990
# 4                                       Comedy     1990  1995    1990
#
#    decade_com_Map year2
# 0            1990  1995
# 1            1990  1995
# 2            1990  1995
# 3            1990  1995
# 4            1990  1995

# %% [markdown]
# ____

# %%
filmes['title'].str.match(r"^\d{4}-\d{2}-\d{2}$").unique()
# Out:
# array([False])

# %% [markdown]
# ### Com `import re` e `apply`

# %%
import re

def valida_data(data):
  regex = r"^\d{4}-\d{2}-\d{2}$"
  return re.match(regex, data) is not None

# %%
inspecao['Date'].apply(valida_data)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Date, Length: 500, dtype: bool

# %%
inspecao[ ~ inspecao['Date'].apply(valida_data) ]
# Out:
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %% [markdown]
# ### Validação de datas reais ( não colocar mes 13 por exemplo)

# %%
from datetime import datetime

# %%
datetime.strptime('1999-12-01','%Y-%m-%d')
# Out:
# datetime.datetime(1999, 12, 1, 0, 0)

# %%
# %%script echo skipping error
#
# datetime.strptime('1999-13-01','%Y-%m-%d')
# Out:
# skipping error

# %%
def valida_data(data):
  try:
    datetime.strptime(data,'%Y-%m-%d')
    return True
  except:
    return False

# %%
inspecao[ ~ inspecao['Date'].apply(valida_data) ] # vendo datas erradas
# Out:
#                                        Name        Date         Info  \
# 10                       NY SWEET SPOT CAFE  2023/13/33      Borough
# 11                       NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12                       NY SWEET SPOT CAFE  2023/13/33  Description
# 13                       NY SWEET SPOT CAFE  2023/13/33        Grade
# 14                       NY SWEET SPOT CAFE  2023/13/33        Score
# 22                       BRANDY'S PIANO BAR  2023-13-33  Description
# 23                       BRANDY'S PIANO BAR  2023-13-33        Grade
# 24                       BRANDY'S PIANO BAR  2023-13-33        Score
# 220              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33      Borough
# 221              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33      Cuisine
# 222              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33  Description
# 223              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33        Grade
# 224              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33        Score
# ...

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995

# %%
def decade(year):
 return (year // 10) * 10

filmes['decade'] = filmes.year.apply(decade)
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  decade
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                   Adventure|Children|Fantasy     1990  1995    1990
# 2                               Comedy|Romance     1990  1995    1990
# 3                         Comedy|Drama|Romance     1990  1995    1990
# 4                                       Comedy     1990  1995    1990

# %% [markdown]
# # Map

# %%
filmes['decade_com_Map'] = filmes.year.map(decade)
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  decade  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                   Adventure|Children|Fantasy     1990  1995    1990
# 2                               Comedy|Romance     1990  1995    1990
# 3                         Comedy|Drama|Romance     1990  1995    1990
# 4                                       Comedy     1990  1995    1990
#
#    decade_com_Map
# 0            1990
# 1            1990
# 2            1990
# 3            1990
# 4            1990

# %%
filmes.groupby('decade').decade.count()
# Out:
# decade
# 1900       3
# 1910       7
# 1920      37
# 1930     136
# 1940     197
# 1950     279
# 1960     401
# 1970     499
# 1980    1177
# 1990    2209
# 2000    2846
# 2010    1927
# Name: decade, dtype: int64

# %% [markdown]
# # Combinações de Dados

# %%
# Printar tabelas bonitinhas
class displayN(object):
    # Adaptado de https://jakevdp.github.io/PythonDataScienceHandbook/index.html
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <hr>
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p><hr>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args

    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)

    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
# Escola 1
df = pd.DataFrame({'Nome': ['Adriana', 'Daniel', 'Henrique'],
                   'Curso': ['Graduação','Graduação','Ensino Médio'],
                   'Idade': [34, 25, 17]})

# Escola 2
df2 = pd.DataFrame({'Nome': ['Beatriz', 'Anna'],
                   'Curso': ['Graduação', 'Ensino Médio'],
                   'Idade': [34, 17],
                   'Ingresso': [2018, 2020]})

# Preferências
df3 = pd.DataFrame({'Nome': ['Adriana', 'Daniel', 'Henrique', 'Beatriz', 'Anna'],
                   'Musica': ['Rock', 'MPB', 'HipHop', 'Jazz', 'Jazz']})

displayN('df', 'df2', 'df3')
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# df3
#        Nome  Musica
# 0   Adriana    Rock
# 1    Daniel     MPB
# 2  Henrique  HipHop
# 3   Beatriz    Jazz
# 4      Anna    Jazz

# %% [markdown]
# ## Concatenação

# %% [markdown]
# ### `pd.concat([df1,df2], axis=0)`, concatena linhas

# %%
df4 = df2[['Nome','Curso','Idade']]

displayN('df', 'df4',
        "pd.concat([df,df4])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df4
#       Nome         Curso  Idade
# 0  Beatriz     Graduação     34
# 1     Anna  Ensino Médio     17
#
# pd.concat([df,df4])
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
# 0   Beatriz     Graduação     34
# 1      Anna  Ensino Médio     17

# %% [markdown]
# ### `pd.concat([df1,df2], axis=1)`, concatena colunas

# %%
df5 = df3[['Musica']].head(3)

displayN('df', 'df5',
        "pd.concat([df,df5],axis=1)")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df5
#    Musica
# 0    Rock
# 1     MPB
# 2  HipHop
#
# pd.concat([df,df5],axis=1)
#        Nome         Curso  Idade  Musica
# 0   Adriana     Graduação     34    Rock
# 1    Daniel     Graduação     25     MPB
# 2  Henrique  Ensino Médio     17  HipHop

# %%
displayN('df', 'df2',
        "pd.concat([df,df2])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# pd.concat([df,df2])
#        Nome         Curso  Idade  Ingresso
# 0   Adriana     Graduação     34       NaN
# 1    Daniel     Graduação     25       NaN
# 2  Henrique  Ensino Médio     17       NaN
# 0   Beatriz     Graduação     34    2018.0
# 1      Anna  Ensino Médio     17    2020.0

# %%
displayN('df', 'df2',
        "pd.concat([df,df2]).reset_index(drop=True)")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# pd.concat([df,df2]).reset_index(drop=True)
#        Nome         Curso  Idade  Ingresso
# 0   Adriana     Graduação     34       NaN
# 1    Daniel     Graduação     25       NaN
# 2  Henrique  Ensino Médio     17       NaN
# 3   Beatriz     Graduação     34    2018.0
# 4      Anna  Ensino Médio     17    2020.0

# %%
displayN('df', 'df2',
        "pd.concat([df,df2],axis=1)")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# pd.concat([df,df2],axis=1)
#        Nome         Curso  Idade     Nome         Curso  Idade  Ingresso
# 0   Adriana     Graduação     34  Beatriz     Graduação   34.0    2018.0
# 1    Daniel     Graduação     25     Anna  Ensino Médio   17.0    2020.0
# 2  Henrique  Ensino Médio     17      NaN           NaN    NaN       NaN

# %%
df3 = pd.concat([df,df2],axis=1)
df3['Nome']
# Out:
#        Nome     Nome
# 0   Adriana  Beatriz
# 1    Daniel     Anna
# 2  Henrique      NaN

# %%
print(df3.loc[0][0])
print(df3.loc[0][3])
# Out:
# Adriana
# Beatriz

# %%
df3.columns = ['Nome', 'Curso', 'Idade', 'Nome2', 'Curso2', 'Idade2', 'Ingresso'] # renomeando as colunas
df3
# Out:
#        Nome         Curso  Idade    Nome2        Curso2  Idade2  Ingresso
# 0   Adriana     Graduação     34  Beatriz     Graduação    34.0    2018.0
# 1    Daniel     Graduação     25     Anna  Ensino Médio    17.0    2020.0
# 2  Henrique  Ensino Médio     17      NaN           NaN     NaN       NaN

# %% [markdown]
# ## Junções
#
# Temos 3 tipos de junções:
#
# > * **Inner**, incluímos somente linhas com *match* das chaves nas duas tabelas
# > * **Outter**, incluímos linhas independente do *match* das chaves nas duas tabelas
# >> * **Left**, incluímos linhas com *match* das chaves nas duas tabelas + linhas da tabela à esquerda independente de match
# >> * **Right**, incluímos linhas com *match* das chaves nas duas tabelas + linhas da tabela à direita independente de *match*

# %% [markdown]
# ### `Inner Joins`

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014]})
df3 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
                    'supervisor': ['Carly', 'Guido', 'Steve']})
displayN('df1', 'df2', 'df3')
# Out:
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#
# df2
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
#
# df3
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
df4 = pd.merge(df1, df2)
df4 = pd.merge(df1, df2, left_on='employee', right_on='employee')
df4 = pd.merge(df1, df2, on='employee')
displayN('df4','df2','df1')
# Out:
# df4
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014
#
# df2
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
#
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
displayN('df3', 'df4', 'pd.merge(df3, df4)')
# Out:
# df3
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve
#
# df4
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014
#
# pd.merge(df3, df4)
#          group supervisor employee  hire_date
# 0   Accounting      Carly      Bob       2008
# 1  Engineering      Guido     Jake       2012
# 2  Engineering      Guido     Lisa       2004
# 3           HR      Steve      Sue       2014

# %%
df5 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization']})
displayN('df1', 'df5', "pd.merge(df1, df5)")
# Out:
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#
# df5
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
#
# pd.merge(df1, df5)
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %% [markdown]
# ### Merge

# %%
df6 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'salary': [70000, 80000, 120000, 90000]})
pd.merge(df1, df6, left_on="employee", right_on="name").drop('name', axis=1)
# Out:
#   employee        group  salary
# 0      Bob   Accounting   70000
# 1     Jake  Engineering   80000
# 2     Lisa  Engineering  120000
# 3      Sue           HR   90000

# %%
displayN("filmes","ratings_mean", " pd.merge(filmes,ratings_mean,on='movieId')")
# Out:
# filmes
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9713   193581  Black Butler: Book of the Atlantic (2017)
# 9714   193583               No Game No Life: Zero (2017)
# 9715   193585                               Flint (2017)
# 9716   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9717   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  decada2  year  decade  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                      Adventure|Children|Fantasy     1990  1995    1990
# ...

# %% [markdown]
# ### `Right` `Left` ` Joins`
#
# `Right` e `Left` ` Joins` são empregados quando queremos adicionar à combinação dos dados elementos independentemente de fazerem *match* com as chaves de dados ou não.

# %%
df7 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue', 'Adriana'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR', 'Commercial']})

df8 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR', 'Research'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization', 'Data Science']})

# %%
displayN('df7','df8',
        'pd.merge(df7,df8)')
# Out:
# df7
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4  Adriana   Commercial
#
# df8
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
# 6     Research  Data Science
#
# pd.merge(df7,df8)
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
displayN('df7','df8',
        "pd.merge(df7,df8,how='left')")
# Out:
# df7
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4  Adriana   Commercial
#
# df8
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
# 6     Research  Data Science
#
# pd.merge(df7,df8,how='left')
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization
# 8  Adriana   Commercial           NaN

# %%
displayN('df7','df8',
        "pd.merge(df7,df8,how='right')")
# Out:
# df7
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4  Adriana   Commercial
#
# df8
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
# 6     Research  Data Science
#
# pd.merge(df7,df8,how='right')
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Lisa  Engineering        coding
# 4     Jake  Engineering         linux
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization
# 8      NaN     Research  Data Science

# %%
displayN('df1','df5',
        "pd.merge(df1,df5,how='outer')")
# Out:
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#
# df5
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
#
# pd.merge(df1,df5,how='outer')
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %% [markdown]
# # Reshape dos dados
#
# Vamos concluir falando sobre operações de reshape, ou de alteração da forma dos dados.
#
# Em muitos casos práticos os dados não estarão exatamente no melhor formato para sua análise. Podemos ter dados em colunas quanto queríamos que estivessem em linhas ou vice-versa. Empregamos então transformações para *reshape* dos dados. O `Pandas` fornece duas funções úteis para isso, o `melt` para levar dados de colunas para linhas e `pivot` para trazer dados de linhas para colunas.

# %% [markdown]
# ## Melt, `pd.melt(df, id_vars = , value_vars = )`
# (transforma colunas em linhas )

# %%
displayN('df',
        "pd.melt(df, id_vars =['Nome'], value_vars =['Curso'])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.melt(df, id_vars =['Nome'], value_vars =['Curso'])
#        Nome variable         value
# 0   Adriana    Curso     Graduação
# 1    Daniel    Curso     Graduação
# 2  Henrique    Curso  Ensino Médio

# %%
displayN('df',
        "pd.melt(df, id_vars =['Nome'], value_vars =['Curso','Idade'])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.melt(df, id_vars =['Nome'], value_vars =['Curso','Idade'])
#        Nome variable         value
# 0   Adriana    Curso     Graduação
# 1    Daniel    Curso     Graduação
# 2  Henrique    Curso  Ensino Médio
# 3   Adriana    Idade            34
# 4    Daniel    Idade            25
# 5  Henrique    Idade            17

# %%
displayN('df',
        "pd.melt(df, id_vars =['Nome'], value_vars =['Idade'], var_name ='*Tipo_atributo*', value_name ='*Valor_atributo*')")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.melt(df, id_vars =['Nome'], value_vars =['Idade'], var_name ='*Tipo_atributo*', value_name ='*Valor_atributo*')
#        Nome *Tipo_atributo*  *Valor_atributo*
# 0   Adriana           Idade                34
# 1    Daniel           Idade                25
# 2  Henrique           Idade                17

# %% [markdown]
# # `pd.pivot(df, index= , columns= , values= )`
# Esta função cria para cada valor de uma coluna uma linha com os valores correspondentes,
#
# Faz o inverso do melt
# transforma linhas em colunas

# %%
displayN('df',
        "pd.pivot(df, 'Nome', 'Curso', 'Idade')")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.pivot(df, 'Nome', 'Curso', 'Idade')
# Curso     Ensino Médio  Graduação
# Nome
# Adriana            NaN       34.0
# Daniel             NaN       25.0
# Henrique          17.0        NaN

# %%
df2 = pd.pivot(df, 'Nome', 'Curso', 'Idade')
df3 = pd.pivot(df, 'Nome', 'Curso', 'Idade').reset_index()
df3.columns.name = ''

print(df2.columns)
print(df3.columns)

displayN('df2','df3')
# Out:
# Index(['Ensino Médio', 'Graduação'], dtype='object', name='Curso')
# Index(['Nome', 'Ensino Médio', 'Graduação'], dtype='object', name='')
# df2
# Curso     Ensino Médio  Graduação
# Nome
# Adriana            NaN       34.0
# Daniel             NaN       25.0
# Henrique          17.0        NaN
#
# df3
#        Nome  Ensino Médio  Graduação
# 0   Adriana           NaN       34.0
# 1    Daniel           NaN       25.0
# 2  Henrique          17.0        NaN

# %% [markdown]
# # Comando shift (avança para a linha seguinte)

# %%
df_selected = financas[['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']]
display(df_selected.head())
display(df_selected.shift().head()) # df[i] = df[i-1], avança
# Out:
# Ticker         BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  118.671890   93.603439  425.388514  106376.0
# 2023-01-03  5.360131  117.841293   92.522995  430.622910  104166.0
# 2023-01-04  5.478500  120.795203   97.571673  440.921560  105334.0
# 2023-01-05  5.430100  123.461746  100.192050  444.358927  107518.0
# 2023-01-06  5.349800  123.745045   98.131722  444.722991  108836.0
# Ticker         BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02       NaN         NaN         NaN         NaN       NaN
# 2023-01-03  5.285500  118.671890   93.603439  425.388514  106376.0
# 2023-01-04  5.360131  117.841293   92.522995  430.622910  104166.0
# 2023-01-05  5.478500  120.795203   97.571673  440.921560  105334.0
# 2023-01-06  5.430100  123.461746  100.192050  444.358927  107518.0

# %% [markdown]
# # quantile()

# %%
# IQR = df.charges.quantile(0.75) - df.charges.quantile(0.25)
# IQR

# %%
# inf = df.charges.quantile(0.25) - 1.5 * IQR
# sup = df.charges.quantile(0.75) + 1.5 * IQR
# print(inf, sup)

# %%
# sum(df.charges < inf)

# %%
# sum(df.charges > sup)

# %%
# sum(df.charges < inf) + sum(df.charges > sup)

# %% [markdown]
# # Graficos

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.DataFrame()
df['x-values'] = np.arange(0,10,0.01)
df['y-values'] = np.random.sample(len(df))
df.head()
# Out:
#    x-values  y-values
# 0      0.00  0.285878
# 1      0.01  0.986747
# 2      0.02  0.431801
# 3      0.03  0.574234
# 4      0.04  0.527242

# %%
plt.figure(figsize=(7,4))

plt.plot('x-values', 'y-values', data=df, color='g', linestyle='-')
# plt.plot(df['x-values'], df['y-values'], color='g', linestyle='-')
plt.title('Random Data',fontsize=14)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.show()

# %%
df = sns.load_dataset('fmri')
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df = df.sort_values('timepoint') # Ordene os dados no tempo
df
# Out:
#      subject  timepoint event    region    signal
# 1063      s0          0   cue  parietal -0.006899
# 258       s7          0  stim  parietal  0.004081
# 259       s6          0  stim  parietal -0.023319
# 260       s5          0  stim  parietal -0.051228
# 865       s5          0   cue   frontal -0.027033
# ...      ...        ...   ...       ...       ...
# 713       s8         18   cue   frontal  0.014358
# 712      s10         18   cue   frontal -0.003251
# 710      s11         18   cue   frontal  0.090520
# 722       s9         18   cue   frontal -0.000643
# 531       s7         18  stim   frontal -0.019634
#
# [1064 rows x 5 columns]

# %%
df_s0 = df[(df['subject'] == 's0' ) & (df['event'] == 'stim') & (df['region'] == 'parietal')]
df_s0_cue = df[(df['subject'] == 's0' ) & (df['event'] == 'cue') & (df['region'] == 'parietal')]

plt.figure(figsize=(7,4))

plt.plot(df_s0['timepoint'], df_s0['signal'], color='g', linestyle='-', label='stim')
plt.plot(df_s0_cue['timepoint'], df_s0_cue['signal'], color='r', linestyle='-', label='cue')
plt.legend()

plt.show()

# %%
# Seu código
fig, ax = plt.subplots(2)

df_s1_stim = df[(df['subject'] == 's1' ) & (df['event'] == 'stim') & (df['region'] == 'parietal')]
df_s1_cue = df[(df['subject'] == 's1' ) & (df['event'] == 'cue') & (df['region'] == 'parietal')]
ax[0].plot(df_s0['timepoint'], df_s0['signal'], color='r', label='stim')
ax[0].plot(df_s0_cue['timepoint'], df_s0_cue['signal'], color='b',label='cue')
ax[1].plot(df_s1_stim['timepoint'], df_s1_stim['signal'], color='r', label='stim')
ax[1].plot(df_s1_cue['timepoint'], df_s1_cue['signal'], color='b', label='cue')
ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')

# %%
ax.shape
# Out:
# (2,)

# %%
fig, ax = plt.subplots(2)

df_s1_stim = df[(df['subject'] == 's1' ) & (df['event'] == 'stim') & (df['region'] == 'parietal')]
df_s1_cue = df[(df['subject'] == 's1' ) & (df['event'] == 'cue') & (df['region'] == 'parietal')]
ax[0].plot(df_s0['timepoint'], df_s0['signal'], color='r', label='stim')
ax[0].plot(df_s0_cue['timepoint'], df_s0_cue['signal'], color='b',label='cue')
ax[1].plot(df_s1_stim['timepoint'], df_s1_stim['signal'], color='r', label='stim')
ax[1].plot(df_s1_cue['timepoint'], df_s1_cue['signal'], color='b', label='cue')
ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')

# %%
fig,(ax1,ax2) = plt.subplots(2,2)
df_s1_stim = df[(df['subject'] == 's1' ) & (df['event'] == 'stim') & (df['region'] == 'parietal')]
df_s1_cue = df[(df['subject'] == 's1' ) & (df['event'] == 'cue') & (df['region'] == 'parietal')]
df_s2_stim = df[(df['subject'] == 's2' ) & (df['event'] == 'stim') & (df['region'] == 'parietal')]
df_s2_cue = df[(df['subject'] == 's2' ) & (df['event'] == 'cue') & (df['region'] == 'parietal')]
df_s3_stim = df[(df['subject'] == 's3' ) & (df['event'] == 'stim') & (df['region'] == 'parietal')]
df_s3_cue = df[(df['subject'] == 's3' ) & (df['event'] == 'cue') & (df['region'] == 'parietal')]

ax1[0].plot(df_s0['timepoint'], df_s0['signal'], color='b', label='stim', )
ax1[0].plot(df_s0_cue['timepoint'], df_s0_cue['signal'], color='r',label='cue', linestyle='--')
ax1[1].plot(df_s1_stim['timepoint'], df_s1_stim['signal'], color='b', label='stim')
ax1[1].plot(df_s1_cue['timepoint'], df_s1_cue['signal'], color='r', label='cue', linestyle='--')
ax2[0].plot(df_s2_stim['timepoint'], df_s2_stim['signal'], color='b', label='stim')
ax2[0].plot(df_s2_cue['timepoint'], df_s2_cue['signal'], color='r', label='cue', linestyle='--')
ax2[1].plot(df_s3_stim['timepoint'], df_s3_stim['signal'], color='b', label='stim')
ax2[1].plot(df_s3_cue['timepoint'], df_s3_cue['signal'], color='r', label='cue', linestyle='--')

ax1[0].legend(loc='upper right')
ax1[1].legend(loc='upper right')
ax2[0].legend(loc='upper right')
ax2[1].legend(loc='upper right')

ax1[0].set_title('s0')
ax1[1].set_title('s1')
ax2[0].set_title('s2')
ax2[1].set_title('s3')

fig.tight_layout(pad=3)

# %% [markdown]
# _____

# %%
import matplotlib.pyplot as plt
# Qual ativo rendeu mais no período? Você pode calcular o percentual de aumento ou descréscimo do ativo do início ao fim do período.
plt.plot(financas[['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']] / financas[['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']].max(),
         label=['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP'])

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(tips[ tips.sex == 'Male' ]['tip'], label='Homens')
plt.hist(tips[ tips.sex == 'Female' ]['tip'], label='Mulheres')

plt.xlabel('Valor das Gorjetas')
plt.ylabel('Quantidades Pagas')
plt.title('Distribuição das Gorjetas', fontsize=14, weight='bold')
plt.legend(title='$\\bf{Gorjetas}$')
plt.show()

# %%
# %matplotlib inline

x = np.arange(-10,10,0.01)

plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# A maior parte das funções `plt` pode ser aplicada diretamente como métodos de eixo (por exemplo `plt.plot() → ax.plot()`) mas os comandos para definir limites, rótulos e títulos diferem ligeiramente quando empregados na interface orientada a objeto e adiciona-se o prefixo `set_` aos comandos:
#
# > ``plt.title()`` → ``ax.set_title()``
#
# > ``plt.xlabel()``  → ``ax.set_xlabel()``
#
# > ``plt.ylabel()`` → ``ax.set_ylabel()``
#
# > ``plt.xlim()``  → ``ax.set_xlim()``
#
# > ``plt.ylim()`` → ``ax.set_ylim()``

# %% [markdown]
# _____

# %%
# %matplotlib inline

x = np.arange(-10,10,0.01)

plt.plot(x, np.sin(x), label='sin(x)')
plt.plot(x, np.cos(4*x), label='cos(4x)')

plt.title('Exemplo Sin(x) & Cos(4x)')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,4)) # cria uma figura alterando o tamanho, figsize=(tamanho_horizontal,tamanho_vertical)

plt.suptitle('Script Layer', fontsize=14, weight='bold', y=1.05)

# cria e ativa um gráfico na figura
plt.subplot(1, 2, 1) # (linhas, colunas, gráfico ativo)
plt.plot(x, np.sin(x))
plt.title('Primeiro plot')

# cria e ativa um segundo gráfico na figura
plt.subplot(1, 2, 2) # (linhas, colunas, gráfico ativo)
plt.plot(x, np.cos(4*x));
plt.title('Segundo plot')

plt.tight_layout()
plt.show()

# %%
# Cria uma grade de gráficos com 1 linha e 2 colunas de gráficos, ax é um vetor em que cada elemento corresponde a um gráfico da grade
fig, ax = plt.subplots(1,2,figsize=(12,4)) # cria uma figura alterando o tamanho, figsize=(tamanho_horizontal,tamanho_vertical)

plt.suptitle('Artist Layer', fontsize=14, weight='bold', y=1.05)

# Os comandos podem então ser direcionados para o gráfico específico
ax[0].plot(x, np.sin(x))
ax[0].set_title('Primeiro plot')

ax[1].plot(x, np.cos(4*x));
ax[1].set_title('Segundo plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Propriedades de linha `linestyle`, `marker`, `color`, `linewidth` e `markersize`
#
# Você pode alterar várias das propriedades das linhas dos gráficos como estilo da linha, cor e sua espessura. Isso é importante para diferenciar várias linhas em um mesmo gráfico ou ainda se você quiser dar destaque a uma ou mais linhas.
#
# Essas propriedades podem ser codificadas explicitamente:
#
# ```
# plt.plot(x, np.cos(x), linestyle='dashed', marker='o', color='green', linewidth=1, markersize=6)
# ```
#
# Ou em um formato resumido:
#
# ```
# plt.plot(x, np.cos(x), '--og', linewidth=1, markersize=6)
# ```
#
# A expressão `'--og'` agrupa os parâmetros `--`, `o` e `g` e indica respectivamente os mesmos parâmetros que o modo explícito `linestyle='dashed', marker='o', color='green'`. Mesmo na forma resumida os parâmetros podem aparecer em qualquer ordem, uma vez que os símbolos de cada parâmetro não se repetem. As cores nesse modo ficam entretanto limitadas ao um conjunto de cores básicas `rgbcmyk` (`r`=red, `g`=green, ...).
#
# O esquema de cores é bastante sofisticado e permite empregar de cores básicas à tons de cinza, como também especificar valores de cada componente RGB (esquema de combinação de cores básicas Red, Green, Blue) e transparência das linhas desenhadas (parâmetro `alpha`).
#
# O código a seguir mostra como empregar o uso dos parâmetros explícitos e de forma resumida, e mostra como essas configurações podem ser empregadas para dar destaque a uma ou mais linhas em um gráfico.

# %%
x = np.arange(0, 6, 0.3)

fig = plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.title('Explicit and Short parameters', fontsize=14, weight='bold')
plt.plot(x, np.sin(x), color='springgreen', marker='o', linestyle='dashed', linewidth=2, markersize=6)
plt.plot(x, np.cos(x), color='slateblue', linestyle='dashdot', linewidth=2)

# short color code (rgbcmyk)
plt.plot(x, np.tanh(x), '--r', linewidth=2, markersize=6)
plt.plot(x, 1/np.exp(x)*np.cos(x), '-.sb', linewidth=1, markersize=4)

plt.subplot(1, 2, 2)
plt.title('Enfatizando uma linha', fontsize=14, weight='bold')
plt.plot(x, np.sin(x), linewidth=1, alpha=0.7)
plt.plot(x, np.cos(x), linewidth=1, alpha=0.7)
plt.plot(x, np.tanh(x), linewidth=1, alpha=0.7)
plt.plot(x, 1/np.exp(x)*np.cos(x), '-.ok')

plt.tight_layout()
plt.show()

# %%
x = np.arange(0.0, 1.1, 0.01)

fig = plt.figure(figsize=(12,12))

plt.subplot(3, 2, 1)
plt.title('Lines Styles', fontsize=14, weight='bold') # automatic colors
plt.plot(x, x**1, linestyle='solid', label='solid')
plt.plot(x, x**2, linestyle='dashed', label='dashed')
plt.plot(x, x**3, linestyle='dashdot', label='dashdot')
plt.plot(x, x**4, linestyle='dotted', label='dotted')
plt.legend(title='Lines Styles')

plt.subplot(3, 2, 2)
plt.title('Basic Colors', fontsize=14, weight='bold')
plt.plot(x, x**1, color='r', label='r')
plt.plot(x, x**2, color='g', label='g')
plt.plot(x, x**3, color='b', label='b')
plt.plot(x, x**4, color='c', label='c')
plt.plot(x, x**5, color='m', label='m')
plt.plot(x, x**6, color='y', label='y')
plt.plot(x, x**7, color='k', label='k')
plt.legend(title='Colors')

plt.subplot(3, 2, 3)
plt.title('Gray Colors', fontsize=14, weight='bold')
plt.plot(x, x**1, color='1', label='1')
plt.plot(x, x**2, color='0.75', label='0.75')
plt.plot(x, x**3, color='0.5', label='0.5')
plt.plot(x, x**4, color='0.25', label='0.25')
plt.plot(x, x**5, color='0.1', label='0.1')
plt.legend(title='Gray level')

x = np.arange(0.0, 1.1, 0.1) # para melhor exibição dos dados com markers

plt.subplot(3, 2, 4)
plt.title('Markers', fontsize=14, weight='bold')
plt.plot(x, x**1, marker='o', label='o')
plt.plot(x, x**2, marker='x', label='x')
plt.plot(x, x**3, marker='v', label='v')
plt.plot(x, x**4, marker='>', label='>')
plt.plot(x, x**6, marker='s', label='s')
plt.plot(x, x**7, marker='D', label='D')
plt.legend(title='Markers')

# o parâmetro alpha permite configurar um grau de transparência nas cores de linha
plt.subplot(3, 2, 5)
plt.title('Alpha', fontsize=14, weight='bold')
plt.plot(x, x**1, alpha=0.8, label='0.8')
plt.plot(x, x**2, alpha=0.7, label='0.7')
plt.plot(x, x**3, alpha=0.6, label='0.6')
plt.plot(x, x**4, alpha=0.5, label='0.5')
plt.plot(x, x**5, alpha=0.4, label='0.4')
plt.plot(x, x**6, alpha=0.3, label='0.3')
plt.legend(title='Transparency')

# empregando diferente espessuras de linha
plt.subplot(3, 2, 6)
plt.title('Linewidth', fontsize=14, weight='bold')
plt.plot(x, x**1, color='0.5', linewidth=1.5, label='1.5')
plt.plot(x, x**2, color='0.5', linewidth=2, label='2')
plt.plot(x, x**3, color='0.5', linewidth=3.5, label='3.5')
plt.plot(x, x**4, color='0.5', linewidth=4, label='4')
plt.plot(x, x**5, color='0.5', linewidth=5, label='5')
plt.legend(title='Line width')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Textos: `title`, `labels`, `lengend` e `text`
#
# Textos são um complemento importante de qualquer gráfico. Eles não são opcionais! Sem eles você não tem como saber exatamente ao que se refere cada eixo, sua escala ou sua unidade de medida. O título ainda pode explicitar a mensagem que você deseja passar e anotações podem ajudar a indicar pontos específicos do gráfico que você deseja destacar.
#
# O `Matplotlib`, como outros pacotes de visualização, permite adicionar inúmeras anotações aos  gráficos como títulos, rótulos ou labels para as linhas, nomear os eixos ou até mesmo inserir uma anotação em uma posição específica do gráfico. Isso é muito importante para tornar claras as informações exibidas e comunicar os dados.
#
# $\rightarrow$ *Textos como rótulos dos eixos e outras anotações **não são opcionais**. A menos que conheça o contexto, sem eles você não terá como saber se um gráfico está exibindo a evolução de uma ação na bolsa no último ano ou a mudança de temperatura global na última década!*

# %%
x = np.linspace(-3, 3, 20)

plt.figure()

# Adicionando labels às diferentes linhas do gráfico
plt.plot(x, np.cos(x), label='cos(x)')
plt.plot(x, np.tanh(x), label='tanh(x)')

# Adicionando o Título
plt.title('Meu Título', color='green', fontsize=18, weight='bold', ha='center')

# Nomeando os eixos
plt.xlabel('x value', color='red', fontsize=14)
plt.ylabel('f(x) value', color='blue', fontsize=14)

# Exibindo a legenda
plt.legend(title='Minha Legenda', loc='best', fontsize='x-large')

plt.show()

# %% [markdown]
# Títulos e rótulos aceitam todas as configurações comuns de editores de texto como tamanhos de fonte (`fontsize`), cor (`color`), estilos (como por exemplo `weight='bold'` e `style='italic'`). Para  diferentes tipos de fonte é necessário modificar parâmetros do `Matplotlib` a partir do `plt.rcParams` e você pode querer experimentar por exemplo `plt.rcParams["font.family"] = "fantasy"` ou um outro tipo de fonte. Aqui manteremos o uso da fonte padrão.
#
# Os títulos podem ser alinhados no centro (padrão), à esquerda ou à direita usando o parâmetro `ha` (`horizontalalignment`, e valores `'center','right'` ou `'left'`), e você pode deixar para o `Matplotlib` definir a melhor posição da legenda ou empregar o parâmetro de localização `loc` (`loc='upper right'`, `loc='lower left'`, `loc='center left'` etc.).

# %% [markdown]
# Quando trabalhando com múltiplos gráficos pode ser necessário adicionar também um `suptitle` ao conjunto de gráficos e empregamos isso em um exemplo anterior quando apresentamos o modo `Artist Layer`:
#
# ```
# plt.suptitle('Artist Layer', fontsize=14, weight='bold', y=1.05)
# ```
#
# O parâmetro `y=1.05` coloca o `suptitle` 0.05 acima da figura e evita a sobreposição dos títulos. O comando `plt.tight_layout()`, no mesmo exemplo, ajusta o automaticamente o layout da figura para evitar sobreposições dos gráficos, como dos textos dos eixos de um gráfico com outro. Empregamos bastante esse comando aqui.

# %% [markdown]
# Anotações dentro de um gráfico são essencias quando se quer chamar a atenção do leitor para um determinado ponto do gráfico. Para isso o `Matplotlib` fornece duas funções, o `plt.text()` e o `plt.annotate()`. O primeiro adiciona um texto em uma posição `x, y` e o segundo permite cirar uma seta do texto até um ponto específico do gráfico.
#
# Pontos específicos do gráfico podem ainda ser destacados, ou com o comando `plot()` destacando uma coordenada específica, ou com a adição de linhas verticais (`vlines()`) ou horizontais (`hlines()`), realçando a posição.

# %%
x = np.linspace(-3, 3, 20)

fig = plt.figure(figsize=(12,4))
plt.suptitle('Adicionando Textos e Anotações aos Gráficos', fontsize=14, weight='bold', y=1.05)

plt.subplot(1, 2, 1)
plt.title('Text, plot marker e h-vlines', fontsize=14, weight='bold')
plt.plot(x, np.tanh(x), 'r--', alpha=0.5)
plt.plot(x, np.cos(x), 'r--', alpha=0.5)
plt.ylim([-1.2,1.2])

# Enfatizando um ponto específico do gráfico
plt.plot(0, 1, marker = 'o' , color = 'darkblue', markersize= 10)
plt.plot(0, 0, marker = 'o' , color = 'darkblue', markersize= 10)

# Adicionando anotações
plt.text(0 + 0.2, 0 - 0.2, 'Ponto Médio', style='italic', color='grey')
plt.text(0 + 0.2, 1 + 0.05, 'Ponto de Máximo', style='italic', color='grey')
plt.text(-2.0, 0.2, 'Ascendente', style='italic', color='grey')
plt.text(1, 0.2, 'Descendente', style='italic', color='grey')

# Adicionando linhas verticais e horizontais
plt.vlines(0, -1, 1.1, linestyle='dashed', color='b', linewidth=1) # vlines(posição, início, fim)
plt.hlines(0, -3, 3, linestyle='dashed', color='b', linewidth=1) # hlines(posição, início, fim)

plt.subplot(1, 2, 2)
plt.title('Text e Annotations', fontsize=14, weight='bold')
plt.plot(x, (x + 2) * (x - 1) * (x - 2), 'r--', alpha=0.5)

# Enfatizando vários pontos do gráfico
plt.plot([-2, 1, 2], [0, 0, 0], 'o', color='darkblue', markersize=10)

# Adicionando anotações
plt.text(-2 + 0.2, 0 - 2.4, '(-2,0)', style='italic', color='dimgrey')
plt.text(1 + 0.2, 0 - 2.4, '(1,0)', style='italic', color='dimgrey')
plt.text(2 + 0.2, 0 - 2.4, '(2,0)', style='italic', color='dimgrey')

# Annotate
plt.annotate('Ponto de Máximo Local', 
             xy=(-1, 6),                # ponto do gráfico
             xytext=(0, -15),           # posição do texto
             arrowprops=dict(arrowstyle="->")) 

plt.tight_layout()                    
plt.show()

# %% [markdown]
# Outra forma útil de destaque pode ser preencher as áreas sob o gráfico (gráficos de área). Para isso você pode pode empregar `plt.fill_between(x,y)`, para preencher a área sob um gráfico, ou ainda `plt.fill_between(x,y,linha-média)` para preencher a área entre o gráfico e uma linha média (o padrão para linha média é 0).
#
# Se você conhece distribuições de probabilidade, reconhecerá nos exemplos abaixo os gráficos de densidade de probabilidade (PDF) e probabilidade acumulada (CDF) de uma distribuição normal com média $0$ e desvio padrão $1$. A probabilidade $P(x \le -0.5)$  é dada pela área sob a curva do gráfico de densidade de probabilidade no intervalo de $[0, -0.5]$, ou diretamente pelo gráfico de distribuição de probabilidade acumulada. Você verá mais sobre isso no capítulo de Distribuição.

# %%
x = np.linspace(-3, 3, 20)

fig = plt.figure(figsize=(12,8))
plt.suptitle('fill_between', fontsize=14, weight='bold', y=1.05)

plt.subplot(2, 2, 1)
plt.plot(x, np.cos(x))

# Fill
plt.fill_between(x, np.cos(x), -1, alpha=0.3)

# Adicionando anotações
plt.text(-0.6, -0.2, 'Sob a Curva', color='white', fontsize=12)
plt.ylim([-1.2,1.2])

plt.subplot(2, 2, 2)
plt.plot(x, np.tanh(x))

# Fill
plt.fill_between(x, np.tanh(x), alpha=0.3)

# Adicionando anotações
plt.text(-2.4, -0.5, 'tanh(x) < 0', color='white', fontsize=12)
plt.text(1.2, 0.4, 'tanh(x) < 0', color='white', fontsize=12)
# hline
plt.hlines(0, -3, 3, linestyle='dashed', color='b', linewidth=1)

# apenas para construção dos dados de uma distribuição normal
#-------------------------------------------------------------------------------
from scipy.stats import norm 
pdf = []
cdf = []
for a in np.arange(-4,4,0.05):
  pdf.append(norm.pdf(a))
  cdf.append(norm.cdf(a))  

plt.subplot(2, 2, 3)
plt.title('PDF, $N(\mu=0, \sigma=1)$',fontsize=12)
plt.plot(np.arange(-4,4,0.05),pdf)

# Fill
plt.fill_between(np.arange(-4,4,0.05), pdf, alpha=0.3)    
plt.fill_between(np.arange(-4,-0.5,0.05), pdf[0:len(np.arange(-4,-0.5,0.05)+1)], color='g', alpha=0.6) 

# Adicionando anotações
plt.text(-1.4, 0.06, f'Área = { norm.cdf(-0.5) :.3f}',fontsize=12, color='white')

plt.subplot(2, 2, 4)
plt.title('CDF, $N(\mu=0, \sigma=1)$',fontsize=12)
plt.plot(np.arange(-4,4,0.05),cdf)

# Fill
plt.fill_between(np.arange(-4,4,0.05), cdf, alpha=0.3)    
plt.fill_between(np.arange(-4,-0.5,0.05), cdf[0:len(np.arange(-4,-0.5,0.05)+1)], color='g', alpha=0.6) 

# Adicionando anotações
plt.vlines(-0.5,0,max(cdf)-max(cdf)/2,linewidth=2,linestyle=':',colors='g') 
plt.hlines(norm.cdf(-0.5), -4, 0, linewidth=2,linestyle=':',colors='g')  
plt.plot(-0.5,norm.cdf(-0.5),'go')

plt.text(0.2, norm.cdf(-0.5), f'P(x<-0.5) = { norm.cdf(-0.5) :.3f}',fontsize=12, color='white')



plt.tight_layout()                    
plt.show()

# %% [markdown]
# ## Limite dos eixos e escalas `xlim`, `ylim` e `ticker`
#
# O `Matplotlib` ajusta automaticamente os limites dos valores dos eixos x e y e as escalas empregadas. Muitas vezes esses valores não são os mais adequados e você pode querer alterá-los. O limites dos valores podem ser definidos empregando as funções `xlim` e `ylim`.

# %%
x = np.linspace(-3, 3, 200)

fig = plt.figure(figsize=(12,4))
plt.suptitle('Configurando xlim e ylim', fontsize=14, weight='bold', y=1.05)

plt.subplot(1,2,1)
plt.plot(x, np.cos(x))
plt.plot(x, np.tanh(x))

plt.subplot(1,2,2)
plt.plot(x, np.cos(x))
plt.plot(x, np.tanh(x))
plt.xlim([0,2])
plt.ylim([-3,3])

plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots(1,2,figsize=(12,4))
plt.suptitle('Configurando as escalas dos Eixos', fontsize=14, weight='bold', y=1.05)

# Mais pontos gerados para exibir diferentes réguas de dados nos eixos
x = np.linspace(-2, 2, 10000)

ax[0].set_title('$cos(x_i)$ e $tanh(x_i)$', fontsize=14)
ax[0].plot(x, np.cos(x))
ax[0].plot(x, np.tanh(x))

# Definindo o intervalo dos valores a serem exibidos nos eixos 
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(0.75))
ax[0].yaxis.set_major_locator(ticker.MultipleLocator(0.1))

ax[1].set_title('$cos(x_i)$ e $tanh(x_i)$', fontsize=14)
ax[1].plot(x, np.cos(x))
ax[1].plot(x, np.tanh(x))

# Suprimindo a régua de valores no eixo x
ax[1].xaxis.set_major_locator(ticker.NullLocator())

# Definindo a quantidade de pontos a ser exibida na régua
ax[1].yaxis.set_major_locator(ticker.MaxNLocator(8))

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,4), sharey=True, sharex=True)
plt.suptitle('Compartilhando o Eixos y', fontsize=14, weight='bold', y=1.05)

# Mais pontos gerados para exibir diferentes réguas de dados nos eixos
x = np.linspace(-2, 2, 10000)

ax[0].set_title('$tanh(x_i)$', fontsize=16)
ax[0].plot(x, np.tanh(x))
ax[0].grid()

ax[1].set_title('$\\frac{1}{e^{x_i} cos(x_i)}$', fontsize=18)
ax[1].plot(x, 1/np.exp(x)*np.cos(x))
ax[1].grid()

plt.tight_layout()
plt.show()

# %%
# apenas a produção dos dados
x = np.random.random_sample(100)

plt.figure(figsize=(12,8))                         
plt.suptitle('Diferentes estilos', fontsize=14, weight='bold', y=1.05)

i = 1
for style in ['classic','fivethirtyeight','seaborn-pastel','ggplot']:
  with plt.style.context(style):
    plt.subplot(2, 2, i)  
    plt.plot(x)     
    plt.title(style, fontsize=14, weight='bold')    
    i = i + 1                   

plt.tight_layout()
plt.show()

plt.style.context('default')
plt.show()

# %%
# apenas a produção dos dados
x = np.random.random_sample(100)
np.random.seed(1234)

x = np.arange(0,100,1)
y = np.random.rand(100)*10
z = np.random.rand(100)*3
t = np.random.rand(100)*5

from matplotlib import cm # para cores no scatter plot

plt.figure(figsize=(12,12))                         
plt.suptitle('Outros Gráficos', fontsize=14, weight='bold', y=1.05)

plt.subplot(3, 2, 1)  
plt.plot(x,y)    
plt.title('Plot', fontsize=14, weight='bold') 

plt.subplot(3, 2, 2)  
plt.hist(y, bins=30, color='g', alpha=0.5)     
plt.title('Histograma', fontsize=14, weight='bold')    
             
plt.subplot(3, 2, 3)  
plt.scatter(x,y,c=x,cmap=cm.viridis)    
plt.title('Scatter plot', fontsize=14, weight='bold') 

plt.subplot(3, 2, 4)  
plt.boxplot([y,z,t],labels=['Cyan','Green','Yellow'])    
plt.title('Box plot', fontsize=14, weight='bold')

plt.subplot(3, 2, 5)  
plt.bar(['Cyan','Green','Yellow'],[y.mean(),z.mean(),t.mean()],color=['c','g','y'],alpha=0.5)    
plt.title('Bar plot', fontsize=14, weight='bold')

plt.subplot(3, 2, 6)  
plt.pie([y.mean(),z.mean(),t.mean()],
        colors=['c','g','y'],
        explode=[0, 0.1, 0],
        labels=['Cyan','Green','Yellow'],
        autopct='%1.2f%%')    
plt.title('Pie plot', fontsize=14, weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercício 1 `plt.plot()`, function. (**RESOLVIDO**)
#
# Produza um gráfico de linha da função $tanh(x)$ para $x \in [-10,10]$.
#
# 1. Inclua um título com a função
# 2. Altere a cor e o estilo de linha do gráfico
# 3. Altere o tamanho da figura
# 4. Inclua rótulos para os eixos do gráfico

# %%
def f(x):
  return np.tanh(x)

x = np.arange(-10.0,10.0,0.05)
y = f(x)

# %%
plt.figure(figsize=(7,4))

plt.plot(x, y, color='k', linestyle=':')
# plt.plot(x, y, 'k:')
plt.title('$tanh(x)$',fontsize=14)
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.show()

# %% [markdown]
# ___

# %%
df = pd.DataFrame()
df['x-values'] = np.arange(0,10,0.01)
df['y-values'] = np.random.sample(len(df))
df.head()
# Out:
#    x-values  y-values
# 0      0.00  0.987100
# 1      0.01  0.024266
# 2      0.02  0.972992
# 3      0.03  0.005151
# 4      0.04  0.277782

# %%
plt.figure(figsize=(7,4))

plt.plot('x-values', 'y-values', data=df, color='g', linestyle='-')
# plt.plot(df['x-values'], df['y-values'], color='g', linestyle='-')
plt.title('Random Data',fontsize=14)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.show()

# %%
df = sns.load_dataset('fmri')
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df = df.sort_values('timepoint')

# %%
df_so = df[(df["subject"] == "s0") & (df["region"] == "parietal") & (df["event"] == "stim")]
df_so
# Out:
#     subject  timepoint event    region    signal
# 521      s0          0  stim  parietal -0.039327
# 251      s0          1  stim  parietal -0.035735
# 237      s0          2  stim  parietal  0.009642
# 225      s0          3  stim  parietal  0.086399
# 211      s0          4  stim  parietal  0.154058
# 196      s0          5  stim  parietal  0.175532
# 182      s0          6  stim  parietal  0.143093
# 135      s0          7  stim  parietal  0.074343
# 153      s0          8  stim  parietal  0.005101
# 139      s0          9  stim  parietal -0.035587
# 126      s0         10  stim  parietal -0.047915
# 112      s0         11  stim  parietal -0.051469
# 98       s0         12  stim  parietal -0.052911
# 265      s0         13  stim  parietal -0.055264
# 70       s0         14  stim  parietal -0.052419
# 56       s0         15  stim  parietal -0.053079
# 42       s0         16  stim  parietal -0.057715
# 28       s0         17  stim  parietal -0.071300
# ...

# %%
# Seu código
plt.figure(figsize=(7,4))

# plt.plot(list(df_so["timepoint"]), list(df_so["signal"]), color='k')
plt.plot(df_so["timepoint"], df_so["signal"], color='k')
# plt.plot(x, y, 'k:')
plt.title('$tanh(x)$',fontsize=14)
plt.xlabel('$TEMPO$')
plt.ylabel('SINAL')
plt.show()

# %%
# Seu código
df_so = df[(df["subject"] == "s0") & (df["region"] == "parietal")]

plt.figure(figsize=(7,4))

# plt.plot(list(df_so["timepoint"]), list(df_so["signal"]), color='k')
plt.plot(list(df_so[(df["event"] == "stim")]["timepoint"]), list(df_so[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
plt.plot(df_so[(df["event"] == "cue")]["timepoint"], df_so[(df["event"] == "cue")]["signal"], color='b', label = "cue")
# plt.plot(x, y, 'k:')
plt.title('$tanh(x)$',fontsize=14)
plt.xlabel('$TEMPO$')
plt.ylabel('SINAL')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_91298/1367441375.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(list(df_so[(df["event"] == "stim")]["timepoint"]), list(df_so[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
# /tmp/ipykernel_91298/1367441375.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(df_so[(df["event"] == "cue")]["timepoint"], df_so[(df["event"] == "cue")]["signal"], color='b', label = "cue")

# %%
# Seu código
fig, ax = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')

df_s1 = df[(df["subject"] == "s1") & (df["region"] == "parietal") & (df["event"] == "stim")]

ax[0].plot(list(df_so[(df["event"] == "stim")]["timepoint"]), list(df_so[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
ax[0].plot(list(df_so[(df["event"] == "cue")]["timepoint"]), list(df_so[(df["event"] == "cue")]["signal"]), color='k', label = "cue")

ax[0].legend()

ax[1].plot(list(df_s1[(df["event"] == "stim")]["timepoint"]), list(df_s1[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
ax[1].plot(list(df_s1[(df["event"] == "cue")]["timepoint"]), list(df_s1[(df["event"] == "cue")]["signal"]), color='b', label = "cue")
ax[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_91298/3650981971.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax[0].plot(list(df_so[(df["event"] == "stim")]["timepoint"]), list(df_so[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
# /tmp/ipykernel_91298/3650981971.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax[0].plot(list(df_so[(df["event"] == "cue")]["timepoint"]), list(df_so[(df["event"] == "cue")]["signal"]), color='k', label = "cue")
# /tmp/ipykernel_91298/3650981971.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax[1].plot(list(df_s1[(df["event"] == "stim")]["timepoint"]), list(df_s1[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
# /tmp/ipykernel_91298/3650981971.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
# Seu código
df_so = df[(df["subject"] == "s0") & (df["region"] == "parietal")]

plt.figure(figsize=(7,4))

# plt.plot(list(df_so["timepoint"]), list(df_so["signal"]), color='k')
plt.plot(list(df_so[(df["event"] == "stim")]["timepoint"]), list(df_so[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
plt.plot(df_so[(df["event"] == "cue")]["timepoint"], df_so[(df["event"] == "cue")]["signal"], color='b', label = "cue")
# plt.plot(x, y, 'k:')
plt.title('$tanh(x)$',fontsize=14)
plt.xlabel('$TEMPO$')
plt.ylabel('SINAL')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_91298/1367441375.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(list(df_so[(df["event"] == "stim")]["timepoint"]), list(df_so[(df["event"] == "stim")]["signal"]), color='k', label = "stim")
# /tmp/ipykernel_91298/1367441375.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(df_so[(df["event"] == "cue")]["timepoint"], df_so[(df["event"] == "cue")]["signal"], color='b', label = "cue")

# %% [markdown]
# ## *Notas Importantes*

# %% [markdown]
# * Seleção (`read-only`), empregue
#
# >> `df[ row-selection-criteria ][ columns-selection-list ]`
#
# * Alteração de linhas (`update`) por chave inteira ou rótulo do índice, empregue
#
# >> `df.iloc[ rows-position, column-position ]...`, ou
#
# >> `df.loc[ rows-key, column-key (name) ]...`
#
# * Alteração de linhas (`update`) por seleção de dados, empregue
#
# >> `df.loc[ row-selection-criteria, column-key (name) ]...` (*preferencialmente*), ou
#
# >> `df.iloc[ row-selection-criteria.index, column-position ]...`

# %% [markdown]
# # Exercicios

# %% [markdown]
# ## Ativo que rendeu mais no periodo

# %%
financas.head(1)
# Out:
# Ticker       BRL=X   ITUB4.SA   PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.2855  118.67189  93.603439  425.388514  106376.0

# %%
financas.tail(2)
# Out:
# Ticker       BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-12-28  4.8261  157.300453  179.723967  356.622498  134185.0
# 2023-12-29  4.8502         NaN         NaN         NaN       NaN

# %%
display(df.iloc[0])
display(df.iloc[-2])
# Out:
# subject            s0
# timepoint           0
# event             cue
# region       parietal
# signal      -0.006899
# Name: 1063, dtype: object
# subject            s9
# timepoint          18
# event             cue
# region        frontal
# signal      -0.000643
# Name: 722, dtype: object

# %%
( financas.iloc[-2] - financas.iloc[0] ) / financas.iloc[0]
# Out:
# Ticker
# BRL=X      -0.086917
# ITUB4.SA    0.325507
# PETR4.SA    0.920057
# VALE3.SA   -0.161655
# ^BVSP       0.261422
# dtype: float64

# %% [markdown]
# ## Substituindo nulos. Substitua os valores nulos pelos valores do dia anterior não nulo.

# %%
financas['PETR4.SA'].isnull()
# Out:
# Date
# 2023-01-02    False
# 2023-01-03    False
# 2023-01-04    False
# 2023-01-05    False
# 2023-01-06    False
#               ...
# 2023-12-25     True
# 2023-12-26    False
# 2023-12-27    False
# 2023-12-28    False
# 2023-12-29     True
# Freq: B, Name: PETR4.SA, Length: 260, dtype: bool

# %%
financas[ financas['PETR4.SA'].isnull() ].head()
# Out:
# Ticker         BRL=X  ITUB4.SA  PETR4.SA  VALE3.SA  ^BVSP
# Date
# 2023-02-20  5.165169       NaN       NaN       NaN    NaN
# 2023-02-21  5.166700       NaN       NaN       NaN    NaN
# 2023-04-07  5.058300       NaN       NaN       NaN    NaN
# 2023-04-21  5.047700       NaN       NaN       NaN    NaN
# 2023-05-01  4.986000       NaN       NaN       NaN    NaN

# %%
ix_nulos = financas[ financas['PETR4.SA'].isnull() ].index
ix_nulos
# Out:
# DatetimeIndex(['2023-02-20', '2023-02-21', '2023-04-07', '2023-04-21',
#                '2023-05-01', '2023-06-08', '2023-09-07', '2023-10-12',
#                '2023-11-02', '2023-11-15', '2023-12-25', '2023-12-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
for line in range(0,len(financas)): ## Substituindo nulos pelos valores do dia anterior não nulo.
  for column in range(0,financas.shape[1]):
    if np.isnan( financas.iloc[line, column] ):
      financas.iloc[line, column] = financas.iloc[line-1, column]

# %%
financas.loc[ ix_nulos ]
# Out:
# Ticker         BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-02-20  5.165169  128.649805  106.575359  413.425367  109303.0
# 2023-02-21  5.166700  128.649805  106.575359  413.425367  109303.0
# 2023-04-07  5.058300  114.167450   93.335439  355.401382  100822.0
# 2023-04-21  5.047700  120.710861  104.644358  348.546427  104367.0
# 2023-05-01  4.986000  119.856919  102.649029  331.461351  104432.0
# 2023-06-08  4.922400  125.326571  123.428039  310.328668  115488.0
# 2023-09-07  4.977000  124.911416  160.278294  320.049959  115985.0
# 2023-10-12  5.049600  134.373773  170.779061  322.466292  117051.0
# 2023-11-02  4.953700  130.180707  170.207654  335.510064  115053.0
# 2023-11-15  4.864500  139.243153  170.889971  342.284254  123328.0
# 2023-12-25  4.869844  156.024480  179.357347  356.953518  132753.0
# 2023-12-29  4.850200  157.300453  179.723967  356.622498  134185.0

# %% [markdown]
# ## Um bom indicador empregado no  mercado é a quantidade de subidas e descidas que um ativo apresenta de um dia para outro (up & down) ao longo  de um período. Quais ativos tiveram mais dias de *up*?

# %% [markdown]
# ### Solução 1

# %%
financas = financas.reset_index(drop=True)
financas.head()
# Out:
# Ticker     BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# 0       5.285500  118.671890   93.603439  425.388514  106376.0
# 1       5.360131  117.841293   92.522995  430.622910  104166.0
# 2       5.478500  120.795203   97.571673  440.921560  105334.0
# 3       5.430100  123.461746  100.192050  444.358927  107518.0
# 4       5.349800  123.745045   98.131722  444.722991  108836.0

# %%
financas.columns
# Out:
# Index(['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP'], dtype='object', name='Ticker')

# %%
for column in ['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']:
  financas[column + '_up'] = False

for line in financas.index[1::]: # salta o primeiro
  for column in ['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']: # salta up
    if financas.loc[line,column] > financas.loc[line-1,column]:
      financas.loc[line,column + '_up'] = True

financas.head()
# Out:
# Ticker     BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP  BRL=X_up  \
# 0       5.285500  118.671890   93.603439  425.388514  106376.0     False
# 1       5.360131  117.841293   92.522995  430.622910  104166.0      True
# 2       5.478500  120.795203   97.571673  440.921560  105334.0      True
# 3       5.430100  123.461746  100.192050  444.358927  107518.0     False
# 4       5.349800  123.745045   98.131722  444.722991  108836.0     False
#
# Ticker  ITUB4.SA_up  PETR4.SA_up  VALE3.SA_up  ^BVSP_up
# 0             False        False        False     False
# 1             False        False         True     False
# 2              True         True         True      True
# 3              True         True         True      True
# 4              True        False         True      True

# %%
[x for x in financas.columns if '_up' in x] # vendos as colunas com _up no nome
# Out:
# ['BRL=X_up', 'ITUB4.SA_up', 'PETR4.SA_up', 'VALE3.SA_up', '^BVSP_up']

# %%
financas[[x for x in financas.columns if '_up' in x]].mean()
# Out:
# Ticker
# BRL=X_up       0.453846
# ITUB4.SA_up    0.496154
# PETR4.SA_up    0.519231
# VALE3.SA_up    0.430769
# ^BVSP_up       0.480769
# dtype: float64

# %% [markdown]
# ## Solução 2

# %%
df_selected = financas[['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']]
df_selected_shift = df_selected.shift() # df[i] = df[i-1], avança
( df_selected - df_selected_shift > 0 ).mean()
# Out:
# Ticker
# BRL=X       0.453846
# ITUB4.SA    0.496154
# PETR4.SA    0.519231
# VALE3.SA    0.430769
# ^BVSP       0.480769
# dtype: float64

# %% [markdown]
# ## Qual o percentual de energia nuclear produzido na Europa no ano de 2018?

# %%
df = energia.copy()

# %%
df[df.type == 'Nuclear']['2018'].sum() / df['2018'].sum()
# Out:
# 0.22925252769137672

# %% [markdown]
# ## Qual o percentual de energia nuclear produzido na França no ano de 2018?

# %%
df[ (df.type == 'Nuclear') & (df.country_name == 'France')]['2018'].sum() / df[(df.country_name == 'France')]['2018'].sum()
# Out:
# 0.7010980377654339

# %% [markdown]
# ## Qual o percentual de energias limpas produzida na Europa no ano de 2018? **`[NoGroup | GroupBy]`**
#
# *Energias limpas somente Hidroelétrica, Eólica, Solar e Geotérmica.*

# %%
df[ df.type.isin(['Hydro',
                  'Wind',
                  'Solar',
                  'Geothermal']) ]['2018'].sum() / df['2018'].sum()
# Out:
# 0.3053953330199326

# %%
df[ df.type.isin(['Hydro',
                  'Wind',
                  'Solar',
                  'Geothermal']) ].groupby('type')['2018'].sum().sum() / df['2018'].sum()
# Out:
# 0.30539533301993255

# %% [markdown]
# ## Considerando os anos de 2016, 2017 e 2018, a produção de energias limpas tem aumentado na Europa? Verifique em termos absolutos e percentuais.
#
# Energias limpas somente Hidroelétrica, Eólica, Solar e Geotérmica.

# %%
clean_energy = ['Hydro', 'Wind', 'Solar', 'Geothermal']
years = ['2016','2017','2018']

print('*** Absolute values ***')
display( df[ df.type.isin(clean_energy) ][years].sum() )
print()
print('*** Percentual values ***')
display( df[ df.type.isin(clean_energy) ][years].sum() / df[years].sum() )
# Out:
# *** Absolute values ***
# 2016    1072303.537
# 2017    1077515.942
# 2018    1156738.155
# dtype: float64
# *** Percentual values ***
# 2016    0.283388
# 2017    0.281951
# 2018    0.305395
# dtype: float64

# %%
clean_energy = ['Hydro', 'Wind', 'Solar', 'Geothermal']
years = ['2016','2017','2018']

for year in years:
  print(year, '\nTotal: \t\t ', df[ df.type.isin(clean_energy) ][year].sum() )
  print('Percentual: \t', f'{df[ df.type.isin(clean_energy) ][year].sum() / df[year].sum():.4f}')
  print()
# Out:
# 2016
# Total: 		  1072303.537
# Percentual: 	 0.2834
#
# 2017
# Total: 		  1077515.942
# Percentual: 	 0.2820
#
# 2018
# Total: 		  1156738.155
# Percentual: 	 0.3054

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
for year in years:
  plt.bar(year, df[ df.type.isin(clean_energy) ][year].sum(), color='orange', alpha=0.6)

plt.ylim([10**6,1.2*10**6])
plt.title('Valores Absolutos')

plt.subplot(1,2,2)
for year in years:
  plt.bar(year, df[ df.type.isin(clean_energy) ][year].sum() / df[year].sum(), color='blue', alpha=0.6)

plt.ylim([0.25,0.32])
plt.title('Valores Percentuais')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Crie um `new_rating` em que para cada gênero adicional (maior que 1) é subtraído 0.1 do rating original.
#
# 1. Aplique funções `apply` e `str` para obter o número de genêros e fazer o cálculo

# %%
df =  pd.merge(filmes,ratings_mean,on='movieId')
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9695   193581  Black Butler: Book of the Atlantic (2017)
# 9696   193583               No Game No Life: Zero (2017)
# 9697   193585                               Flint (2017)
# 9698   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9699   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  decada2  year  decade  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                      Adventure|Children|Fantasy     1990  1995    1990
# ...

# %%
df['new_rating'] = df.rating - 0.1*( df.genres.str.split('|').apply(lambda x: len(x)) - 1 )
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  decade  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                   Adventure|Children|Fantasy     1990  1995    1990
# 2                               Comedy|Romance     1990  1995    1990
# 3                         Comedy|Drama|Romance     1990  1995    1990
# 4                                       Comedy     1990  1995    1990
#
#    decade_com_Map    rating  new_rating
# 0            1990  3.920930    3.520930
# 1            1990  3.431818    3.231818
# 2            1990  3.259615    3.159615
# 3            1990  2.357143    2.157143
# 4            1990  3.071429    3.071429

# %%
df.new_rating.sum()
# Out:
# 30411.847024261806

# %%
df["rating_novo"]=df["rating"] -df['genres'].str.count("\|")*0.1
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9695   193581  Black Butler: Book of the Atlantic (2017)
# 9696   193583               No Game No Life: Zero (2017)
# 9697   193585                               Flint (2017)
# 9698   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9699   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  decada2  year  decade  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                      Adventure|Children|Fantasy     1990  1995    1990
# ...

# %% [markdown]
# # CASE

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/yahoo_finance_2019_2023.csv')
df.head()
# Out:
#          Date   BRL=X      BTC-USD   ITUB4.SA  PETR4.SA    ^BVSP
# 0  2019-01-01  3.8800  3843.520020        NaN       NaN      NaN
# 1  2019-01-02  3.8799  3943.409424  29.194490  9.149798  91012.0
# 2  2019-01-03  3.7863  3836.741211  29.675810  9.374168  91564.0
# 3  2019-01-04  3.7551  3857.717529  29.178703  9.400789  91841.0
# 4  2019-01-05     NaN  3845.194580        NaN       NaN      NaN

# %%
df_melt = df.melt(id_vars='Date', value_vars=['BRL=X', 'ITUB4.SA', 'PETR4.SA', '^BVSP', 'BTC-USD'], var_name='Ticket', value_name='Adj Close' )
df_melt.head()
# Out:
#          Date Ticket  Adj Close
# 0  2019-01-01  BRL=X     3.8800
# 1  2019-01-02  BRL=X     3.8799
# 2  2019-01-03  BRL=X     3.7863
# 3  2019-01-04  BRL=X     3.7551
# 4  2019-01-05  BRL=X        NaN

# %%
df_melt.tail()
# Out:
#             Date   Ticket     Adj Close
# 7595  2023-02-24  BTC-USD  23198.126953
# 7596  2023-02-25  BTC-USD  23175.375000
# 7597  2023-02-26  BTC-USD  23561.212891
# 7598  2023-02-27  BTC-USD  23522.871094
# 7599  2023-02-28  BTC-USD  23147.353516

# %%
df_melt.groupby("Ticket").count()
# Out:
#           Date  Adj Close
# Ticket
# BRL=X     1520       1085
# BTC-USD   1520       1520
# ITUB4.SA  1520       1033
# PETR4.SA  1520       1033
# ^BVSP     1520       1033

# %%
from datetime import datetime

df_melt['day_of_week'] = pd.to_datetime(df_melt.Date).dt.day_name()
df_melt.head()
# Out:
#          Date Ticket  Adj Close day_of_week
# 0  2019-01-01  BRL=X     3.8800     Tuesday
# 1  2019-01-02  BRL=X     3.8799   Wednesday
# 2  2019-01-03  BRL=X     3.7863    Thursday
# 3  2019-01-04  BRL=X     3.7551      Friday
# 4  2019-01-05  BRL=X        NaN    Saturday

# %%
df_melt[ (df_melt.day_of_week == 'Friday') & (df_melt.Ticket == 'BRL=X') ].nsmallest(5,'Adj Close')
# Out:
#            Date Ticket  Adj Close day_of_week
# 31   2019-02-01  BRL=X     3.6428      Friday
# 10   2019-01-11  BRL=X     3.7079      Friday
# 38   2019-02-08  BRL=X     3.7149      Friday
# 199  2019-07-19  BRL=X     3.7174      Friday
# 45   2019-02-15  BRL=X     3.7220      Friday

# %%
df_Friday = df_melt[ df_melt.day_of_week == 'Friday' ]
df_Friday = df_Friday.pivot(index='Date', columns='Ticket', values='Adj Close')
df_Friday.head()
# Out:
# Ticket       BRL=X      BTC-USD   ITUB4.SA  PETR4.SA    ^BVSP
# Date
# 2019-01-04  3.7551  3857.717529  29.178703  9.400789  91841.0
# 2019-01-11  3.7079  3687.365479  29.667917  9.503470  93658.0
# 2019-01-18  3.7489  3657.839355  29.715265  9.659387  96097.0
# 2019-01-25  3.7698  3599.765869        NaN       NaN      NaN
# 2019-02-01  3.6428  3487.945312  30.634508  9.811504  97861.0

# %%
df_Friday.iloc[-4::] # Qual a média da cotação do dólar nas últimas 4 sextas-feiras da base?
# Out:
# Ticket       BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP
# Date
# 2023-02-03  5.0492  23449.322266  23.057737  19.154360  108490.0
# 2023-02-10  5.2895  21651.183594  23.681910  20.645603  108150.0
# 2023-02-17  5.2168  24565.601562  24.673246  20.429256  109303.0
# 2023-02-24  5.1362  23198.126953  23.562584  20.012018  105873.0

# %%
df_Friday.iloc[-4::]['BRL=X'].mean()
# Out:
# 5.172925114631653

# %% [markdown]
# https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2024/blob/main/IMT_ex_combine_reshape_join_solucao.ipynb
