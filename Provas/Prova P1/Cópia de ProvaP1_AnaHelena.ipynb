# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="ITM">
# </head>
#
# <img src="https://maua.br/images/selo-60-anos-maua.svg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # **P1S1 2024S1 ECM514 LAB - Ciência de Dados**
#
# Nesta avaliação você terá a oportunidade de empregar o que aprendeu atá aqui para fazer diversas análises interessantes sobre dados como **posts de notícias (CNN), preços do Airbnb, emissões (CO2) no mundo e renda e desigualdade no Brasil** (os cases variam para cada prova).
#
# Antes de iniciar cada case, explore e entenda os dados empregados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

path = 'https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/'

# %% [markdown]
# # **Case 5**: World Inequality $\times$ Gapminder
#
# Neste case analise as relações entre emissões de CO2, escolaridade e nível de concentração de renda no Brasil a partir das 3 bases abaixo.

# %% [markdown]
# <img src="https://wid.world/wp-content/uploads/2022/01/BannerHome-WIR-en.png" width=400>

# %%
school = pd.read_csv(path + 'gapminder_school_men_15_to_24_years.csv')
school_BR = school[ school.country == 'Brazil']
school_BR.head()
# Out:
#    country  1970  1971  1972  1973  1974  1975  1976  1977  1978  ...  2006  \
# 23  Brazil   3.4  3.47  3.55  3.64  3.72   3.8  3.89  3.97  4.06  ...  7.04
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015
# 23  7.17  7.29  7.42  7.55  7.68  7.81  7.94  8.08  8.21
#
# [1 rows x 47 columns]

# %%
co2 = pd.read_csv(path + 'gapminder_co2_emissions_tonnes_per_person.csv')
co2_BR = co2[ co2.country == 'Brazil']
co2_BR.head()
# Out:
#    country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  2009  \
# 23  Brazil   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.86
#
#     2010  2011  2012  2013  2014  2015  2016  2017  2018
# 23   2.1  2.18  2.31  2.46  2.59  2.42   2.2  2.23  2.18
#
# [1 rows x 220 columns]

# %%
wid = pd.read_csv(path + 'WID_Data_13092021-135730.csv')
wid.head()
# Out:
#   country                                    ind_description ind_code  year  \
# 0  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2000
# 1  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2001
# 2  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2002
# 3  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2003
# 4  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2004
#
#         value
# 0  16488.0559
# 1  16323.1697
# 2  16416.2538
# 3  16204.9913
# 4  16740.7222

# %% [markdown]
# # Q51. Junção de dados
#
# Faça uma 'junção natural' (apenas instâncias associadas em ambas as relações)  dos dados de escolaridade e emissões de CO2 construindo um `dataframe` `school_co2_BR` como abaixo. **Qual o número de linhas e valor da soma de emissões obtido nesse novo `dataframe`?**
#
# <br>
#
# Dicas:
# 1. Pode ser útil empregar `melt()` e `merge()`.
# 2. Renomeie as colunas quando necessário.

# %%
school_BR.head()
# Out:
#    country  1970  1971  1972  1973  1974  1975  1976  1977  1978  ...  2006  \
# 23  Brazil   3.4  3.47  3.55  3.64  3.72   3.8  3.89  3.97  4.06  ...  7.04
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015
# 23  7.17  7.29  7.42  7.55  7.68  7.81  7.94  8.08  8.21
#
# [1 rows x 47 columns]

# %%
# pd.melt(school_BR, id_vars =['country'], var_name ='country', value_name ='Valor_atributo')

# %%
melt_df1 = pd.melt(school_BR, id_vars =['country'],value_name ='school_years', var_name ='year')
melt_df1.head(3)
# Out:
#   country  year  school_years
# 0  Brazil  1970          3.40
# 1  Brazil  1971          3.47
# 2  Brazil  1972          3.55

# %%
melt_df2 = pd.melt(co2_BR, id_vars =['country'],value_name ='c02', var_name ='year')
melt_df2.tail(3)
# Out:
#     country  year   c02
# 216  Brazil  2016  2.20
# 217  Brazil  2017  2.23
# 218  Brazil  2018  2.18

# %%
# seu código

df4 = pd.merge(melt_df1, melt_df2, left_on='year', right_on='year')
df4.head()
# Out:
#   country_x  year  school_years country_y    c02
# 0    Brazil  1970          3.40    Brazil  0.984
# 1    Brazil  1971          3.47    Brazil  1.050
# 2    Brazil  1972          3.55    Brazil  1.140
# 3    Brazil  1973          3.64    Brazil  1.290
# 4    Brazil  1974          3.72    Brazil  1.370

# %%
df4.shape
# Out:
# (46, 5)

# %%
df4.c02.sum()
# Out:
# 75.644

# %% [markdown]
# # Q52. Quanto o nível de escolaridade e de emissões caminham juntos no Brasil?
#
# No `dataframe` obtido na questão anterior, empregue o comando `corr()` para obter a correlação entre os valores de anos de escolaridade e emissões. **Qual a correlação entre os valores de anos de escolaridade e emissões ao longo do período?**.
#
# <br>
#
# Dicas:
# 1. `corr()` retorna uma matriz diagonal. A correlação entre duas variáveis é o valor de intersecção da linha e coluna correspondente às duas variáveis respectivamente.
# 2. É equivalente ao coeficiente de `pearson` e valores acima de $0.9$ correspondem a uma alta correlação entre as variáveis.

# %%
df4.c02.head()
# Out:
# 0    0.984
# 1    1.050
# 2    1.140
# 3    1.290
# 4    1.370
# Name: c02, dtype: float64

# %%
df4.school_years.head()
# Out:
# 0    3.40
# 1    3.47
# 2    3.55
# 3    3.64
# 4    3.72
# Name: school_years, dtype: float64

# %%
# seu código
df4[["school_years","c02"]].corr()
# Out:
#               school_years       c02
# school_years      1.000000  0.916627
# c02               0.916627  1.000000

# %% [markdown]
# # Q53. Normalização de dados
#
# No `dataframe` da questão anterior normalize os dados de anos de escolaridade e emissões aplicando a normalização padrão (`standard`). **Qual a média e desvio padrão obtida dos valores normalizados?**.
#
# <br>
#
# Nota:
# 1. Normalização padrão (`standard`):
#
# $$ x_{std} = \frac{x - \bar{x}}{\sigma(x)}$$
#
# > onde $\bar{x}$ é o valor médio dos valores e $\sigma(x)$ o desvio padrão.
#
# Dica:
# 2. Você pode atribuir os valores diretamente ou criar uma função para isso, empregando ou não o `apply()`.

# %%
# seu código

df4[["school_years","c02"]]
# Out:
#     school_years    c02
# 0           3.40  0.984
# 1           3.47  1.050
# 2           3.55  1.140
# 3           3.64  1.290
# 4           3.72  1.370
# 5           3.80  1.400
# 6           3.89  1.410
# 7           3.97  1.440
# 8           4.06  1.530
# 9           4.15  1.590
# 10          4.24  1.540
# 11          4.33  1.380
# 12          4.42  1.350
# 13          4.52  1.280
# 14          4.61  1.270
# 15          4.71  1.330
# 16          4.81  1.430
# 17          4.91  1.460
# 18          5.01  1.450
# 19          5.11  1.450
# 20          5.21  1.390
# 21          5.32  1.430
# 22          5.42  1.420
# 23          5.53  1.460
# 24          5.64  1.500
# 25          5.75  1.580
# 26          5.86  1.710
# 27          5.97  1.780
# 28          6.08  1.820
# 29          6.20  1.840
# 30          6.32  1.860
# 31          6.43  1.880
# 32          6.55  1.830
# 33          6.67  1.750
# 34          6.79  1.810
# 35          6.92  1.840
# 36          7.04  1.820
# ...

# %%
df4["school_years_norm"] = (df4["school_years"] - df4["school_years"].mean())/df4["school_years"].std()
df4.head()
# Out:
#   country_x  year  school_years country_y    c02  school_years_norm
# 0    Brazil  1970          3.40    Brazil  0.984          -1.520679
# 1    Brazil  1971          3.47    Brazil  1.050          -1.472088
# 2    Brazil  1972          3.55    Brazil  1.140          -1.416554
# 3    Brazil  1973          3.64    Brazil  1.290          -1.354079
# 4    Brazil  1974          3.72    Brazil  1.370          -1.298546

# %%
df4.describe()
# Out:
#        school_years        c02  school_years_norm
# count     46.000000  46.000000       4.600000e+01
# mean       5.590652   1.644435       1.448117e-17
# std        1.440575   0.364571       1.000000e+00
# min        3.400000   0.984000      -1.520679e+00
# 25%        4.352500   1.402500      -8.594850e-01
# 50%        5.475000   1.535000      -8.028198e-02
# 75%        6.760000   1.840000       8.117232e-01
# max        8.210000   2.590000       1.818266e+00

# %%
df4.school_years_norm.mean()
# Out:
# 1.4481169886415085e-17

# %%
df4.school_years_norm.std()
# Out:
# 1.0

# %%
df4["c02_norm"] = (df4["c02"] - df4["c02"].mean())/df4["c02"].std()
df4.head()
# Out:
#   country_x  year  school_years country_y    c02  school_years_norm  c02_norm
# 0    Brazil  1970          3.40    Brazil  0.984          -1.520679 -1.811541
# 1    Brazil  1971          3.47    Brazil  1.050          -1.472088 -1.630506
# 2    Brazil  1972          3.55    Brazil  1.140          -1.416554 -1.383640
# 3    Brazil  1973          3.64    Brazil  1.290          -1.354079 -0.972198
# 4    Brazil  1974          3.72    Brazil  1.370          -1.298546 -0.752761

# %%
df4.c02_norm.mean()
# Out:
# -3.765104170467922e-16

# %%
df4.c02_norm.std()
# Out:
# 1.0

# %% [markdown]
# # Q54. Quanto o nível de escolaridade, emissões e concentração de renda (percentual do PIB dos 90% mais pobres) caminham juntos no Brasil?
#
# Faça agora uma nova 'junção natural' dos dados anteriores (apenas instâncias associadas em ambas as relações) com os dados de percentual do PIB (indicador `p90p100`) do `dataframe` `wid`. **Quais atributos, dentre escolaridade, emissões e percentual de concentração de renda, apresentam correlação maior no período? Normalize os dados (normalização padrão) e veja se os valores de correlação se mantêm.**
#
# <br>
#
# Dicas:
# 1. Certifique-se que os atributos de *match* do `merge()` são do mesmo tipo em cada `dataframe`. Para isso pode ser necessário fazer uma conversão de tipos como `df.coluna.astype('int64')`.
# 2. Você pode querer empregar a função de normalização da questão anterior.

# %%
# seu código

df4.dtypes
# Out:
# country_x             object
# year                  object
# school_years         float64
# country_y             object
# c02                  float64
# school_years_norm    float64
# c02_norm             float64
# dtype: object

# %%
df4.year = df4.year.astype('int64')
df4.dtypes
# Out:
# country_x             object
# year                   int64
# school_years         float64
# country_y             object
# c02                  float64
# school_years_norm    float64
# c02_norm             float64
# dtype: object

# %%
df4[df4.year.isin([2000])]
# Out:
#    country_x  year  school_years country_y   c02  school_years_norm  c02_norm
# 30    Brazil  2000          6.32    Brazil  1.86            0.50629  0.591285

# %%
wid.head()
# Out:
#   country                                    ind_description ind_code  year  \
# 0  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2000
# 1  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2001
# 2  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2002
# 3  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2003
# 4  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2004
#
#         value
# 0  16488.0559
# 1  16323.1697
# 2  16416.2538
# 3  16204.9913
# 4  16740.7222

# %%
df_final = pd.merge(df4, wid, left_on='year', right_on='year')
df_final
# Out:
#    country_x  year  school_years country_y   c02  school_years_norm  c02_norm  \
# 0     Brazil  2000          6.32    Brazil  1.86           0.506290  0.591285
# 1     Brazil  2000          6.32    Brazil  1.86           0.506290  0.591285
# 2     Brazil  2001          6.43    Brazil  1.88           0.582648  0.646144
# 3     Brazil  2001          6.43    Brazil  1.88           0.582648  0.646144
# 4     Brazil  2002          6.55    Brazil  1.83           0.665948  0.508996
# 5     Brazil  2002          6.55    Brazil  1.83           0.665948  0.508996
# 6     Brazil  2003          6.67    Brazil  1.75           0.749248  0.289560
# 7     Brazil  2003          6.67    Brazil  1.75           0.749248  0.289560
# 8     Brazil  2004          6.79    Brazil  1.81           0.832548  0.454137
# 9     Brazil  2004          6.79    Brazil  1.81           0.832548  0.454137
# 10    Brazil  2005          6.92    Brazil  1.84           0.922790  0.536426
# ...

# %%
wid.dtypes
# Out:
# country             object
# ind_description     object
# ind_code            object
# year                 int64
# value              float64
# dtype: object

# %% [markdown]
# # **Case 2**: Airbnb
#
# Neste case analise dados sobre imóveis alugados pela plataforma Airbnb em NYC no ano de 2019.

# %%
df = pd.read_csv(path + 'AB_NYC_2019.csv')
df.head()
# Out:
#        id                                            name  host_id  \
# 0   20913              Charming 1 bed GR8 WBurg LOCATION!    79402
# 1   25235               Large 2 Bedroom Great for Groups!    87773
# 2   76761  Eveland the Place to Stay & Enjoy a 5-⭐️ 2bdrm   118971
# 3  135465             Garden apartment close to Manhattan   663879
# 4  169002                Modern Space in Charming Pre-war   805344
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0   Christiana            Brooklyn        Williamsburg  40.70984  -73.95775
# 1       Shelly            Brooklyn  Bedford-Stuyvesant  40.68373  -73.92377
# 2       Evelyn            Brooklyn         South Slope  40.66552  -73.99019
# 3  Christopher            Brooklyn         Fort Greene  40.68626  -73.97598
# 4         Alec           Manhattan              Harlem  40.82411  -73.94934
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# # Q21. Proprietários com mais imóveis na plataforma
#
# **Existem proprietários ("hosts") alugando mais de um imóvel na plataforma? Se sim, qual é o proprietário com mais imóveis na base da plataforma e quantos ele possui na plataforma?**
#
# <br>
#
# Dicas:
# 1. Atenção, pode haver nomes *homônimos*.

# %%
df.groupby(["host_id","host_name"])[["name"]].count().sort_values("name")
# Out:
#                         name
# host_id   host_name
# 50448556  Miguel           0
# 68890     Paula            1
# 57783233  Maia             1
# 58884411  Hubert           1
# 59181407  Pierre-Marc      1
# ...                      ...
# 205031545 Red Awning       2
# 19303369  Hiroki           4
# 30283594  Kara             4
# 120762452 Stanley          4
# 219517861 Sonder (NYC)     7
#
# [777 rows x 1 columns]

# %%
df.groupby("host_name")[["host_name"]].count().max()
# Out:
# host_name    7
# dtype: int64

# %%
# df2 = pd.DataFrame( df.groupby("name")[["name"]].count()).reset_index()
df.groupby("host_name")[["name"]].count()
# Out:
#            name
# host_name
# A.B.          1
# Aaron         3
# Abby          1
# Abena         1
# Abigail       1
# ...         ...
# Yvonne        1
# Zhaoyu        1
# Zlatan        1
# 威             1
# 文静            1
#
# [628 rows x 1 columns]

# %%
df.groupby("name")[["name"]].count().nlargest(1,"name")
# Out:
#                                      name
# name
# Parkside Brooklyn Artist Apartment!     2

# %%
df.groupby("name")[["name"]].count().max()
# Out:
# name    2
# dtype: int64

# %%
# seu código
df.nlargest(2,"calculated_host_listings_count")
# Out:
#            id                                             name    host_id  \
# 676  32225188   Sonder | Stock Exchange | Private 1BR + Lounge  219517861
# 677  32237493  Sonder | Stock Exchange | Serene 2BR + Sofa Bed  219517861
#
#         host_name neighbourhood_group       neighbourhood  latitude  \
# 676  Sonder (NYC)           Manhattan  Financial District  40.70644
# 677  Sonder (NYC)           Manhattan  Financial District  40.70650
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# 676  -74.01214  Entire home/apt    231               2                  7
# 677  -74.01171  Entire home/apt    404               2                 15
#
#     last_review  reviews_per_month  calculated_host_listings_count  \
# 676  2019-05-13               1.69                             327
# 677  2019-06-09               3.19                             327
#
#      availability_365
# 676               347
# 677               310

# %% [markdown]
# # Q22. O preço dos imóveis entre anunciantes de vários imóveis (locatários profissionais) e anunciantes com um único imóvel
#
# **Considere o preço médio dos imóveis. Existe diferença do preço médio dos imóveis dos anunciantes com mais de um imóvel e dos anunciantes com um único imóvel na plataforma?**

# %%
pd.DataFrame(df.groupby("host_name")[["name","price"]].agg({ 'name': 'count', 'price': 'mean' })).groupby("name").mean()
# Out:
#            price
# name
# 0     300.000000
# 1     151.093333
# 2     145.120968
# 3     166.649123
# 4     145.500000
# 5     160.800000
# 6     186.166667
# 7     277.500000

# %%
pd.DataFrame(df.groupby("host_name")[["name","price"]].agg({ 'name': 'count', 'price': 'mean' })).groupby("name").mean().apply(lambda x: '{:.2f}'.format(x))

# %% [markdown]
# # Q23. Preços em Manhattan
#
# **Qual a vizinhança (`neighbourhood_group`) de Manhattan com a maior média de preços de aluguel, e qual é esse valor?**
#
# <br>
# Dicas:
# 1. Pode ser útil empregar `sort_values()` ou `nlargest()`.

# %%
# seu código

# %%
df.groupby("neighbourhood_group")[["price"]].mean().sort_values("price")
# Out:
#                           price
# neighbourhood_group
# Bronx                 71.500000
# Staten Island         89.428571
# Queens                92.227848
# Brooklyn             128.087879
# Manhattan            196.157609

# %% [markdown]
# # Q24.  Manhattan $\times$ Brooklyn
#
# **Qual o percentual de imóveis de Manhattan e do Brooklyn com preços estatisticamente discrepantes (*outliers*) com relação ao preço geral (toda a base) dos imóveis?**
#
# <br>
#
# Nota:
# 1. Lembrando, *outliers* são dados fora do intervalo
#
# $$[Q1 - 1.5 \times IQR, Q3 + 1.5 \times IQR]$$
#
# > onde $IQR$ é a distância interquartil.

# %%
# seu código

# %% [markdown]
# # Q25. Maiores variações de preço
#
# **Há alguma vizinhaça (`neighbourhood_group`) que o desvio padrão dos preços é maior que os próprios preços!?!? Se sim, quais são essas vizinhaças?**

# %%
# seu código
df.groupby("neighbourhood_group")[["price"]].agg({ 'price': ['mean',"std"] })#.sort_values("price")
#.agg({ 'name': 'count', 'price': 'mean' }
# Out:
#                           price
#                            mean         std
# neighbourhood_group
# Bronx                 71.500000   32.246583
# Brooklyn             128.087879  135.909080
# Manhattan            196.157609  234.131794
# Queens                92.227848   72.164511
# Staten Island         89.428571   40.236207

# %% [markdown]
# # Q26. Reviews $\times$ Preços, influenciam de que forma?
#
# **Considere os imóveis com as 100 maiores quantidades de "revisões" (`number_of_reviews`) e os imóveis com as 100 menores quantidades de "revisões".  Existe diferença do preço médio dos imóveis entre esses dois grupos? Qual é essa diferença?**
#
# <br>
#
# Dica:
# 1. Atenção: Os imóveis com as 100 maiores (menores) quantidades de reviews não pode ser obtida direta e somente com `nlargest(100)` (`nsmallest(100)`) (por que???). Mesmo assim esses comandos podem ser úteis aqui.
#
# > $[1, 2, 3, 3, 3, 4, 5, 6]$, por exemplo tem `nsmallest(3)` = $[1, 2, 3]$, mas $[1, 2, 3, 3, 3]$ ocorrências com os 3 menores valores!

# %%
# seu código

df.head()
# Out:
#        id                                            name  host_id  \
# 0   20913              Charming 1 bed GR8 WBurg LOCATION!    79402
# 1   25235               Large 2 Bedroom Great for Groups!    87773
# 2   76761  Eveland the Place to Stay & Enjoy a 5-⭐️ 2bdrm   118971
# 3  135465             Garden apartment close to Manhattan   663879
# 4  169002                Modern Space in Charming Pre-war   805344
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0   Christiana            Brooklyn        Williamsburg  40.70984  -73.95775
# 1       Shelly            Brooklyn  Bedford-Stuyvesant  40.68373  -73.92377
# 2       Evelyn            Brooklyn         South Slope  40.66552  -73.99019
# 3  Christopher            Brooklyn         Fort Greene  40.68626  -73.97598
# 4         Alec           Manhattan              Harlem  40.82411  -73.94934
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df[["number_of_reviews"]].nsmallest(100,"number_of_reviews").mean() - df[["number_of_reviews"]].nlargest(100,"number_of_reviews").mean()
# Out:
# number_of_reviews   -116.33
# dtype: float64

# %%
df[["number_of_reviews","price"]].nsmallest(100,"number_of_reviews")["price"].mean() - df[["number_of_reviews","price"]].nlargest(100,"number_of_reviews")["price"].mean()
# Out:
# 37.75999999999999

# %%
df[["number_of_reviews","price"]].nlargest(100,"number_of_reviews")["price"]
# Out:
# 2      169
# 89      59
# 115     99
# 169     70
# 87      72
#       ...
# 121    300
# 6      110
# 418    105
# 593    300
# 291     70
# Name: price, Length: 100, dtype: int64

# %%
df[["number_of_reviews","price"]].nlargest(100,"number_of_reviews")
# Out:
#      number_of_reviews  price
# 2                  398    169
# 89                 350     59
# 115                277     99
# 169                255     70
# 87                 229     72
# ..                 ...    ...
# 121                 62    300
# 6                   61    110
# 418                 61    105
# 593                 61    300
# 291                 60     70
#
# [100 rows x 2 columns]

# %%
df[["number_of_reviews","price"]].nsmallest(100,"number_of_reviews")["price"].mean()
# Out:
# 162.38

# %% [markdown]
# # **Case 4**: World Inequality
#
# Neste case analise a concentração de renda no Brasil.

# %% [markdown]
# <img src="https://wid.world/wp-content/uploads/2022/01/BannerHome-WIR-en.png" width=400>

# %%
wid = pd.read_csv(path + 'WID_Data_13092021-135730.csv')
wid.head()
# Out:
#   country                                    ind_description ind_code  year  \
# 0  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2000
# 1  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2001
# 2  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2002
# 3  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2003
# 4  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2004
#
#         value
# 0  16488.0559
# 1  16323.1697
# 2  16416.2538
# 3  16204.9913
# 4  16740.7222

# %% [markdown]
# Nesta última base há dois tipos de indicadores,

# %%
wid.ind_code.unique()
# Out:
# array(['pall', 'p90p100'], dtype=object)

# %% [markdown]
# * **`pall`** = corresponde ao PIB em USD
# * **`p90p100`** = corresponde ao percentual do PIB que se concentra em 90% da população mais pobre (por exemplo, se a distribuição fosse perfeitamente igualitária 90% da população corresponderia a 90% do PIB, e um percentual maior significa uma melhor distribuição de renda)

# %% [markdown]
# # Q41. A concentração de renda no Brasil aumentou ou diminui com base nos dados do período?
#
# **Compare os valores de `p90p100` do Brasil no ano mais antigo e no ano mais recente da base. A distribuição de renda no Brasil melhorou ao final do período?**

# %%
# seu código

# %% [markdown]
# # Q42. Qual a concentração média do PIB nas classes mais pobres no período?
#
# **Qual o valor médio do PIB atribuído a 90% da população mais pobre considerados todos os anos da base?**
#
# <br>
#
# Dica:
# 1. Entenda que o valor do PIB atribuído a 90% da população mais pobre é um percentual que é fornecido na base para cada ano.
# 2. `groupby()` pode ser um comando útil aqui, mas não é obrigatório.

# %%
# seu código

# %% [markdown]
# # **Case 1**: CNN news
#
# Neste case analise comentários de notícias postados pelo canal CNN.

# %%
df = pd.read_csv(path + 'Cleaned_cnn_comments.csv')
df.head()
# Out:
#                                         comment_text likes  comment_time
# 0  Just like US did not abandon Vietnam, Iraq, Af...    73        7200.0
# 1  Anybody else getting tired of these people spe...   193        7200.0
# 2  "If two fish are fighting in a river an Englis...    45        7200.0
# 3  "Not abandon" is not equal to "Defend/no fly-z...     7        7200.0
# 4  It's time we pray that our world leaders get a...    52        7200.0

# %% [markdown]
# # Q11. Temas mais frenquentes nos posts
#
# **Considere os posts com as palavras `['Biden','Trump','Ukraine','Russia','US']`. Quais aparecem com maior frequência nos posts da CNN?**
#
# <br>
#
# Dicas:
# 1. Considere as palavras como estão. Não é necessário considerar variações das palavras (como maíscula/minúscula).
# 2. No caso de mais de um termo estar presente, considere somente o 1o termo que surgir na ordem que eles se apresentam acima.

# %%
# seu código
df.comment_text.str.find('Biden').sum()
# Out:
# -198

# %%
df.comment_text.str.find('Trump').sum()
# Out:
# 46284

# %%
df.comment_text.str.find('Ukraine').sum()
# Out:
# 33093

# %%
df.comment_text.str.find('Biden').unique()
# Out:
# array([  -1,    0,   46,   55,   38,   76,   16,  590,    4,   62,   93,
#          42,    7,   91,   10,   31,   39,   12,   26,   41,  147,   75,
#          27,  268,   11,  118,   13,   86,   56,   66,   15,   29,   57,
#          70,   48,  270,   45,   32,   17,  493,   49,   90,   14,   18,
#          22,   34,  140,   33,  111,  100,   21,   40,   20,   19,   84,
#          71,   35,   72,   50,   79,   28,  116,  868,   97,   25,  125,
#           8,  666,   77,   36,   44,   81,   51,    6,   61,   37,   60,
#          47,  179,   88,   82,   53,   74,  104,  574,  181,   99,  114,
#         335,    3,  197,   24,  122,   67,   52,  107,   85,   59,   63,
#         180,   87,  149,   64,   54,   80,    5,   65,  108,  128,   30,
#         110,  124,  105, 1358,   78,    1])

# %%
df.head()
# Out:
#                                         comment_text likes  comment_time
# 0  Just like US did not abandon Vietnam, Iraq, Af...    73        7200.0
# 1  Anybody else getting tired of these people spe...   193        7200.0
# 2  "If two fish are fighting in a river an Englis...    45        7200.0
# 3  "Not abandon" is not equal to "Defend/no fly-z...     7        7200.0
# 4  It's time we pray that our world leaders get a...    52        7200.0

# %%
df.iloc(0)

# %%
df[ df.comment_text.str.contains('Biden',na=False) ].count()
# Out:
# comment_text    289
# likes           289
# comment_time    289
# dtype: int64

# %%
df[ df.comment_text.str.contains('Ukraine',na=False) ].count()
# Out:
# comment_text    892
# likes           892
# comment_time    892
# dtype: int64

# %% [markdown]
#  ['Biden','Trump','Ukraine','Russia','US']

# %%
df[ df.comment_text.str.contains('Trump',na=False) ].count()
# Out:
# comment_text    1224
# likes           1224
# comment_time    1224
# dtype: int64

# %%
df[ df.comment_text.str.contains('Trump',na=False) ]
# Out:
#                                             comment_text likes  comment_time
# 35     Gosh, my US friends should be so proud of your...     1        7200.0
# 173    Pretty sure Trump wouldn’t give a fig about Ta...     1        7200.0
# 218    "There has never been, ever before, an adminis...     5        7200.0
# 223    It would be an insult to American justice syst...   546        7200.0
# 244    Kintzinger is one of the best reps we have - t...   129        7200.0
# ...                                                  ...   ...           ...
# 17018                                 European Trumpers.     1         720.0
# 17206  Wouldn't have happened if Trump were still in ...     1         720.0
# 17505  Who started the war blamed other, sound like D...     1         720.0
# 17740  The debt ceiling was raised 3 times under Trum...     6         720.0
# 17796                      Trump 2024 bring him back! 🇺🇸     3         720.0
#
# [1224 rows x 3 columns]

# %%
# df[ df.comment_text.str.contains('Trump',na=False) ]

# %%
df[ df.comment_text.str.contains('US',na=False) ].count()
# Out:
# comment_text    542
# likes           542
# comment_time    542
# dtype: int64

# %%
df[ df.comment_text.str.contains('US',na=False) ]
# Out:
#                                             comment_text likes  comment_time
# 0      Just like US did not abandon Vietnam, Iraq, Af...    73        7200.0
# 7      Nance says the US won't abandon Taiwan, as she...    19        7200.0
# 8                     Also US : "We Selling Weapon soon"    23        7200.0
# 13     Let's congratulate the US on serving the polic...     1        7200.0
# 14     the only reason US will not abandon Taiwan is ...     4        7200.0
# ...                                                  ...   ...           ...
# 17661  It is understandable why zombie movies are mad...     3         720.0
# 17682  ....and just like last time Serbia is now draw...     1         720.0
# 17717           RUSSIA 🇷🇺️  \r\nUkraine loses  zellensky     1         720.0
# 17725  Go Russia go! Take your country back protect y...     5         720.0
# 17788  They have loads of money for Ukraine but not f...     7         720.0
#
# [542 rows x 3 columns]

# %% [markdown]
# # Q12. Mais comentários, mais likes?
#
# **Considere os posts com as palavras `['Biden','Trump','Ukraine','Russia','US']`. Quais apresentam maior quantidade de likes?**
#
# <br>
#
# Dicas:
# 1. Considere as palavras como estão. Não é necessário considerar variações das palavras (como maíscula/minúscula).
# 2. No caso de mais de um termo estar presente, considere somente o 1o termo que surgir na ordem que eles se apresentam acima.
# 3. **Atenção, inspecione os valores de `likes`** e faça as transformações necessárias. `apply()` e `replace()` ('K') podem ser úteis aqui.

# %%
df.comment_text
# Out:
# 0        Just like US did not abandon Vietnam, Iraq, Af...
# 1        Anybody else getting tired of these people spe...
# 2        "If two fish are fighting in a river an Englis...
# 3        "Not abandon" is not equal to "Defend/no fly-z...
# 4        It's time we pray that our world leaders get a...
#                                ...
# 17805    Крагунана бракта дриктоскт кубланкт гизания гр...
# 17806    Yaaaa now they get too spend more of our tax d...
# 17807    Каркустка страктакта барзактория бакраска буст...
# 17808                                 BRING BACK TRUMP2024
# 17809    IL never vote republican if they don't remove ...
# Name: comment_text, Length: 17810, dtype: object

# %%
df[ df.comment_text.str.contains('US ',na=False) ].dtypes
# Out:
# comment_text     object
# likes            object
# comment_time    float64
# dtype: object

# %%
df.likes.unique()
# Out:
# array(['73', '193', '45', '7', '52', '34', '19', '23', '58', '14', '51',
#        '39', '1', '4', '2', '114', '10', '28', '126', '80', '46', '8',
#        '86', '5', '12', '15', '20', '26', '6', '13', '16', '3', '33', '9',
#        '11', '74', '41', '60', '27', '122', '18', '609', '378', '490',
#        '476', '1.3K', '113', '134', '30', '516', '82', '313', '22', '49',
#        '56', '132', '43', '478', '294', '546', '40', '325', '202', '48',
#        '235', '89', '129', '84', '120', '885', '95', '162', '219', '135',
#        '170', '246', '102', '119', '59', '110', '547', '408', '116',
#        '258', '62', '72', '106', '66', '64', '68', '24', '29', '37', '32',
#        '57', '17', '254', '190', '166', '77', '117', '67', '55', '92',
#        '25', '171', '93', '21', '634', '447', '232', '324', '157', '111',
#        '79', '44', '42', '164', '38', '36', '69', '105', '684', '31',
#        '83', '844', '502', '108', '206', '307', '71', '2.7K', '777',
# ...

# %%
# prompt: ValueError: invalid literal for int() with base 10: '1.3000' pq deu esse erro

df.likes = df.likes.str.replace('K', '').astype(float) * 1000

# %%
# prompt: df.likesNumerico = df.likesNumerico.astype('float')
# pq deu errado

df.likes = df.likes.str.replace('K', '').astype(float) * 1000

# %%
# df.likes = df.likes.astype('int64')
df["likesNumerico"] = df.likes.apply(lambda x: x.replace("K","000"))
df
df.likesNumerico = df.likesNumerico.astype(float)

# %%
df
# Out:
#                                             comment_text likes  comment_time  \
# 0      Just like US did not abandon Vietnam, Iraq, Af...    73        7200.0
# 1      Anybody else getting tired of these people spe...   193        7200.0
# 2      "If two fish are fighting in a river an Englis...    45        7200.0
# 3      "Not abandon" is not equal to "Defend/no fly-z...     7        7200.0
# 4      It's time we pray that our world leaders get a...    52        7200.0
# ...                                                  ...   ...           ...
# 17805  Крагунана бракта дриктоскт кубланкт гизания гр...     1         720.0
# 17806  Yaaaa now they get too spend more of our tax d...     1         720.0
# 17807  Каркустка страктакта барзактория бакраска буст...     1         720.0
# 17808                               BRING BACK TRUMP2024     2         720.0
# 17809  IL never vote republican if they don't remove ...     1         720.0
#
#       likesNumerico
# 0                73
# ...

# %%
df.dtypes
# Out:
# comment_text      object
# likes             object
# comment_time     float64
# likesNumerico     object
# dtype: object

# %%
df[ df.comment_text.str.contains('US ',na=False) ]["likesNumerico"].sum()
# Out:
# '731923142112014811223611411311713228115161685002138158022344235741324241321113821611512346411244810484131102619211.700015711211679214121711111.100084141330111148133123521111122341217211111404167161221132311112152941524447105254101381381271334243115234441468153331614074191921101111114113112721624021111129811582311112802406755611153442511111510112434117713720671111111111112111111117'

# %%
df[ df.comment_text.str.contains('US ',na=False) ]["likes"].sum()
# Out:
# 5293800.0

# %%
# seu código

df[ df.comment_text.str.contains('US ',na=False) ]["likes"].sum()
# Out:
# '731923142112014811223611411311713228115161685002138158022344235741324241321113821611512346411244810484131102619211.7K15711211679214121711111.1K84141330111148133123521111122341217211111404167161221132311112152941524447105254101381381271334243115234441468153331614074191921101111114113112721624021111129811582311112802406755611153442511111510112434117713720671111111111112111111117'

# %%
df[ df.comment_text.str.contains('Trump ',na=False) ]["likes"].sum()
# Out:
# '1546246591164111111211842019145811111234116136266111112.7K2132625221957117725161311155182419913276112713384035722382661811321441735618162111212713831219541515313611111211111112610132481513440113017294212693914323482257012093316116725685351221012551112122112153928166610873411119212711861.....3K1.3K7024410271457305721111126214841317225119142471261477596130811211134066514326554341332114342229011112214911311738771361561266302813313202492741311124412111119551732.'

# %%
df[ df.comment_text.str.contains('Trump ',na=False) ][["likes"]].sum()
# Out:
# likes    1546246591164111111211842019145811111234116136...
# dtype: object

# %%
df[ df.comment_text.str.contains('Ukraine ',na=False) ]["likes"].sum()
# Out:
# '...'
