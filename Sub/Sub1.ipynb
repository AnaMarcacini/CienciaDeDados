# %%
import pandas as pd
import numpy as np

# %%
# %%capture
# !pip install yfinance
# google

# %%
# %%capture
# %pip install yfinance
# google

# %% [markdown]
# ## Aquisição dos dados OLD

# %%
Affairs = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv')
Affairs.head()
# Out:
#    rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 0         4        0    male  37.0         10.00       no              3
# 1         5        0  female  27.0          4.00       no              4
# 2        11        0  female  32.0         15.00      yes              1
# 3        16        0    male  57.0         15.00      yes              5
# 4        23        0    male  22.0          0.75       no              2
#
#    education  occupation  rating
# 0         18           7       4
# 1         14           6       4
# 2         12           1       4
# 3         18           6       5
# 4         17           6       3

# %%
carros = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv',index_col='rownames')
carros.index.name = 'Veiculo'
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros2 = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/MASS/Cars93.csv',index_col=0)
carros2.index.name = ''
carros2.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 1        Acura  Integra    Small       12.9   15.9       18.8        25
# 2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 3         Audi       90  Compact       25.9   29.1       32.3        20
# 4         Audi      100  Midsize       30.8   37.7       44.6        19
# 5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
#                                                ...
# 1           31                 NaN      Front  ...          5     177
# 2           25  Driver & Passenger      Front  ...          5     195
# 3           26         Driver only      Front  ...          5     180
# 4           26  Driver & Passenger      Front  ...          6     193
# 5           30         Driver only       Rear  ...          4     186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
#
# 1        102     68           37           26.5          11.0    2705
# 2        115     71           38           30.0          15.0    3560
# 3        102     67           37           28.0          14.0    3375
# 4        106     70           37           31.0          17.0    3405
# 5        109     69           39           27.0          13.0    3640
#
#     Origin           Make
#
# 1  non-USA  Acura Integra
# 2  non-USA   Acura Legend
# 3  non-USA        Audi 90
# 4  non-USA       Audi 100
# 5  non-USA       BMW 535i
#
# [5 rows x 27 columns]

# %%
filme = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/movie.csv')
filme.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
inspecao= pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/restaurant_inspections2.csv')
inspecao.head()
# Out:
#                 Name        Date         Info  \
# 0  E & E Grill House  2017-08-08      Borough
# 1  E & E Grill House  2017-08-08      Cuisine
# 2  E & E Grill House  2017-08-08  Description
# 3  E & E Grill House  2017-08-08        Grade
# 4  E & E Grill House  2017-08-08        Score
#
#                                                Value
# 0                                          MANHATTAN
# 1                                           American
# 2  Non-food contact surface improperly constructe...
# 3                                                  A
# 4                                                9.0

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
seguro = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/insurance.csv')
seguro.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
filmes = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/movies.csv')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_mean = ratings.groupby('movieId').rating.mean().reset_index()
ratings_mean.head()
# Out:
#    movieId    rating
# 0        1  3.920930
# 1        2  3.431818
# 2        3  3.259615
# 3        4  2.357143
# 4        5  3.071429

# %%
energia = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/energy_types.csv')

energia.head()
# Out:
#   country country_name                  type    level     2016     2017  \
# 0      BE      Belgium  Conventional thermal  Level 1  30728.0  31316.0
# 1      BE      Belgium               Nuclear  Level 1  41430.0  40128.5
# 2      BE      Belgium                 Hydro  Level 1   1476.0   1360.9
# 3      BE      Belgium    Pumped hydro power  Level 2   1110.0   1093.2
# 4      BE      Belgium                  Wind  Level 1   5340.0   6387.9
#
#         2018
# 0  30092.635
# 1  26995.628
# 2   1239.248
# 3    983.190
# 4   7177.346

# %% [markdown]
# ### Criando um pd.Series e um pd.DataFrame

# %%
# Séries
student_names = pd.Series(['Adriana', 'Carol', 'Daniel'])
age = pd.Series([18, 19, 19])

# DataFrame
students = pd.DataFrame({ 'Student Name': student_names, 'Age': age })
students
# Out:
#   Student Name  Age
# 0      Adriana   18
# 1        Carol   19
# 2       Daniel   19

# %%
testeGroupby = pd.DataFrame({'data': [1, 2, 3, 4, 5, 6]},
                   index=['A', 'B', 'C', 'A', 'B', 'C'])
testeGroupby.index.name = 'key'
testeGroupby
# Out:
#      data
# key
# A       1
# B       2
# C       3
# A       4
# B       5
# C       6

# %%
pedidos = pd.DataFrame( {'Pedido': pd.Series([ 1, 1, 1, 2, 2, 2, 2, 3, 3]),
                         'Itens': pd.Series([ 'Tênis Corrida', 'Tênis Caminhada', 'Camiseta', 'Tênis Caminhada', 'Camiseta', 'Boné' , 'Keds' ,'Tênis Caminhada', 'Camiseta' ]),
                         'Preco Unidade': pd.Series([ 300, 250, 90, 250, 90, 60, 250, 250, 90]),
                         'Quantidade': pd.Series([ 1, 2, 3, 2, 1, 1, 3, 2, 1]) } )
pedidos
# Out:
#    Pedido            Itens  Preco Unidade  Quantidade
# 0       1    Tênis Corrida            300           1
# 1       1  Tênis Caminhada            250           2
# 2       1         Camiseta             90           3
# 3       2  Tênis Caminhada            250           2
# 4       2         Camiseta             90           1
# 5       2             Boné             60           1
# 6       2             Keds            250           3
# 7       3  Tênis Caminhada            250           2
# 8       3         Camiseta             90           1

# %% [markdown]
# # Aquisição de dados

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
seguro = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/insurance.csv')
seguro.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
Affairs = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv')
Affairs.head()
# Out:
#    rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 0         4        0    male  37.0         10.00       no              3
# 1         5        0  female  27.0          4.00       no              4
# 2        11        0  female  32.0         15.00      yes              1
# 3        16        0    male  57.0         15.00      yes              5
# 4        23        0    male  22.0          0.75       no              2
#
#    education  occupation  rating
# 0         18           7       4
# 1         14           6       4
# 2         12           1       4
# 3         18           6       5
# 4         17           6       3

# %%
carros = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv',index_col='rownames')
carros.index.name = 'Veiculo'
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
import yfinance as yf

financas = yf.download(['^BVSP', 'PETR4.SA', 'ITUB4.SA', 'VALE3.SA', 'BRL=X'],'2023-01-01','2024-01-01')
financas.head()

financasAdjClose = financas['Adj Close']
financasAdjClose
# Out:
# [*********************100%%**********************]  5 of 5 completed
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.238420  16.037287  80.482178  106376.0
# 2023-01-03  5.360131  21.775312  15.631456  80.338135  104166.0
# 2023-01-04  5.478500  21.838877  16.128246  80.482178  105334.0
# 2023-01-05  5.430100  22.519920  16.709003  81.832550  107518.0
# 2023-01-06  5.349800  22.910389  16.611048  83.128906  108836.0
# ...              ...        ...        ...        ...       ...
# 2023-12-25  4.869844        NaN        NaN        NaN       NaN
# 2023-12-26  4.869744  31.979033  33.820606  73.377686  133533.0
# 2023-12-27  4.813500  32.197613  33.847778  74.085999  134194.0
# 2023-12-28  4.826100  32.283138  33.739063  73.894554  134185.0
# 2023-12-29  4.850200        NaN        NaN        NaN       NaN
#
# [260 rows x 5 columns]

# %% [markdown]
# ## Criar DF

# %%
testeGroupby = pd.DataFrame({'data': [1, 2, 3, 4, 5, 6]},
                   index=['A', 'B', 'C', 'A', 'B', 'C'])
testeGroupby.index.name = 'key'
testeGroupby
# Out:
#      data
# key
# A       1
# B       2
# C       3
# A       4
# B       5
# C       6

# %% [markdown]
# # Operações Básicas

# %% [markdown]
# ## Primeiros e ultimos valores

# %%
display(Affairs.head(1)) # primeiros 1 valores
display(Affairs.tail(1)) # ultimos 1 valores
# Out:
#    rownames  affairs gender   age  yearsmarried children  religiousness  \
# 0         4        0   male  37.0          10.0       no              3
#
#    education  occupation  rating
# 0         18           7       4
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 600         14           1       5

# %% [markdown]
# ## Shape

# %%
Affairs.shape # nr de linhas e colunas
# Out:
# (601, 10)

# %%
len(Affairs) # linhas
# Out:
# 601

# %% [markdown]
# ## Describe

# %%
Affairs.describe()
# Out:
#           rownames     affairs         age  yearsmarried  religiousness  \
# count   601.000000  601.000000  601.000000    601.000000     601.000000
# mean   1059.722130    1.455907   32.487521      8.177696       3.116473
# std     914.904611    3.298758    9.288762      5.571303       1.167509
# min       4.000000    0.000000   17.500000      0.125000       1.000000
# 25%     528.000000    0.000000   27.000000      4.000000       2.000000
# 50%    1009.000000    0.000000   32.000000      7.000000       3.000000
# 75%    1453.000000    0.000000   37.000000     15.000000       4.000000
# max    9029.000000   12.000000   57.000000     15.000000       5.000000
#
#         education  occupation      rating
# count  601.000000  601.000000  601.000000
# mean    16.166389    4.194676    3.931780
# std      2.402555    1.819443    1.103179
# min      9.000000    1.000000    1.000000
# 25%     14.000000    3.000000    3.000000
# 50%     16.000000    5.000000    4.000000
# 75%     18.000000    6.000000    5.000000
# max     20.000000    7.000000    5.000000

# %%
Affairs.describe(include='all')
# Out:
#            rownames     affairs  gender         age  yearsmarried children  \
# count    601.000000  601.000000     601  601.000000    601.000000      601
# unique          NaN         NaN       2         NaN           NaN        2
# top             NaN         NaN  female         NaN           NaN      yes
# freq            NaN         NaN     315         NaN           NaN      430
# mean    1059.722130    1.455907     NaN   32.487521      8.177696      NaN
# std      914.904611    3.298758     NaN    9.288762      5.571303      NaN
# min        4.000000    0.000000     NaN   17.500000      0.125000      NaN
# 25%      528.000000    0.000000     NaN   27.000000      4.000000      NaN
# 50%     1009.000000    0.000000     NaN   32.000000      7.000000      NaN
# 75%     1453.000000    0.000000     NaN   37.000000     15.000000      NaN
# max     9029.000000   12.000000     NaN   57.000000     15.000000      NaN
#
#         religiousness   education  occupation      rating
# count      601.000000  601.000000  601.000000  601.000000
# unique            NaN         NaN         NaN         NaN
# top               NaN         NaN         NaN         NaN
# freq              NaN         NaN         NaN         NaN
# mean         3.116473   16.166389    4.194676    3.931780
# std          1.167509    2.402555    1.819443    1.103179
# min          1.000000    9.000000    1.000000    1.000000
# 25%          2.000000   14.000000    3.000000    3.000000
# 50%          3.000000   16.000000    5.000000    4.000000
# 75%          4.000000   18.000000    6.000000    5.000000
# max          5.000000   20.000000    7.000000    5.000000

# %%
Affairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rownames       601 non-null    int64
#  1   affairs        601 non-null    int64
#  2   gender         601 non-null    object
#  3   age            601 non-null    float64
#  4   yearsmarried   601 non-null    float64
#  5   children       601 non-null    object
#  6   religiousness  601 non-null    int64
#  7   education      601 non-null    int64
#  8   occupation     601 non-null    int64
#  9   rating         601 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 47.1+ KB

# %% [markdown]
# ## Tipos de dado de cada coluna

# %%
Affairs.dtypes
# Out:
# rownames           int64
# affairs            int64
# gender            object
# age              float64
# yearsmarried     float64
# children          object
# religiousness      int64
# education          int64
# occupation         int64
# rating             int64
# dtype: object

# %% [markdown]
# ## Ver todas as colunas

# %%
Affairs.columns
# Out:
# Index(['rownames', 'affairs', 'gender', 'age', 'yearsmarried', 'children',
#        'religiousness', 'education', 'occupation', 'rating'],
#       dtype='object')

# %%
Affairs.columns.to_list()
# Out:
# ['rownames',
#  'affairs',
#  'gender',
#  'age',
#  'yearsmarried',
#  'children',
#  'religiousness',
#  'education',
#  'occupation',
#  'rating']

# %%
Affairs.keys()
# Out:
# Index(['rownames', 'affairs', 'gender', 'age', 'yearsmarried', 'children',
#        'religiousness', 'education', 'occupation', 'rating'],
#       dtype='object')

# %%
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros.keys()
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
for column in carros:
  print(column)
# Out:
# mpg
# cyl
# disp
# hp
# drat
# wt
# qsec
# vs
# am
# gear
# carb

# %% [markdown]
# ## Ver Linhas

# %%
carros.index
# Out:
# Index(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D', 'Merc 230',
#        'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL', 'Merc 450SLC',
#        'Cadillac Fleetwood', 'Lincoln Continental', 'Chrysler Imperial',
#        'Fiat 128', 'Honda Civic', 'Toyota Corolla', 'Toyota Corona',
#        'Dodge Challenger', 'AMC Javelin', 'Camaro Z28', 'Pontiac Firebird',
#        'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa', 'Ford Pantera L',
#        'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype='object', name='Veiculo')

# %%
for line in carros.index:
  print(line)
# Out:
# Mazda RX4
# Mazda RX4 Wag
# Datsun 710
# Hornet 4 Drive
# Hornet Sportabout
# Valiant
# Duster 360
# Merc 240D
# Merc 230
# Merc 280
# Merc 280C
# Merc 450SE
# Merc 450SL
# Merc 450SLC
# Cadillac Fleetwood
# Lincoln Continental
# Chrysler Imperial
# Fiat 128
# Honda Civic
# Toyota Corolla
# Toyota Corona
# Dodge Challenger
# AMC Javelin
# Camaro Z28
# Pontiac Firebird
# Fiat X1-9
# Porsche 914-2
# Lotus Europa
# Ford Pantera L
# Ferrari Dino
# Maserati Bora
# Volvo 142E

# %%
display(carros.items())
display("___________________")
for col, data in carros.items():
  print(col, data)
# Out:
# <generator object DataFrame.items at 0x789b4c3ff6a0>
# '___________________'
# mpg Veiculo
# Mazda RX4              21.0
# Mazda RX4 Wag          21.0
# Datsun 710             22.8
# Hornet 4 Drive         21.4
# Hornet Sportabout      18.7
# Valiant                18.1
# Duster 360             14.3
# Merc 240D              24.4
# Merc 230               22.8
# Merc 280               19.2
# Merc 280C              17.8
# Merc 450SE             16.4
# Merc 450SL             17.3
# Merc 450SLC            15.2
# Cadillac Fleetwood     10.4
# Lincoln Continental    10.4
# Chrysler Imperial      14.7
# Fiat 128               32.4
# Honda Civic            30.4
# Toyota Corolla         33.9
# Toyota Corona          21.5
# Dodge Challenger       15.5
# AMC Javelin            15.2
# Camaro Z28             13.3
# Pontiac Firebird       19.2
# Fiat X1-9              27.3
# Porsche 914-2          26.0
# Lotus Europa           30.4
# Ford Pantera L         15.8
# Ferrari Dino           19.7
# Maserati Bora          15.0
# Volvo 142E             21.4
# Name: mpg, dtype: float64
# cyl Veiculo
# Mazda RX4              6
# Mazda RX4 Wag          6
# Datsun 710             4
# Hornet 4 Drive         6
# Hornet Sportabout      8
# Valiant                6
# Duster 360             8
# Merc 240D              4
# Merc 230               4
# Merc 280               6
# Merc 280C              6
# Merc 450SE             8
# Merc 450SL             8
# Merc 450SLC            8
# Cadillac Fleetwood     8
# Lincoln Continental    8
# Chrysler Imperial      8
# Fiat 128               4
# Honda Civic            4
# Toyota Corolla         4
# Toyota Corona          4
# Dodge Challenger       8
# AMC Javelin            8
# Camaro Z28             8
# Pontiac Firebird       8
# Fiat X1-9              4
# Porsche 914-2          4
# Lotus Europa           4
# Ford Pantera L         8
# Ferrari Dino           6
# Maserati Bora          8
# Volvo 142E             4
# Name: cyl, dtype: int64
# disp Veiculo
# Mazda RX4              160.0
# Mazda RX4 Wag          160.0
# Datsun 710             108.0
# Hornet 4 Drive         258.0
# Hornet Sportabout      360.0
# Valiant                225.0
# Duster 360             360.0
# Merc 240D              146.7
# Merc 230               140.8
# Merc 280               167.6
# Merc 280C              167.6
# Merc 450SE             275.8
# Merc 450SL             275.8
# Merc 450SLC            275.8
# Cadillac Fleetwood     472.0
# Lincoln Continental    460.0
# Chrysler Imperial      440.0
# Fiat 128                78.7
# Honda Civic             75.7
# Toyota Corolla          71.1
# Toyota Corona          120.1
# Dodge Challenger       318.0
# AMC Javelin            304.0
# Camaro Z28             350.0
# Pontiac Firebird       400.0
# Fiat X1-9               79.0
# Porsche 914-2          120.3
# Lotus Europa            95.1
# Ford Pantera L         351.0
# Ferrari Dino           145.0
# Maserati Bora          301.0
# Volvo 142E             121.0
# Name: disp, dtype: float64
# hp Veiculo
# Mazda RX4              110
# Mazda RX4 Wag          110
# Datsun 710              93
# Hornet 4 Drive         110
# Hornet Sportabout      175
# Valiant                105
# Duster 360             245
# Merc 240D               62
# Merc 230                95
# Merc 280               123
# Merc 280C              123
# Merc 450SE             180
# Merc 450SL             180
# Merc 450SLC            180
# Cadillac Fleetwood     205
# Lincoln Continental    215
# Chrysler Imperial      230
# Fiat 128                66
# Honda Civic             52
# Toyota Corolla          65
# Toyota Corona           97
# Dodge Challenger       150
# AMC Javelin            150
# Camaro Z28             245
# Pontiac Firebird       175
# Fiat X1-9               66
# Porsche 914-2           91
# Lotus Europa           113
# Ford Pantera L         264
# Ferrari Dino           175
# Maserati Bora          335
# Volvo 142E             109
# Name: hp, dtype: int64
# drat Veiculo
# Mazda RX4              3.90
# Mazda RX4 Wag          3.90
# Datsun 710             3.85
# Hornet 4 Drive         3.08
# Hornet Sportabout      3.15
# Valiant                2.76
# Duster 360             3.21
# Merc 240D              3.69
# Merc 230               3.92
# Merc 280               3.92
# Merc 280C              3.92
# Merc 450SE             3.07
# Merc 450SL             3.07
# Merc 450SLC            3.07
# Cadillac Fleetwood     2.93
# Lincoln Continental    3.00
# Chrysler Imperial      3.23
# Fiat 128               4.08
# Honda Civic            4.93
# Toyota Corolla         4.22
# Toyota Corona          3.70
# Dodge Challenger       2.76
# AMC Javelin            3.15
# Camaro Z28             3.73
# Pontiac Firebird       3.08
# Fiat X1-9              4.08
# Porsche 914-2          4.43
# Lotus Europa           3.77
# Ford Pantera L         4.22
# Ferrari Dino           3.62
# Maserati Bora          3.54
# Volvo 142E             4.11
# Name: drat, dtype: float64
# wt Veiculo
# Mazda RX4              2.620
# Mazda RX4 Wag          2.875
# Datsun 710             2.320
# Hornet 4 Drive         3.215
# Hornet Sportabout      3.440
# Valiant                3.460
# Duster 360             3.570
# Merc 240D              3.190
# Merc 230               3.150
# Merc 280               3.440
# Merc 280C              3.440
# Merc 450SE             4.070
# Merc 450SL             3.730
# Merc 450SLC            3.780
# Cadillac Fleetwood     5.250
# Lincoln Continental    5.424
# Chrysler Imperial      5.345
# Fiat 128               2.200
# Honda Civic            1.615
# Toyota Corolla         1.835
# Toyota Corona          2.465
# Dodge Challenger       3.520
# AMC Javelin            3.435
# Camaro Z28             3.840
# Pontiac Firebird       3.845
# Fiat X1-9              1.935
# Porsche 914-2          2.140
# Lotus Europa           1.513
# Ford Pantera L         3.170
# Ferrari Dino           2.770
# Maserati Bora          3.570
# Volvo 142E             2.780
# Name: wt, dtype: float64
# qsec Veiculo
# Mazda RX4              16.46
# Mazda RX4 Wag          17.02
# Datsun 710             18.61
# Hornet 4 Drive         19.44
# Hornet Sportabout      17.02
# Valiant                20.22
# Duster 360             15.84
# Merc 240D              20.00
# Merc 230               22.90
# Merc 280               18.30
# Merc 280C              18.90
# Merc 450SE             17.40
# Merc 450SL             17.60
# Merc 450SLC            18.00
# Cadillac Fleetwood     17.98
# Lincoln Continental    17.82
# Chrysler Imperial      17.42
# Fiat 128               19.47
# Honda Civic            18.52
# Toyota Corolla         19.90
# Toyota Corona          20.01
# Dodge Challenger       16.87
# AMC Javelin            17.30
# Camaro Z28             15.41
# Pontiac Firebird       17.05
# Fiat X1-9              18.90
# Porsche 914-2          16.70
# Lotus Europa           16.90
# Ford Pantera L         14.50
# Ferrari Dino           15.50
# Maserati Bora          14.60
# Volvo 142E             18.60
# Name: qsec, dtype: float64
# vs Veiculo
# Mazda RX4              0
# Mazda RX4 Wag          0
# Datsun 710             1
# Hornet 4 Drive         1
# Hornet Sportabout      0
# Valiant                1
# Duster 360             0
# Merc 240D              1
# Merc 230               1
# Merc 280               1
# Merc 280C              1
# Merc 450SE             0
# Merc 450SL             0
# Merc 450SLC            0
# Cadillac Fleetwood     0
# Lincoln Continental    0
# Chrysler Imperial      0
# Fiat 128               1
# Honda Civic            1
# Toyota Corolla         1
# Toyota Corona          1
# Dodge Challenger       0
# AMC Javelin            0
# Camaro Z28             0
# Pontiac Firebird       0
# Fiat X1-9              1
# Porsche 914-2          0
# Lotus Europa           1
# Ford Pantera L         0
# Ferrari Dino           0
# Maserati Bora          0
# Volvo 142E             1
# Name: vs, dtype: int64
# am Veiculo
# Mazda RX4              1
# Mazda RX4 Wag          1
# Datsun 710             1
# Hornet 4 Drive         0
# Hornet Sportabout      0
# Valiant                0
# Duster 360             0
# Merc 240D              0
# Merc 230               0
# Merc 280               0
# Merc 280C              0
# Merc 450SE             0
# Merc 450SL             0
# Merc 450SLC            0
# Cadillac Fleetwood     0
# Lincoln Continental    0
# Chrysler Imperial      0
# Fiat 128               1
# Honda Civic            1
# Toyota Corolla         1
# Toyota Corona          0
# Dodge Challenger       0
# AMC Javelin            0
# Camaro Z28             0
# Pontiac Firebird       0
# Fiat X1-9              1
# Porsche 914-2          1
# Lotus Europa           1
# Ford Pantera L         1
# Ferrari Dino           1
# Maserati Bora          1
# Volvo 142E             1
# Name: am, dtype: int64
# gear Veiculo
# Mazda RX4              4
# Mazda RX4 Wag          4
# Datsun 710             4
# Hornet 4 Drive         3
# Hornet Sportabout      3
# Valiant                3
# Duster 360             3
# Merc 240D              4
# Merc 230               4
# Merc 280               4
# Merc 280C              4
# Merc 450SE             3
# Merc 450SL             3
# Merc 450SLC            3
# Cadillac Fleetwood     3
# Lincoln Continental    3
# Chrysler Imperial      3
# Fiat 128               4
# Honda Civic            4
# Toyota Corolla         4
# Toyota Corona          3
# Dodge Challenger       3
# AMC Javelin            3
# Camaro Z28             3
# Pontiac Firebird       3
# Fiat X1-9              4
# Porsche 914-2          5
# Lotus Europa           5
# Ford Pantera L         5
# Ferrari Dino           5
# Maserati Bora          5
# Volvo 142E             4
# Name: gear, dtype: int64
# carb Veiculo
# Mazda RX4              4
# Mazda RX4 Wag          4
# Datsun 710             1
# Hornet 4 Drive         1
# Hornet Sportabout      2
# Valiant                1
# Duster 360             4
# Merc 240D              2
# Merc 230               2
# Merc 280               4
# Merc 280C              4
# Merc 450SE             3
# Merc 450SL             3
# Merc 450SLC            3
# Cadillac Fleetwood     4
# Lincoln Continental    4
# Chrysler Imperial      4
# Fiat 128               1
# Honda Civic            2
# Toyota Corolla         1
# Toyota Corona          1
# Dodge Challenger       2
# AMC Javelin            2
# Camaro Z28             4
# Pontiac Firebird       2
# Fiat X1-9              1
# Porsche 914-2          2
# Lotus Europa           2
# Ford Pantera L         4
# Ferrari Dino           6
# Maserati Bora          8
# Volvo 142E             2
# Name: carb, dtype: int64

# %% [markdown]
# # Seleções de Dados

# %% [markdown]
# ## Coluna

# %% [markdown]
# Affairs.education *OU* Affairs['education'] - > retorna serie
# <br>Affairs[['education']] -> retorna DF

# %%
display(type(Affairs['education']))
display(type(Affairs.education))
Affairs['education'] # ou Affairs.education
# Out:
# pandas.core.series.Series
# pandas.core.series.Series
# 0      18
# 1      14
# 2      12
# 3      18
# 4      17
#        ..
# 596    12
# 597    18
# 598    17
# 599    18
# 600    14
# Name: education, Length: 601, dtype: int64

# %%
display(type(Affairs[['education']]))
Affairs[['education']]
# Out:
# pandas.core.frame.DataFrame
#      education
# 0           18
# 1           14
# 2           12
# 3           18
# 4           17
# ..         ...
# 596         12
# 597         18
# 598         17
# 599         18
# 600         14
#
# [601 rows x 1 columns]

# %%
Affairs.columns
# Out:
# Index(['rownames', 'affairs', 'gender', 'age', 'yearsmarried', 'children',
#        'religiousness', 'education', 'occupation', 'rating'],
#       dtype='object')

# %%
Affairs[['affairs', 'education']]
# Out:
#      affairs  education
# 0          0         18
# 1          0         14
# 2          0         12
# 3          0         18
# 4          0         17
# ..       ...        ...
# 596        1         12
# 597        7         18
# 598        2         17
# 599        2         18
# 600        1         14
#
# [601 rows x 2 columns]

# %%
Affairs[['affairs', 'education']].mean()
# Out:
# affairs       1.455907
# education    16.166389
# dtype: float64

# %%
Affairs3 = Affairs[['affairs', 'education']]
Affairs3.shape
# Out:
# (601, 2)

# %% [markdown]
# ### Multi-Index

# %%
financas.head(2)
# Out:
# Price      Adj Close                                                Close  \
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP     BRL=X
# Date
# 2023-01-02  5.285500  22.238420  16.037287  80.482178  106376.0  5.285500
# 2023-01-03  5.360131  21.775312  15.631456  80.338135  104166.0  5.360131
#
# Price                                              ...      Open           \
# Ticker     ITUB4.SA PETR4.SA   VALE3.SA     ^BVSP  ...     BRL=X ITUB4.SA
# Date                                               ...
# 2023-01-02    24.49    22.92  89.400002  106376.0  ...  5.285500    24.43
# 2023-01-03    23.98    22.34  89.239998  104166.0  ...  5.360131    24.49
#
# Price                                      Volume                          \
# Ticker       PETR4.SA   VALE3.SA     ^BVSP  BRL=X    ITUB4.SA    PETR4.SA
# Date
# 2023-01-02  23.540001  88.680000  109734.0      0  23340700.0  78424700.0
# 2023-01-03  22.940001  89.400002  106377.0      0  29873800.0  96750300.0
#
# Price
# Ticker        VALE3.SA       ^BVSP
# Date
# 2023-01-02  12783800.0   8130500.0
# 2023-01-03  25332600.0  14466700.0
#
# [2 rows x 30 columns]

# %%
financas.columns
# Out:
# MultiIndex([('Adj Close',    'BRL=X'),
#             ('Adj Close', 'ITUB4.SA'),
#             ('Adj Close', 'PETR4.SA'),
#             ('Adj Close', 'VALE3.SA'),
#             ('Adj Close',    '^BVSP'),
#             (    'Close',    'BRL=X'),
#             (    'Close', 'ITUB4.SA'),
#             (    'Close', 'PETR4.SA'),
#             (    'Close', 'VALE3.SA'),
#             (    'Close',    '^BVSP'),
#             (     'High',    'BRL=X'),
#             (     'High', 'ITUB4.SA'),
#             (     'High', 'PETR4.SA'),
#             (     'High', 'VALE3.SA'),
#             (     'High',    '^BVSP'),
#             (      'Low',    'BRL=X'),
#             (      'Low', 'ITUB4.SA'),
#             (      'Low', 'PETR4.SA'),
#             (      'Low', 'VALE3.SA'),
#             (      'Low',    '^BVSP'),
#             (     'Open',    'BRL=X'),
#             (     'Open', 'ITUB4.SA'),
#             (     'Open', 'PETR4.SA'),
#             (     'Open', 'VALE3.SA'),
#             (     'Open',    '^BVSP'),
#             (   'Volume',    'BRL=X'),
#             (   'Volume', 'ITUB4.SA'),
#             (   'Volume', 'PETR4.SA'),
#             (   'Volume', 'VALE3.SA'),
#             (   'Volume',    '^BVSP')],
#            names=['Price', 'Ticker'])

# %%
financas.columns[0:5]
# Out:
# MultiIndex([('Adj Close',    'BRL=X'),
#             ('Adj Close', 'ITUB4.SA'),
#             ('Adj Close', 'PETR4.SA'),
#             ('Adj Close', 'VALE3.SA'),
#             ('Adj Close',    '^BVSP')],
#            names=['Price', 'Ticker'])

# %%
# %%script echo skipping alternative solution
financas2 = financas[[('Adj Close',    'BRL=X'),
            ('Adj Close', 'ITUB4.SA'),
            ('Adj Close', 'PETR4.SA'),
            ('Adj Close', 'VALE3.SA'),
            ('Adj Close',    '^BVSP')]]

financas2.head()
# Out:
# Price      Adj Close
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.238420  16.037287  80.482178  106376.0
# 2023-01-03  5.360131  21.775312  15.631456  80.338135  104166.0
# 2023-01-04  5.478500  21.838877  16.128246  80.482178  105334.0
# 2023-01-05  5.430100  22.519920  16.709003  81.832550  107518.0
# 2023-01-06  5.349800  22.910389  16.611048  83.128906  108836.0

# %%
financas = financas['Adj Close']
financas
# Out:
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.238420  16.037287  80.482178  106376.0
# 2023-01-03  5.360131  21.775312  15.631456  80.338135  104166.0
# 2023-01-04  5.478500  21.838877  16.128246  80.482178  105334.0
# 2023-01-05  5.430100  22.519920  16.709003  81.832550  107518.0
# 2023-01-06  5.349800  22.910389  16.611048  83.128906  108836.0
# ...              ...        ...        ...        ...       ...
# 2023-12-25  4.869844        NaN        NaN        NaN       NaN
# 2023-12-26  4.869744  31.979033  33.820606  73.377686  133533.0
# 2023-12-27  4.813500  32.197613  33.847778  74.085999  134194.0
# 2023-12-28  4.826100  32.283138  33.739063  73.894554  134185.0
# 2023-12-29  4.850200        NaN        NaN        NaN       NaN
#
# [260 rows x 5 columns]

# %% [markdown]
# financas.isnull() # gera tabelas de vdd e falso para cada coluna

# %% [markdown]
# ## Linhas

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_images/03_subset_rows.svg" width=320, align="center">
#
# O critério de seleção é um predicado lógico e você deve empregar a seguinte sintaxe:
#
# ```
# df [ <critério de seleção> ]
# ```
#
# Exemplos
#
# ```
# df [ nome_coluna == valor ]
# df [ nome_coluna != valor ]
# df [ nome_coluna > valor ]
# ```

# %%
Affairs.children == 'yes'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 596     True
# 597     True
# 598     True
# 599     True
# 600     True
# Name: children, Length: 601, dtype: bool

# %%
Affairs.children.isin(["yes"]) # esta em (is in)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 596     True
# 597     True
# 598     True
# 599     True
# 600     True
# Name: children, Length: 601, dtype: bool

# %%
display(Affairs[Affairs.children == 'yes'])
# ou
Affairs[Affairs.children.isin(["yes"])]
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 2          11        0  female  32.0          15.0      yes              1
# 3          16        0    male  57.0          15.0      yes              5
# 7          45        0    male  57.0          15.0      yes              2
# 8          47        0  female  32.0          15.0      yes              4
# 10         50        0    male  37.0          15.0      yes              2
# ..        ...      ...     ...   ...           ...      ...            ...
# 596      1938        1    male  22.0           1.5      yes              1
# 597      1941        7  female  32.0          10.0      yes              2
# 598      1954        2    male  32.0          10.0      yes              2
# 599      1959        2    male  22.0           7.0      yes              3
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 2           12           1       4
# 3           18           6       5
# 7           14           4       4
# 8           16           1       2
# 10          20           7       2
# ..         ...         ...     ...
# 596         12           2       5
# 597         18           5       4
# 598         17           6       5
# 599         18           6       2
# 600         14           1       5
#
# [430 rows x 10 columns]
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 2          11        0  female  32.0          15.0      yes              1
# 3          16        0    male  57.0          15.0      yes              5
# 7          45        0    male  57.0          15.0      yes              2
# 8          47        0  female  32.0          15.0      yes              4
# 10         50        0    male  37.0          15.0      yes              2
# ..        ...      ...     ...   ...           ...      ...            ...
# 596      1938        1    male  22.0           1.5      yes              1
# 597      1941        7  female  32.0          10.0      yes              2
# 598      1954        2    male  32.0          10.0      yes              2
# 599      1959        2    male  22.0           7.0      yes              3
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 2           12           1       4
# 3           18           6       5
# 7           14           4       4
# 8           16           1       2
# 10          20           7       2
# ..         ...         ...     ...
# 596         12           2       5
# 597         18           5       4
# 598         17           6       5
# 599         18           6       2
# 600         14           1       5
#
# [430 rows x 10 columns]

# %% [markdown]
# IMPORTANTE O USO DE () ENTRE OS CRITEIROS

# %%
Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 18) ]
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 80        412        0    male  17.5          1.50      yes              3
# 540      1138       12  female  17.5          0.75      yes              2
# 571      1674       12  female  17.5          0.75      yes              2
#
#      education  occupation  rating
# 80          18           6       5
# 540         12           1       3
# 571         12           3       5

# %%
tips_nao_fumantes = tips[ tips.smoker == 'No' ]
tips_fumantes = tips[ tips.smoker == 'Yes' ]
print(f'Percentual de Clientes Fumantes {len( tips_fumantes ) / len( tips ) :.2f} %')
# Out:
# Percentual de Clientes Fumantes 0.38 %

# %%
# Considerando somente os finais de semana, quem tem média de participantes na mesa maior, fumantes ou não fumantes? 
print('Não fumantes tem média de participantes na mesa maior que fumantes? ',
      tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean() <
      tips[ (tips.smoker == 'No') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean())
# Out:
# Não fumantes tem média de participantes na mesa maior que fumantes?  True

# %%
f"Não fumantes {tips[ (tips.smoker == 'No') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean()} \
    fumantes {tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ]['size'].mean()} \
        "
# Out:
# 'Não fumantes 2.764705882352941     fumantes 2.5081967213114753         '

# %%
tips[ tips.day.isin(['Sat','Sun']) ].groupby('smoker')['size'].mean()
# Out:
# smoker
# No     2.764706
# Yes    2.508197
# Name: size, dtype: float64

# %%
tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ].groupby(["day","smoker"]).count()
# Out:
#             total_bill  tip  sex  time  size
# day smoker
# Sat Yes             42   42   42    42    42
# Sun Yes             19   19   19    19    19

# %%
tips[ (tips.smoker == 'Yes') & (tips.day.isin(['Sat','Sun'])) ].groupby(["day","smoker"])[["smoker"]].count()
# Out:
#             smoker
# day smoker
# Sat Yes         42
# Sun Yes         19

# %%
for line in carros.index:
  print(line)
# Out:
# AMC Javelin
# Cadillac Fleetwood
# Camaro Z28
# Chrysler Imperial
# Datsun 710
# Dodge Challenger
# Duster 360
# Ferrari Dino
# Fiat 128
# Fiat X1-9
# Ford Pantera L
# Honda Civic
# Hornet 4 Drive
# Hornet Sportabout
# Lincoln Continental
# Lotus Europa
# Maserati Bora
# Mazda RX4
# Mazda RX4 Wag
# Merc 230
# Merc 240D
# Merc 280
# Merc 280C
# Merc 450SE
# Merc 450SL
# Merc 450SLC
# Pontiac Firebird
# Porsche 914-2
# Toyota Corolla
# Toyota Corona
# Valiant
# Volvo 142E

# %% [markdown]
# ### Acessando valores por índice .loc, .iloc, .at, .iat

# %% [markdown]
# i - pega pelo indice numero
#
# sem i - pega pelo valor nome

# %% [markdown]
# `DataFrame.loc`
#
# Access a group of rows and columns by label(s).
#
# `DataFrame.iloc`
#
# Access a group of rows and columns by integer position(s).
#
# `DataFrame.at`
#
# Access a single value for a row/column label pair.
#
# `DataFrame.iat`
#
# Access a single value for a row/column pair by integer position.

# %%
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros.mpg.head(5)
# Out:
# Veiculo
# Mazda RX4            21.0
# Mazda RX4 Wag        21.0
# Datsun 710           22.8
# Hornet 4 Drive       21.4
# Hornet Sportabout    18.7
# Name: mpg, dtype: float64

# %%
carros.mpg['Porsche 914-2'] # Indice
# df['Porsche 914-2'] --> erro não pode buscar linhas como se fossem colunas - usar o loc
# Out:
# np.float64(26.0)

# %% [markdown]
# ### Loc

# %%
carros.loc['Datsun 710',['mpg','cyl']]

# ou
carros.loc['Datsun 710'][['mpg','cyl']]
# Out:
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64

# %%
temp = carros.sort_index().copy()
temp.head()
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
display(temp.loc[ 'Cadillac Fleetwood' , 'am' ])
temp.loc[ 'Cadillac Fleetwood' , 'am' ] = 1 # atualizando dado especifico
temp.head()
# Out:
# np.int64(1)
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %% [markdown]
# #### + de 1

# %%
temp.loc['Camaro Z28':'Datsun 710'] # pegando valores do camaro até datsun
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Camaro Z28         13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                    carb
# Veiculo
# Camaro Z28            4
# Chrysler Imperial     4
# Datsun 710            1

# %%
temp.loc['Camaro Z28':'Datsun 710' , 'hp':'am'] # pegando valores do camaro até datsun e as colunas hp até am
# Out:
#                     hp  drat     wt   qsec  vs  am
# Veiculo
# Camaro Z28         245  3.73  3.840  15.41   0   0
# Chrysler Imperial  230  3.23  5.345  17.42   0   0
# Datsun 710          93  3.85  2.320  18.61   1   1

# %%
temp.iloc[2:5 , 3:9] # pegando valores do camaro até datsun e as colunas hp até am
# Out:
#                     hp  drat     wt   qsec  vs  am
# Veiculo
# Camaro Z28         245  3.73  3.840  15.41   0   0
# Chrysler Imperial  230  3.23  5.345  17.42   0   0
# Datsun 710          93  3.85  2.320  18.61   1   1

# %%
display(carros.head())

for line in carros.index:
  for column in carros:
    carros.loc[line,column] = carros.loc[line,column] + 10 # somar + 10 em todas as linhas e colunas

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp   drat      wt   qsec  vs  am  \
# Veiculo
# AMC Javelin         35.2   18  314.0  1510  13.15  13.435  27.30  10  14
# Cadillac Fleetwood  30.4   18  482.0  2060  12.93  15.250  27.98  10  14
# Camaro Z28          33.3   18  360.0  2460  13.73  13.840  25.41  10  14
# Chrysler Imperial   34.7   18  450.0  2310  13.23  15.345  27.42  10  14
# Datsun 710          42.8   14  118.0   940  13.85  12.320  28.61  11  14
#
#                     gear  carb   kmpg
# Veiculo
# AMC Javelin           13    12  34.32
# Cadillac Fleetwood    13    14  26.64
# Camaro Z28            13    14  31.28
# Chrysler Imperial     13    14  33.52
# Datsun 710            14    11  46.48
#                      mpg  cyl   disp    hp   drat      wt   qsec  vs  am  \
# Veiculo
# AMC Javelin         45.2   28  324.0  1520  23.15  23.435  37.30  20  24
# Cadillac Fleetwood  40.4   28  492.0  2070  22.93  25.250  37.98  20  24
# Camaro Z28          43.3   28  370.0  2470  23.73  23.840  35.41  20  24
# Chrysler Imperial   44.7   28  460.0  2320  23.23  25.345  37.42  20  24
# Datsun 710          52.8   24  128.0   950  23.85  22.320  38.61  21  24
#
#                     gear  carb   kmpg
# Veiculo
# AMC Javelin           23    22  44.32
# Cadillac Fleetwood    23    24  36.64
# Camaro Z28            23    24  41.28
# Chrysler Imperial     23    24  43.52
# Datsun 710            24    21  56.48

# %% [markdown]
# ### iloc

# %%
display(Affairs.head(1)) # primeiros 1 valores
Affairs.iloc[0]
# Out:
#    rownames  affairs gender   age  yearsmarried children  religiousness  \
# 0         4        0   male  37.0          10.0       no              3
#
#    education  occupation  rating
# 0         18           7       4
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 600         14           1       5
# rownames            4
# affairs             0
# gender           male
# age              37.0
# yearsmarried     10.0
# children           no
# religiousness       3
# education          18
# occupation          7
# rating              4
# Name: 0, dtype: object

# %%
display(Affairs.tail(2)) # ultimos 1 valores

Affairs.iloc[-2]
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 599      1959        2    male  22.0           7.0      yes              3
# 600      9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 599         18           6       2
# 600         14           1       5
# rownames         1959
# affairs             2
# gender           male
# age              22.0
# yearsmarried      7.0
# children          yes
# religiousness       3
# education          18
# occupation          6
# rating              2
# Name: 599, dtype: object

# %%
for line in range(0,len(carros)):
  print( carros.iloc[line] )
# Out:
# mpg       15.200
# cyl        8.000
# disp     304.000
# hp      1500.000
# drat       3.150
# wt         3.435
# qsec      17.300
# vs         0.000
# am         4.000
# gear       3.000
# carb       2.000
# kmpg      24.320
# Name: AMC Javelin, dtype: float64
# mpg       10.40
# cyl        8.00
# disp     472.00
# hp      2050.00
# drat       2.93
# wt         5.25
# qsec      17.98
# vs         0.00
# am         4.00
# gear       3.00
# carb       4.00
# kmpg      16.64
# Name: Cadillac Fleetwood, dtype: float64
# mpg       13.30
# cyl        8.00
# disp     350.00
# hp      2450.00
# drat       3.73
# wt         3.84
# qsec      15.41
# vs         0.00
# am         4.00
# gear       3.00
# carb       4.00
# kmpg      21.28
# Name: Camaro Z28, dtype: float64
# mpg       14.700
# cyl        8.000
# disp     440.000
# hp      2300.000
# drat       3.230
# wt         5.345
# qsec      17.420
# vs         0.000
# am         4.000
# gear       3.000
# carb       4.000
# kmpg      23.520
# Name: Chrysler Imperial, dtype: float64
# mpg      22.80
# cyl       4.00
# disp    108.00
# hp      930.00
# drat      3.85
# wt        2.32
# qsec     18.61
# vs        1.00
# am        4.00
# gear      4.00
# carb      1.00
# kmpg     36.48
# Name: Datsun 710, dtype: float64
# mpg       15.50
# cyl        8.00
# disp     318.00
# hp      1500.00
# drat       2.76
# wt         3.52
# qsec      16.87
# vs         0.00
# am         4.00
# gear       3.00
# carb       2.00
# kmpg      24.80
# Name: Dodge Challenger, dtype: float64
# mpg       14.30
# cyl        8.00
# disp     360.00
# hp      2450.00
# drat       3.21
# wt         3.57
# qsec      15.84
# vs         0.00
# am         4.00
# gear       3.00
# carb       4.00
# kmpg      22.88
# Name: Duster 360, dtype: float64
# mpg       19.70
# cyl        6.00
# disp     145.00
# hp      1750.00
# drat       3.62
# wt         2.77
# qsec      15.50
# vs         0.00
# am         4.00
# gear       5.00
# carb       6.00
# kmpg      31.52
# Name: Ferrari Dino, dtype: float64
# mpg      32.40
# cyl       4.00
# disp     78.70
# hp      660.00
# drat      4.08
# wt        2.20
# qsec     19.47
# vs        1.00
# am        4.00
# gear      4.00
# carb      1.00
# kmpg     51.84
# Name: Fiat 128, dtype: float64
# mpg      27.300
# cyl       4.000
# disp     79.000
# hp      660.000
# drat      4.080
# wt        1.935
# qsec     18.900
# vs        1.000
# am        4.000
# gear      4.000
# carb      1.000
# kmpg     43.680
# Name: Fiat X1-9, dtype: float64
# mpg       15.80
# cyl        8.00
# disp     351.00
# hp      2640.00
# drat       4.22
# wt         3.17
# qsec      14.50
# vs         0.00
# am         1.00
# gear       5.00
# carb       4.00
# kmpg      25.28
# Name: Ford Pantera L, dtype: float64
# mpg      30.400
# cyl       4.000
# disp     75.700
# hp      520.000
# drat      4.930
# wt        1.615
# qsec     18.520
# vs        1.000
# am        1.000
# gear      4.000
# carb      2.000
# kmpg     48.640
# Name: Honda Civic, dtype: float64
# mpg       21.400
# cyl        6.000
# disp     258.000
# hp      1100.000
# drat       3.080
# wt         3.215
# qsec      19.440
# vs         1.000
# am         0.000
# gear       3.000
# carb       1.000
# kmpg      34.240
# Name: Hornet 4 Drive, dtype: float64
# mpg       18.70
# cyl        8.00
# disp     360.00
# hp      1750.00
# drat       3.15
# wt         3.44
# qsec      17.02
# vs         0.00
# am         0.00
# gear       3.00
# carb       2.00
# kmpg      29.92
# Name: Hornet Sportabout, dtype: float64
# mpg       10.400
# cyl        8.000
# disp     460.000
# hp      2150.000
# drat       3.000
# wt         5.424
# qsec      17.820
# vs         0.000
# am         0.000
# gear       3.000
# carb       4.000
# kmpg      16.640
# Name: Lincoln Continental, dtype: float64
# mpg       30.400
# cyl        4.000
# disp      95.100
# hp      1130.000
# drat       3.770
# wt         1.513
# qsec      16.900
# vs         1.000
# am         1.000
# gear       5.000
# carb       2.000
# kmpg      48.640
# Name: Lotus Europa, dtype: float64
# mpg       15.00
# cyl        8.00
# disp     301.00
# hp      3350.00
# drat       3.54
# wt         3.57
# qsec      14.60
# vs         0.00
# am         1.00
# gear       5.00
# carb       8.00
# kmpg      24.00
# Name: Maserati Bora, dtype: float64
# mpg       21.00
# cyl        6.00
# disp     160.00
# hp      1100.00
# drat       3.90
# wt         2.62
# qsec      16.46
# vs         0.00
# am         1.00
# gear       4.00
# carb       4.00
# kmpg      33.60
# Name: Mazda RX4, dtype: float64
# mpg       21.000
# cyl        6.000
# disp     160.000
# hp      1100.000
# drat       3.900
# wt         2.875
# qsec      17.020
# vs         0.000
# am         1.000
# gear       4.000
# carb       4.000
# kmpg      33.600
# Name: Mazda RX4 Wag, dtype: float64
# mpg      22.80
# cyl       4.00
# disp    140.80
# hp      950.00
# drat      3.92
# wt        3.15
# qsec     22.90
# vs        1.00
# am        0.00
# gear      4.00
# carb      2.00
# kmpg     36.48
# Name: Merc 230, dtype: float64
# mpg      24.40
# cyl       4.00
# disp    146.70
# hp      620.00
# drat      3.69
# wt        3.19
# qsec     20.00
# vs        1.00
# am        0.00
# gear      4.00
# carb      2.00
# kmpg     39.04
# Name: Merc 240D, dtype: float64
# mpg       19.20
# cyl        6.00
# disp     167.60
# hp      1230.00
# drat       3.92
# wt         3.44
# qsec      18.30
# vs         1.00
# am         0.00
# gear       4.00
# carb       4.00
# kmpg      30.72
# Name: Merc 280, dtype: float64
# mpg       17.80
# cyl        6.00
# disp     167.60
# hp      1230.00
# drat       3.92
# wt         3.44
# qsec      18.90
# vs         1.00
# am         0.00
# gear       4.00
# carb       4.00
# kmpg      28.48
# Name: Merc 280C, dtype: float64
# mpg       16.40
# cyl        8.00
# disp     275.80
# hp      1800.00
# drat       3.07
# wt         4.07
# qsec      17.40
# vs         0.00
# am         0.00
# gear       3.00
# carb       3.00
# kmpg      26.24
# Name: Merc 450SE, dtype: float64
# mpg       17.30
# cyl        8.00
# disp     275.80
# hp      1800.00
# drat       3.07
# wt         3.73
# qsec      17.60
# vs         0.00
# am         0.00
# gear       3.00
# carb       3.00
# kmpg      27.68
# Name: Merc 450SL, dtype: float64
# mpg       15.20
# cyl        8.00
# disp     275.80
# hp      1800.00
# drat       3.07
# wt         3.78
# qsec      18.00
# vs         0.00
# am         0.00
# gear       3.00
# carb       3.00
# kmpg      24.32
# Name: Merc 450SLC, dtype: float64
# mpg       19.200
# cyl        8.000
# disp     400.000
# hp      1750.000
# drat       3.080
# wt         3.845
# qsec      17.050
# vs         0.000
# am         0.000
# gear       3.000
# carb       2.000
# kmpg      30.720
# Name: Pontiac Firebird, dtype: float64
# mpg      26.00
# cyl       4.00
# disp    120.30
# hp      910.00
# drat      4.43
# wt        2.14
# qsec     16.70
# vs        0.00
# am        1.00
# gear      5.00
# carb      2.00
# kmpg     41.60
# Name: Porsche 914-2, dtype: float64
# mpg      33.900
# cyl       4.000
# disp     71.100
# hp      650.000
# drat      4.220
# wt        1.835
# qsec     19.900
# vs        1.000
# am        1.000
# gear      4.000
# carb      1.000
# kmpg     54.240
# Name: Toyota Corolla, dtype: float64
# mpg      21.500
# cyl       4.000
# disp    120.100
# hp      970.000
# drat      3.700
# wt        2.465
# qsec     20.010
# vs        1.000
# am        0.000
# gear      3.000
# carb      1.000
# kmpg     34.400
# Name: Toyota Corona, dtype: float64
# mpg       18.10
# cyl        6.00
# disp     225.00
# hp      1050.00
# drat       2.76
# wt         3.46
# qsec      20.22
# vs         1.00
# am         0.00
# gear       3.00
# carb       1.00
# kmpg      28.96
# Name: Valiant, dtype: float64
# mpg       21.40
# cyl        4.00
# disp     121.00
# hp      1090.00
# drat       4.11
# wt         2.78
# qsec      18.60
# vs         1.00
# am         1.00
# gear       4.00
# carb       2.00
# kmpg      34.24
# Name: Volvo 142E, dtype: float64

# %%
for line in range(0,len(carros)):
  print( carros.iloc[line, 0:2] )
# Out:
# mpg    15.2
# cyl     8.0
# Name: AMC Javelin, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Cadillac Fleetwood, dtype: float64
# mpg    13.3
# cyl     8.0
# Name: Camaro Z28, dtype: float64
# mpg    14.7
# cyl     8.0
# Name: Chrysler Imperial, dtype: float64
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64
# mpg    15.5
# cyl     8.0
# Name: Dodge Challenger, dtype: float64
# mpg    14.3
# cyl     8.0
# Name: Duster 360, dtype: float64
# mpg    19.7
# cyl     6.0
# Name: Ferrari Dino, dtype: float64
# mpg    32.4
# cyl     4.0
# Name: Fiat 128, dtype: float64
# mpg    27.3
# cyl     4.0
# Name: Fiat X1-9, dtype: float64
# mpg    15.8
# cyl     8.0
# Name: Ford Pantera L, dtype: float64
# mpg    30.4
# cyl     4.0
# Name: Honda Civic, dtype: float64
# mpg    21.4
# cyl     6.0
# Name: Hornet 4 Drive, dtype: float64
# mpg    18.7
# cyl     8.0
# Name: Hornet Sportabout, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Lincoln Continental, dtype: float64
# mpg    30.4
# cyl     4.0
# Name: Lotus Europa, dtype: float64
# mpg    15.0
# cyl     8.0
# Name: Maserati Bora, dtype: float64
# mpg    21.0
# cyl     6.0
# Name: Mazda RX4, dtype: float64
# mpg    21.0
# cyl     6.0
# Name: Mazda RX4 Wag, dtype: float64
# mpg    22.8
# cyl     4.0
# Name: Merc 230, dtype: float64
# mpg    24.4
# cyl     4.0
# Name: Merc 240D, dtype: float64
# mpg    19.2
# cyl     6.0
# Name: Merc 280, dtype: float64
# mpg    17.8
# cyl     6.0
# Name: Merc 280C, dtype: float64
# mpg    16.4
# cyl     8.0
# Name: Merc 450SE, dtype: float64
# mpg    17.3
# cyl     8.0
# Name: Merc 450SL, dtype: float64
# mpg    15.2
# cyl     8.0
# Name: Merc 450SLC, dtype: float64
# mpg    19.2
# cyl     8.0
# Name: Pontiac Firebird, dtype: float64
# mpg    26.0
# cyl     4.0
# Name: Porsche 914-2, dtype: float64
# mpg    33.9
# cyl     4.0
# Name: Toyota Corolla, dtype: float64
# mpg    21.5
# cyl     4.0
# Name: Toyota Corona, dtype: float64
# mpg    18.1
# cyl     6.0
# Name: Valiant, dtype: float64
# mpg    21.4
# cyl     4.0
# Name: Volvo 142E, dtype: float64

# %%
for line in range(0,len(carros)):
  print( carros.iloc[line][['mpg','cyl']] )
# Out:
# mpg    15.2
# cyl     8.0
# Name: AMC Javelin, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Cadillac Fleetwood, dtype: float64
# mpg    13.3
# cyl     8.0
# Name: Camaro Z28, dtype: float64
# mpg    14.7
# cyl     8.0
# Name: Chrysler Imperial, dtype: float64
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64
# mpg    15.5
# cyl     8.0
# Name: Dodge Challenger, dtype: float64
# mpg    14.3
# cyl     8.0
# Name: Duster 360, dtype: float64
# mpg    19.7
# cyl     6.0
# Name: Ferrari Dino, dtype: float64
# mpg    32.4
# cyl     4.0
# Name: Fiat 128, dtype: float64
# mpg    27.3
# cyl     4.0
# Name: Fiat X1-9, dtype: float64
# mpg    15.8
# cyl     8.0
# Name: Ford Pantera L, dtype: float64
# mpg    30.4
# cyl     4.0
# Name: Honda Civic, dtype: float64
# mpg    21.4
# cyl     6.0
# Name: Hornet 4 Drive, dtype: float64
# mpg    18.7
# cyl     8.0
# Name: Hornet Sportabout, dtype: float64
# mpg    10.4
# cyl     8.0
# Name: Lincoln Continental, dtype: float64
# mpg    30.4
# cyl     4.0
# Name: Lotus Europa, dtype: float64
# mpg    15.0
# cyl     8.0
# Name: Maserati Bora, dtype: float64
# mpg    21.0
# cyl     6.0
# Name: Mazda RX4, dtype: float64
# mpg    21.0
# cyl     6.0
# Name: Mazda RX4 Wag, dtype: float64
# mpg    22.8
# cyl     4.0
# Name: Merc 230, dtype: float64
# mpg    24.4
# cyl     4.0
# Name: Merc 240D, dtype: float64
# mpg    19.2
# cyl     6.0
# Name: Merc 280, dtype: float64
# mpg    17.8
# cyl     6.0
# Name: Merc 280C, dtype: float64
# mpg    16.4
# cyl     8.0
# Name: Merc 450SE, dtype: float64
# mpg    17.3
# cyl     8.0
# Name: Merc 450SL, dtype: float64
# mpg    15.2
# cyl     8.0
# Name: Merc 450SLC, dtype: float64
# mpg    19.2
# cyl     8.0
# Name: Pontiac Firebird, dtype: float64
# mpg    26.0
# cyl     4.0
# Name: Porsche 914-2, dtype: float64
# mpg    33.9
# cyl     4.0
# Name: Toyota Corolla, dtype: float64
# mpg    21.5
# cyl     4.0
# Name: Toyota Corona, dtype: float64
# mpg    18.1
# cyl     6.0
# Name: Valiant, dtype: float64
# mpg    21.4
# cyl     4.0
# Name: Volvo 142E, dtype: float64

# %%
temp.iloc[ 1 , 8 ] = 0  # atualizando dado especifico
temp.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %% [markdown]
# ### + de um valor

# %%
carros.iloc[2,0:2]
# Out:
# mpg    22.8
# cyl     4.0
# Name: Datsun 710, dtype: float64

# %%
temp.iloc[2:5]['mpg']
# Out:
# Veiculo
# Camaro Z28           13.3
# Chrysler Imperial    14.7
# Datsun 710           22.8
# Name: mpg, dtype: float64

# %%
temp.head(11)
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
# Dodge Challenger    15.5    8  318.0  1500  2.76  3.520  16.87   0   1     3
# Duster 360          14.3    8  360.0  2450  3.21  3.570  15.84   0   1     3
# Ferrari Dino        19.7    6  145.0  1750  3.62  2.770  15.50   0   1     5
# Fiat 128            32.4    4   78.7   660  4.08  2.200  19.47   1   1     4
# Fiat X1-9           27.3    4   79.0   660  4.08  1.935  18.90   1   1     4
# Ford Pantera L      15.8    8  351.0  2640  4.22  3.170  14.50   0   1     5
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
# Dodge Challenger       2  24.80
# Duster 360             4  22.88
# Ferrari Dino           6  31.52
# Fiat 128               1  51.84
# Fiat X1-9              1  43.68
# Ford Pantera L         4  25.28

# %%
temp.iloc[ 0:10 , 8 ] = 2 # linhas da 0-10 coluna 8 tudo fica = 2
temp.head(12)
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   2     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   2     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   2     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   2     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   2     4
# Dodge Challenger    15.5    8  318.0  1500  2.76  3.520  16.87   0   2     3
# Duster 360          14.3    8  360.0  2450  3.21  3.570  15.84   0   2     3
# Ferrari Dino        19.7    6  145.0  1750  3.62  2.770  15.50   0   2     5
# Fiat 128            32.4    4   78.7   660  4.08  2.200  19.47   1   2     4
# Fiat X1-9           27.3    4   79.0   660  4.08  1.935  18.90   1   2     4
# Ford Pantera L      15.8    8  351.0  2640  4.22  3.170  14.50   0   1     5
# Honda Civic         30.4    4   75.7   520  4.93  1.615  18.52   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
# Dodge Challenger       2  24.80
# Duster 360             4  22.88
# Ferrari Dino           6  31.52
# Fiat 128               1  51.84
# Fiat X1-9              1  43.68
# Ford Pantera L         4  25.28
# Honda Civic            2  48.64

# %%
display(carros.head())

for i in range(0,len(carros)):

  carros.iloc[i]['mpg'] = carros.iloc[i]['mpg'] + 10 # NÃO ALTERA --> Gera uma copia do df quando eu seleciono a coluna

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   4     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   4     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   4     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   4     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   4     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
# /tmp/ipykernel_44578/4206193782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carros.iloc[i]['mpg'] = carros.iloc[i]['mpg'] + 10 # NÃO ALTERA --> Gera uma copia do df quando eu seleciono a coluna
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   4     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   4     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   4     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   4     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   4     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
display(carros.head())

for line in range(0,len(carros)):
  carros.iloc[line,0] = carros.iloc[line,0] + 10 # Não gera a copia -- não estou selecionando a coluna

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   4     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   4     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   4     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   4     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   4     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         25.2    8  304.0  1500  3.15  3.435  17.30   0   4     3
# Cadillac Fleetwood  20.4    8  472.0  2050  2.93  5.250  17.98   0   4     3
# Camaro Z28          23.3    8  350.0  2450  3.73  3.840  15.41   0   4     3
# Chrysler Imperial   24.7    8  440.0  2300  3.23  5.345  17.42   0   4     3
# Datsun 710          32.8    4  108.0   930  3.85  2.320  18.61   1   4     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
display(carros.head())

for line in range(0,len(carros)):
  for column in range(0,carros.shape[1]):
    carros.iloc[line,column] = carros.iloc[line,column] + 10 # somando mais 10 em todas as linhas e colunas do df

display(carros.head())
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         25.2    8  304.0  1500  3.15  3.435  17.30   0   4     3
# Cadillac Fleetwood  20.4    8  472.0  2050  2.93  5.250  17.98   0   4     3
# Camaro Z28          23.3    8  350.0  2450  3.73  3.840  15.41   0   4     3
# Chrysler Imperial   24.7    8  440.0  2300  3.23  5.345  17.42   0   4     3
# Datsun 710          32.8    4  108.0   930  3.85  2.320  18.61   1   4     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
#                      mpg  cyl   disp    hp   drat      wt   qsec  vs  am  \
# Veiculo
# AMC Javelin         35.2   18  314.0  1510  13.15  13.435  27.30  10  14
# Cadillac Fleetwood  30.4   18  482.0  2060  12.93  15.250  27.98  10  14
# Camaro Z28          33.3   18  360.0  2460  13.73  13.840  25.41  10  14
# Chrysler Imperial   34.7   18  450.0  2310  13.23  15.345  27.42  10  14
# Datsun 710          42.8   14  118.0   940  13.85  12.320  28.61  11  14
#
#                     gear  carb   kmpg
# Veiculo
# AMC Javelin           13    12  34.32
# Cadillac Fleetwood    13    14  26.64
# Camaro Z28            13    14  31.28
# Chrysler Imperial     13    14  33.52
# Datsun 710            14    11  46.48

# %% [markdown]
# ### At e iat

# %%
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %%
# df.at['Datsun 710',['mpg','cyl']] --> erro
carros.at['Datsun 710','mpg']
# Out:
# np.float64(22.8)

# %%
carros.iat[2,0]
# Out:
# np.float64(13.3)

# %%
# df.ix[2:5,'mpg'] - ERRO

# %% [markdown]
# ## Linhas e Colunas

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns_rows.svg" width=320, align="center">
#
# A boa prática indica que sempre faremos primeiro a seleção das linhas,
#
# ```
# df [ <critério de seleção> ] ...
#
# ...Selecionando uma coluna
# df [ <critério de seleção> ].nome_coluna                  pd.Series
# df [ <critério de seleção> ]['nome_coluna']
#
# ...Selecionando uma ou mais colunas
# df [ <critério de seleção> ][ [<lista-de-colunas>] ]      pd.DataFrame
#
# ```

# %%
Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 18) ].education.mean()
# Out:
# np.float64(14.0)

# %%
Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 30) ][['affairs', 'education']]
# Out:
#      affairs  education
# 11         0         18
# 19         0         14
# 22         0         16
# 28         0         16
# 29         0         17
# ..       ...        ...
# 580        1         18
# 590        7         16
# 593       12         17
# 596        1         12
# 599        2         18
#
# [135 rows x 2 columns]

# %%
display(tips[ tips.smoker == 'Yes' ]['tip'].mean() > tips[ tips.smoker == 'No' ]['tip'].mean())

tips[ tips.sex == 'Female' ]['tip'].mean() > tips[ tips.sex == 'Male' ]['tip'].mean()
# Out:
# np.True_
# np.False_

# %%
import matplotlib.pyplot as plt
plt.hist(tips[ tips.sex == 'Male' ]['tip'], label='Homens')
plt.hist(tips[ tips.sex == 'Female' ]['tip'], label='Mulheres')

plt.xlabel('Valor das Gorjetas')
plt.ylabel('Quantidades Pagas')
plt.title('Distribuição das Gorjetas', fontsize=14, weight='bold')
plt.legend(title='$\\bf{Gorjetas}$')
plt.show()

# %%
len( Affairs[ (Affairs['children'] == 'yes') & (Affairs.age < 30) ] ) / len(Affairs) * 100
# Out:
# 22.462562396006653

# %% [markdown]
# # Propriedades de uma serie

# %%
type(Affairs.children)
# Out:
# pandas.core.series.Series

# %%
Affairs.gender.value_counts()
# Out:
# gender
# female    315
# male      286
# Name: count, dtype: int64

# %%
Affairs.education.value_counts()
# Out:
# education
# 14    154
# 16    115
# 18    112
# 17     89
# 20     80
# 12     44
# 9       7
# Name: count, dtype: int64

# %%
Affairs.age.value_counts()
# Out:
# age
# 27.0    153
# 22.0    117
# 32.0    115
# 37.0     88
# 42.0     56
# 47.0     23
# 57.0     22
# 52.0     21
# 17.5      6
# Name: count, dtype: int64

# %%
display(financas.sum())
financas.sum().sum()
# Out:
# Price      Ticker
# Adj Close  BRL=X       1.298500e+03
#            ITUB4.SA    6.288432e+03
#            PETR4.SA    5.990838e+03
#            VALE3.SA    1.699367e+04
#            ^BVSP       2.832012e+07
# Close      BRL=X       1.298500e+03
#            ITUB4.SA    6.777040e+03
#            PETR4.SA    7.362800e+03
#            VALE3.SA    1.835013e+04
#            ^BVSP       2.832012e+07
# High       BRL=X       1.304821e+03
#            ITUB4.SA    6.847480e+03
#            PETR4.SA    7.454590e+03
#            VALE3.SA    1.854528e+04
#            ^BVSP       2.852448e+07
# Low        BRL=X       1.291391e+03
#            ITUB4.SA    6.699940e+03
#            PETR4.SA    7.258670e+03
#            VALE3.SA    1.818992e+04
#            ^BVSP       2.810338e+07
# Open       BRL=X       1.298500e+03
#            ITUB4.SA    6.772290e+03
#            PETR4.SA    7.352220e+03
#            VALE3.SA    1.838142e+04
#            ^BVSP       2.829769e+07
# Volume     BRL=X       0.000000e+00
#            ITUB4.SA    7.207736e+09
#            PETR4.SA    1.417672e+10
#            VALE3.SA    6.290076e+09
#            ^BVSP       2.908533e+09
# dtype: float64
# np.float64(30724792442.42987)

# %%
display(financasAdjClose.sum())
financasAdjClose.sum().sum()
# Out:
# Ticker
# BRL=X       1.298500e+03
# ITUB4.SA    6.288432e+03
# PETR4.SA    5.990838e+03
# VALE3.SA    1.699367e+04
# ^BVSP       2.832012e+07
# dtype: float64
# np.float64(28350689.43955183)

# %%
# Affairs

# %%
Affairs.yearsmarried.mean()
# Out:
# np.float64(8.17769550748752)

# %%
Affairs.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
Affairs.groupby('gender').groups.keys()
# Out:
# dict_keys(['female', 'male'])

# %%
Affairs.gender.nunique()#nunique desconsidera nulos
# Out:
# 2

# %%
len(Affairs.gender.unique())# conta os valores nulos
# Out:
# 2

# %%
seguro.charges.describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
seguro.region.describe()
# Out:
# count          1338
# unique            4
# top       southeast
# freq            364
# Name: region, dtype: object

# %% [markdown]
# ## Contagem de dados

# %%
AffairsContagem = Affairs.gender # series
AffairsContagem = AffairsContagem.to_list() # lista
AffairsContagem.count('female')
# Out:
# 315

# %%
##

# %% [markdown]
# # Propriedades do DF

# %% [markdown]
# ## Maiores e Menores Valores

# %%
display(Affairs.nsmallest(5,'yearsmarried'))
display(type(Affairs.nsmallest(5,'yearsmarried')))
Affairs_top3 = Affairs.nlargest(3,'yearsmarried')
Affairs_top3
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 72        378        0  female  22.0         0.125       no              2
# 102       515        0  female  22.0         0.125       no              4
# 126       630        0  female  22.0         0.125       no              2
# 171       807        0  female  22.0         0.125       no              4
# 175       830        0    male  32.0         0.125      yes              2
#
#      education  occupation  rating
# 72          12           5       5
# 102         12           4       5
# 126         14           4       5
# 171         14           4       5
# 175         18           5       2
# pandas.core.frame.DataFrame
#    rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 2        11        0  female  32.0          15.0      yes              1
# 3        16        0    male  57.0          15.0      yes              5
# 7        45        0    male  57.0          15.0      yes              2
#
#    education  occupation  rating
# 2         12           1       4
# 3         18           6       5
# 7         14           4       4

# %% [markdown]
# CUIDADO NÃO LEVA EM CONTA VALORES REPETIDOS

# %% [markdown]
# ## Ordenar dados do index

# %%
carros.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Veiculo
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
carros = carros.sort_index()
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %% [markdown]
# ## Tratamento de Nulos

# %%
financasAdjClose.isnull() # gera tabelas de vdd e falso para cada coluna
# Out:
# Ticker      BRL=X  ITUB4.SA  PETR4.SA  VALE3.SA  ^BVSP
# Date
# 2023-01-02  False     False     False     False  False
# 2023-01-03  False     False     False     False  False
# 2023-01-04  False     False     False     False  False
# 2023-01-05  False     False     False     False  False
# 2023-01-06  False     False     False     False  False
# ...           ...       ...       ...       ...    ...
# 2023-12-25  False      True      True      True   True
# 2023-12-26  False     False     False     False  False
# 2023-12-27  False     False     False     False  False
# 2023-12-28  False     False     False     False  False
# 2023-12-29  False      True      True      True   True
#
# [260 rows x 5 columns]

# %%
financasAdjClose.isnull().sum()
# Out:
# Ticker
# BRL=X        0
# ITUB4.SA    12
# PETR4.SA    12
# VALE3.SA    12
# ^BVSP       12
# dtype: int64

# %%
financasAdjClose[financasAdjClose["ITUB4.SA"].isnull() ]
# Out:
# Ticker         BRL=X  ITUB4.SA  PETR4.SA  VALE3.SA  ^BVSP
# Date
# 2023-02-20  5.165169       NaN       NaN       NaN    NaN
# 2023-02-21  5.166700       NaN       NaN       NaN    NaN
# 2023-04-07  5.058300       NaN       NaN       NaN    NaN
# 2023-04-21  5.047700       NaN       NaN       NaN    NaN
# 2023-05-01  4.986000       NaN       NaN       NaN    NaN
# 2023-06-08  4.922400       NaN       NaN       NaN    NaN
# 2023-09-07  4.977000       NaN       NaN       NaN    NaN
# 2023-10-12  5.049600       NaN       NaN       NaN    NaN
# 2023-11-02  4.953700       NaN       NaN       NaN    NaN
# 2023-11-15  4.864500       NaN       NaN       NaN    NaN
# 2023-12-25  4.869844       NaN       NaN       NaN    NaN
# 2023-12-29  4.850200       NaN       NaN       NaN    NaN

# %% [markdown]
# ## Percorrendo Colunas

# %%
for c in [ 'age', 'yearsmarried', 'education']:
  print(Affairs[c].mean())
# Out:
# 32.48752079866888
# 8.17769550748752
# 16.16638935108153

# %% [markdown]
# ## Iterando sobre as linhas `iterrows()`

# %%
for index, row in carros.iterrows():

  if row['disp'] > 450:
    print(row)
# Out:
# mpg       10.40
# cyl        8.00
# disp     472.00
# hp      2050.00
# drat       2.93
# wt         5.25
# qsec      17.98
# vs         0.00
# am         4.00
# gear       3.00
# carb       4.00
# kmpg      16.64
# Name: Cadillac Fleetwood, dtype: float64
# mpg       10.400
# cyl        8.000
# disp     460.000
# hp      2150.000
# drat       3.000
# wt         5.424
# qsec      17.820
# vs         0.000
# am         0.000
# gear       3.000
# carb       4.000
# kmpg      16.640
# Name: Lincoln Continental, dtype: float64

# %%
print(carros.mpg.sum())

for _, row in carros.iterrows():

  # print('before',row['mpg'])
  row['mpg'] = row['mpg'] + 1
  # print('after',row['mpg'])

print(carros.mpg.sum())
# Out:
# 642.9
# 642.9

# %%
for index, row in carros.iterrows():

  if row['disp'] > 450:
    print(row.name, 'mpg = ', row.mpg)
# Out:
# Cadillac Fleetwood mpg =  10.4
# Lincoln Continental mpg =  10.4

# %% [markdown]
# ## Criando uma Copia

# %%
Affairs2 = Affairs.copy()

# %% [markdown]
# ## Atualizando Valores

# %%
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb
# Veiculo
# AMC Javelin            2
# Cadillac Fleetwood     4
# Camaro Z28             4
# Chrysler Imperial      4
# Datsun 710             1

# %% [markdown]
# #### Nova Coluna

# %%
carros['kmpg'] = 1.6 * carros['mpg']
carros.head()
# Out:
#                      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
carros['hp'] = carros['hp'] * 10
carros.head()
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   0     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dolar_real_rate = 5.8
tips['total_bill'] = tips['total_bill'] * dolar_real_rate         # alterando
tips['tip'] = tips['tip'] * dolar_real_rate                       # alterando

tips['total_bill_minus_tips'] = tips['total_bill'] - tips['tip']    # incluindo um novo atributo
tips['bill_by_head'] = tips['total_bill'] / tips['size']            # incluindo um novo atributo
tips.head()
# Out:
#    total_bill     tip     sex smoker  day    time  size  \
# 0      98.542   5.858  Female     No  Sun  Dinner     2
# 1      59.972   9.628    Male     No  Sun  Dinner     3
# 2     121.858  20.300    Male     No  Sun  Dinner     3
# 3     137.344  19.198    Male     No  Sun  Dinner     2
# 4     142.622  20.938  Female     No  Sun  Dinner     4
#
#    total_bill_minus_tips  bill_by_head
# 0                 92.684     49.271000
# 1                 50.344     19.990667
# 2                101.558     40.619333
# 3                118.146     68.672000
# 4                121.684     35.655500

# %% [markdown]
# ##### Atualizando Valores Especificos

# %%
display(carros.loc[ 'Cadillac Fleetwood' , 'am' ])
carros.loc[ 'Cadillac Fleetwood' , 'am' ] = 1 # atualizando dado especifico
carros.head()
# Out:
# np.int64(0)
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   0     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   0     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48

# %%
carros.head(11)
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   1     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   1     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   1     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   1     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   1     4
# Dodge Challenger    15.5    8  318.0  1500  2.76  3.520  16.87   0   0     3
# Duster 360          14.3    8  360.0  2450  3.21  3.570  15.84   0   0     3
# Ferrari Dino        19.7    6  145.0  1750  3.62  2.770  15.50   0   1     5
# Fiat 128            32.4    4   78.7   660  4.08  2.200  19.47   1   1     4
# Fiat X1-9           27.3    4   79.0   660  4.08  1.935  18.90   1   1     4
# Ford Pantera L      15.8    8  351.0  2640  4.22  3.170  14.50   0   1     5
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
# Dodge Challenger       2  24.80
# Duster 360             4  22.88
# Ferrari Dino           6  31.52
# Fiat 128               1  51.84
# Fiat X1-9              1  43.68
# Ford Pantera L         4  25.28

# %%
carros.iloc[ 0:10 , 8 ] = 4 # linhas da 0-10 coluna 8 tudo fica = 1
carros.head(12)
# Out:
#                      mpg  cyl   disp    hp  drat     wt   qsec  vs  am  gear  \
# Veiculo
# AMC Javelin         15.2    8  304.0  1500  3.15  3.435  17.30   0   4     3
# Cadillac Fleetwood  10.4    8  472.0  2050  2.93  5.250  17.98   0   4     3
# Camaro Z28          13.3    8  350.0  2450  3.73  3.840  15.41   0   4     3
# Chrysler Imperial   14.7    8  440.0  2300  3.23  5.345  17.42   0   4     3
# Datsun 710          22.8    4  108.0   930  3.85  2.320  18.61   1   4     4
# Dodge Challenger    15.5    8  318.0  1500  2.76  3.520  16.87   0   4     3
# Duster 360          14.3    8  360.0  2450  3.21  3.570  15.84   0   4     3
# Ferrari Dino        19.7    6  145.0  1750  3.62  2.770  15.50   0   4     5
# Fiat 128            32.4    4   78.7   660  4.08  2.200  19.47   1   4     4
# Fiat X1-9           27.3    4   79.0   660  4.08  1.935  18.90   1   4     4
# Ford Pantera L      15.8    8  351.0  2640  4.22  3.170  14.50   0   1     5
# Honda Civic         30.4    4   75.7   520  4.93  1.615  18.52   1   1     4
#
#                     carb   kmpg
# Veiculo
# AMC Javelin            2  24.32
# Cadillac Fleetwood     4  16.64
# Camaro Z28             4  21.28
# Chrysler Imperial      4  23.52
# Datsun 710             1  36.48
# Dodge Challenger       2  24.80
# Duster 360             4  22.88
# Ferrari Dino           6  31.52
# Fiat 128               1  51.84
# Fiat X1-9              1  43.68
# Ford Pantera L         4  25.28
# Honda Civic            2  48.64

# %%
financasAdjClose.head()
# Out:
# Ticker         BRL=X   ITUB4.SA   PETR4.SA   VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  22.238420  16.037287  80.482178  106376.0
# 2023-01-03  5.360131  21.775312  15.631456  80.338135  104166.0
# 2023-01-04  5.478500  21.838877  16.128246  80.482178  105334.0
# 2023-01-05  5.430100  22.519920  16.709003  81.832550  107518.0
# 2023-01-06  5.349800  22.910389  16.611048  83.128906  108836.0

# %%
financasAdjClose
# Out:
# 'ITUB4.SA'

# %%
for column in ['ITUB4.SA', 'PETR4.SA', 'VALE3.SA']:
  financasAdjClose[column] = financasAdjClose[column] * financasAdjClose['BRL=X']

financasAdjClose.head()
# Out:
# /tmp/ipykernel_44578/970446959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financasAdjClose[column] = financasAdjClose[column] * financasAdjClose['BRL=X']
# Ticker         BRL=X    ITUB4.SA   PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  117.541173  84.765080  425.388554  106376.0
# 2023-01-03  5.360131  116.718523  83.786651  430.622910  104166.0
# 2023-01-04  5.478500  119.644284  88.358596  440.921602  105334.0
# 2023-01-05  5.430100  122.285419  90.731559  444.358927  107518.0
# 2023-01-06  5.349800  122.566001  88.865785  444.723032  108836.0

# %% [markdown]
# ## GroupBY

# %%
testeGroupby
# Out:
#      data
# key
# A       1
# B       2
# C       3
# A       4
# B       5
# C       6

# %%
testeGroupby.groupby(testeGroupby.index).sum()
# Out:
#      data
# key
# A       5
# B       7
# C       9

# %%
display( testeGroupby.groupby(testeGroupby.index).mean() )
display( testeGroupby.groupby(testeGroupby.index).std() )
display( testeGroupby.groupby(testeGroupby.index).min() )
display(testeGroupby.groupby(testeGroupby.index).sum())
# Out:
#      data
# key
# A     2.5
# B     3.5
# C     4.5
#         data
# key
# A    2.12132
# B    2.12132
# C    2.12132
#      data
# key
# A       1
# B       2
# C       3
#      data
# key
# A       5
# B       7
# C       9

# %%
Affairs2.groupby("gender")

# %%
Affairs2.groupby("gender").count()
# Out:
#         rownames  affairs  age  yearsmarried  children  religiousness  \
# gender
# female       315      315  315           315       315            315
# male         286      286  286           286       286            286
#
#         education  occupation  rating
# gender
# female        315         315     315
# male          286         286     286

# %%
Affairs2.groupby("gender").gender.count()
# Out:
# gender
# female    315
# male      286
# Name: gender, dtype: int64

# %%
Affairs2.loc[0,'gender'] = None

Affairs2.groupby('gender').gender.count()
# Out:
# gender
# female    315
# male      285
# Name: gender, dtype: int64

# %%
Affairs2.groupby('gender',dropna=False).gender.count()
# Out:
# gender
# female    315
# male      285
# NaN         0
# Name: gender, dtype: int64

# %%
fem = sum( seguro[seguro.sex == 'female'].charges )
print(f'Total dos Seguros (Mulheres):  {fem:.2f}')

masc = sum( seguro[seguro.sex == 'male'].charges )
print(f'Total dos Seguros (Homens):  {masc:.2f}')

seguro.groupby('sex').charges.sum()
# Out:
# Total dos Seguros (Mulheres):  8321061.19
# Total dos Seguros (Homens):  9434763.80
# sex
# female    8.321061e+06
# male      9.434764e+06
# Name: charges, dtype: float64

# %%
# 
fem = len( seguro[seguro.sex == 'female'] ) / len(seguro)
print(f'Percentual de Mulheres seguradas: {fem:.4f}')

masc = len( seguro[seguro.sex == 'male'] ) / len(seguro)
print(f'Percentual de Homens segurados: {masc:.4f}')
# Out:
# Percentual de Mulheres seguradas: 0.4948
# Percentual de Homens segurados: 0.5052

# %%
seguro.groupby('sex').sex.count() / seguro.sex.count()
# Out:
# sex
# female    0.494768
# male      0.505232
# Name: sex, dtype: float64

# %%
fem = sum( seguro[seguro.sex == 'female'].charges ) / sum( seguro.charges )
print(f'Total dos Seguros (Mulheres):  {fem:.2f}')

masc = sum( seguro[seguro.sex == 'male'].charges ) / sum( seguro.charges )
print(f'Total dos Seguros (Homens):  {masc:.2f}')
# Out:
# Total dos Seguros (Mulheres):  0.47
# Total dos Seguros (Homens):  0.53

# %%
seguro.groupby('sex').charges.sum() / seguro.charges.sum()
# Out:
# sex
# female    0.468638
# male      0.531362
# Name: charges, dtype: float64

# %%
seguro.groupby('smoker').children.mean()
# Out:
# smoker
# no     1.090226
# yes    1.113139
# Name: children, dtype: float64

# %%
seguro.groupby('smoker').children.mean().max()
# Out:
# np.float64(1.1131386861313868)

# %%
seguro.groupby('smoker').children.mean() >= seguro.groupby('smoker').children.mean().max()
# Out:
# smoker
# no     False
# yes     True
# Name: children, dtype: bool

# %%
carros2.groupby('Type').Price.mean()
# Out:
# Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64

# %%
carros2.groupby('Type').Price.count()
# Out:
# Type
# Compact    16
# Large      11
# Midsize    22
# Small      21
# Sporty     14
# Van         9
# Name: Price, dtype: int64

# %%
carros2.groupby('Type').Price.count().sort_index()
# Out:
# Type
# Compact    16
# Large      11
# Midsize    22
# Small      21
# Sporty     14
# Van         9
# Name: Price, dtype: int64

# %%
carros2.groupby('Type').Price.count().sort_values()
# Out:
# Type
# Van         9
# Large      11
# Sporty     14
# Compact    16
# Small      21
# Midsize    22
# Name: Price, dtype: int64

# %%
carros2.groupby('Type').Price.count().sort_values(ascending=False)
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Price, dtype: int64

# %%
carros2.Type.value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
carros2.groupby('Type')[['Price','MPG.city']].mean()
# Out:
#              Price   MPG.city
# Type
# Compact  18.212500  22.687500
# Large    24.300000  18.363636
# Midsize  27.218182  19.545455
# Small    10.166667  29.857143
# Sporty   19.392857  21.785714
# Van      19.100000  17.000000

# %%
carros2.groupby('Type').count()
# Out:
#          Manufacturer  Model  Min.Price  Price  Max.Price  MPG.city  \
# Type
# Compact            16     16         16     16         16        16
# Large              11     11         11     11         11        11
# Midsize            22     22         22     22         22        22
# Small              21     21         21     21         21        21
# Sporty             14     14         14     14         14        14
# Van                 9      9          9      9          9         9
#
#          MPG.highway  AirBags  DriveTrain  Cylinders  ...  Passengers  Length  \
# Type                                                  ...
# Compact           16       11          16         16  ...          16      16
# Large             11       11          11         11  ...          11      11
# Midsize           22       18          22         22  ...          22      22
# Small             21        5          21         21  ...          21      21
# Sporty            14       11          14         14  ...          14      14
# Van                9        3           9          9  ...           9       9
#
#          Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  Weight  \
# Type
# Compact         16     16           16              16            16      16
# Large           11     11           11              11            11      11
# Midsize         22     22           22              22            22      22
# Small           21     21           21              21            21      21
# Sporty          14     14           14              12            12      14
# Van              9      9            9               9             0       9
#
#          Origin  Make
# Type
# Compact      16    16
# Large        11    11
# Midsize      22    22
# Small        21    21
# Sporty       14    14
# Van           9     9
#
# [6 rows x 26 columns]

# %% [markdown]
# ### Agregação de mais níveis

# %%
carros2.groupby(['Type','DriveTrain']).Price.mean()
# Out:
# Type     DriveTrain
# Compact  4WD           19.500000
#          Front         16.715385
#          Rear          27.300000
# Large    Front         23.971429
#          Rear          24.875000
# Midsize  Front         24.052941
#          Rear          37.980000
# Small    4WD            9.650000
#          Front         10.221053
# Sporty   4WD           20.100000
#          Front         16.014286
#          Rear          23.840000
# Van      4WD           19.460000
#          Front         18.650000
# Name: Price, dtype: float64

# %%
carros2.groupby(['Type','DriveTrain']).Price.mean()['Compact']
# Out:
# DriveTrain
# 4WD      19.500000
# Front    16.715385
# Rear     27.300000
# Name: Price, dtype: float64

# %%
carros2.groupby(['Type','DriveTrain']).Price.mean().unstack() ## Unstack faz o filtro (groupby) ficar em coluna
# Out:
# DriveTrain    4WD      Front    Rear
# Type
# Compact     19.50  16.715385  27.300
# Large         NaN  23.971429  24.875
# Midsize       NaN  24.052941  37.980
# Small        9.65  10.221053     NaN
# Sporty      20.10  16.014286  23.840
# Van         19.46  18.650000     NaN

# %% [markdown]
# ### . AGG()

# %%
display(testeGroupby.groupby(testeGroupby.index).agg(['mean', 'std', 'min']))
display( testeGroupby.groupby(testeGroupby.index).mean() )
display( testeGroupby.groupby(testeGroupby.index).std() )
display( testeGroupby.groupby(testeGroupby.index).min() )
display(testeGroupby.groupby(testeGroupby.index).sum())
# Out:
#     data
#     mean      std min
# key
# A    2.5  2.12132   1
# B    3.5  2.12132   2
# C    4.5  2.12132   3
#      data
# key
# A     2.5
# B     3.5
# C     4.5
#         data
# key
# A    2.12132
# B    2.12132
# C    2.12132
#      data
# key
# A       1
# B       2
# C       3
#      data
# key
# A       5
# B       7
# C       9

# %%
display( pedidos.groupby('Itens')['Quantidade'].agg(['mean', 'std', 'min', 'count']) )
carros2.groupby('Type').Price.agg(['mean','std'])
# Out:
#                      mean       std  min  count
# Itens
# Boné             1.000000       NaN    1      1
# Camiseta         1.666667  1.154701    1      3
# Keds             3.000000       NaN    3      1
# Tênis Caminhada  2.000000  0.000000    2      3
# Tênis Corrida    1.000000       NaN    1      1
#               mean        std
# Type
# Compact  18.212500   6.686890
# Large    24.300000   6.337507
# Midsize  27.218182  12.264841
# Small    10.166667   1.953288
# Sporty   19.392857   7.974716
# Van      19.100000   1.878164

# %%
display( pedidos.groupby( ['Itens','Pedido'] ).agg(['min','max']) )
# Out:
#                        Preco Unidade      Quantidade
#                                  min  max        min max
# Itens           Pedido
# Boné            2                 60   60          1   1
# Camiseta        1                 90   90          3   3
#                 2                 90   90          1   1
#                 3                 90   90          1   1
# Keds            2                250  250          3   3
# Tênis Caminhada 1                250  250          2   2
#                 2                250  250          2   2
#                 3                250  250          2   2
# Tênis Corrida   1                300  300          1   1

# %% [markdown]
# ### diferentes agregadores

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'Price': 'mean', 'MPG.city': 'max' })
# Out:
#              Price  MPG.city
# Type
# Compact  18.212500        26
# Large    24.300000        20
# Midsize  27.218182        23
# Small    10.166667        46
# Sporty   19.392857        30
# Van      19.100000        18

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'Price': ['mean', 'std'], 'MPG.city': 'max' })
# Out:
#              Price            MPG.city
#               mean        std      max
# Type
# Compact  18.212500   6.686890       26
# Large    24.300000   6.337507       20
# Midsize  27.218182  12.264841       23
# Small    10.166667   1.953288       46
# Sporty   19.392857   7.974716       30
# Van      19.100000   1.878164       18

# %% [markdown]
# ### Aggregate user functions

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'Price': ['mean', 'std'], 'MPG.city': lambda x: x.max() - x.min() })
# Out:
#              Price            MPG.city
#               mean        std <lambda>
# Type
# Compact  18.212500   6.686890        6
# Large    24.300000   6.337507        4
# Midsize  27.218182  12.264841        7
# Small    10.166667   1.953288       24
# Sporty   19.392857   7.974716       13
# Van      19.100000   1.878164        3

# %%
carros2.groupby('Type')[['Price','MPG.city']].agg({ 'MPG.city': ["max","min",lambda x: x.max() - x.min() ]})
# Out:
#         MPG.city
#              max min <lambda_0>
# Type
# Compact       26  20          6
# Large         20  16          4
# Midsize       23  16          7
# Small         46  22         24
# Sporty        30  17         13
# Van           18  15          3

# %% [markdown]
# ### Interando grupos

# %%
for (Type, group) in carros2.groupby('Type'):
    print("{0:30s} shape={1}".format(Type, group.shape))
# Out:
# Compact                        shape=(16, 27)
# Large                          shape=(11, 27)
# Midsize                        shape=(22, 27)
# Small                          shape=(21, 27)
# Sporty                         shape=(14, 27)
# Van                            shape=(9, 27)

# %%
group_list = []

for (Type, group) in carros2.groupby('Type'):
    group_list.append(group)

# %%
group_list[0]
# Out:
#      Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 3            Audi        90  Compact       25.9   29.1       32.3        20
# 12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 13      Chevrolet   Corsica  Compact       11.4   11.4       11.4        25
# 21       Chrysler   LeBaron  Compact       14.5   15.8       17.1        23
# 25          Dodge    Spirit  Compact       11.9   13.3       14.7        22
# 33           Ford     Tempo  Compact       10.4   11.3       12.2        22
# 43          Honda    Accord  Compact       13.8   17.5       21.2        24
# 55          Mazda       626  Compact       14.3   16.5       18.7        26
# 58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9        20
# 65         Nissan    Altima  Compact       13.0   15.7       18.3        24
# 68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 74        Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
# 78           Saab       900  Compact       20.3   28.7       37.1        20
# 82         Subaru    Legacy  Compact       16.3   19.5       22.7        23
# 90     Volkswagen    Passat  Compact       17.6   20.0       22.4        21
# 92          Volvo       240  Compact       21.8   22.7       23.5        21
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
#                                                 ...
# 3            26         Driver only      Front  ...          5     180
# 12           36                 NaN      Front  ...          5     182
# 13           34         Driver only      Front  ...          5     184
# 21           28  Driver & Passenger      Front  ...          6     183
# 25           27         Driver only      Front  ...          6     181
# 33           27                 NaN      Front  ...          5     177
# 43           31  Driver & Passenger      Front  ...          4     185
# 55           34         Driver only      Front  ...          5     184
# 58           29         Driver only       Rear  ...          5     175
# 65           30         Driver only      Front  ...          5     181
# 68           31                 NaN      Front  ...          5     188
# 74           31                 NaN      Front  ...          5     181
# 78           26         Driver only      Front  ...          5     184
# 82           30         Driver only        4WD  ...          5     179
# 90           30                 NaN      Front  ...          5     180
# 92           28         Driver only       Rear  ...          5     190
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
#
# 3         102     67           37           28.0          14.0    3375
# 12        101     66           38           25.0          13.0    2490
# 13        103     68           39           26.0          14.0    2785
# 21        104     68           41           30.5          14.0    3085
# 25        104     68           39           30.5          14.0    2970
# 33        100     68           39           27.5          13.0    2690
# 43        107     67           41           28.0          14.0    3040
# 55        103     69           40           29.5          14.0    2970
# 58        105     67           34           26.0          12.0    2920
# 65        103     67           40           28.5          14.0    3050
# 68        103     67           39           28.0          14.0    2910
# 74        101     66           39           25.0          13.0    2575
# 78         99     67           37           26.5          14.0    2775
# 82        102     67           37           27.0          14.0    3085
# 90        103     67           35           31.5          14.0    2985
# 92        104     67           37           29.5          14.0    2985
#
#      Origin                Make
#
# 3   non-USA             Audi 90
# 12      USA  Chevrolet Cavalier
# 13      USA   Chevrolet Corsica
# 21      USA    Chrysler LeBaron
# 25      USA        Dodge Spirit
# 33      USA          Ford Tempo
# 43  non-USA        Honda Accord
# 55  non-USA           Mazda 626
# 58  non-USA  Mercedes-Benz 190E
# 65  non-USA       Nissan Altima
# 68      USA  Oldsmobile Achieva
# 74      USA     Pontiac Sunbird
# 78  non-USA            Saab 900
# 82  non-USA       Subaru Legacy
# 90  non-USA   Volkswagen Passat
# 92  non-USA           Volvo 240
#
# [16 rows x 27 columns]

# %%
group_list[1]
# Out:
#    Manufacturer           Model   Type  Min.Price  Price  Max.Price  MPG.city  \
#
# 7         Buick         LeSabre  Large       19.9   20.8       21.7        19
# 8         Buick      Roadmaster  Large       22.6   23.7       24.9        16
# 10     Cadillac         DeVille  Large       33.0   34.7       36.3        16
# 18    Chevrolet         Caprice  Large       18.0   18.8       19.6        17
# 20     Chrylser        Concorde  Large       18.4   18.4       18.4        20
# 22     Chrysler        Imperial  Large       29.5   29.5       29.5        20
# 30        Eagle          Vision  Large       17.5   19.3       21.2        20
# 38         Ford  Crown_Victoria  Large       20.1   20.9       21.7        18
# 52      Lincoln        Town_Car  Large       34.4   36.1       37.8        18
# 71   Oldsmobile    Eighty-Eight  Large       19.5   20.7       21.9        19
# 77      Pontiac      Bonneville  Large       19.4   24.4       29.4        19
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
#                                                 ...
# 7            28         Driver only      Front  ...          6     200
# 8            25         Driver only       Rear  ...          6     216
# 10           25         Driver only      Front  ...          6     206
# 18           26         Driver only       Rear  ...          6     214
# 20           28  Driver & Passenger      Front  ...          6     203
# 22           26         Driver only      Front  ...          6     203
# 30           28  Driver & Passenger      Front  ...          6     202
# 38           26         Driver only       Rear  ...          6     212
# 52           26  Driver & Passenger       Rear  ...          6     219
# 71           28         Driver only      Front  ...          6     201
# 77           28  Driver & Passenger      Front  ...          6     177
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
#
# 7         111     74           42           30.5          17.0    3470
# 8         116     78           45           30.5          21.0    4105
# 10        114     73           43           35.0          18.0    3620
# 18        116     77           42           29.5          20.0    3910
# 20        113     74           40           31.0          15.0    3515
# 22        110     69           44           36.0          17.0    3570
# 30        113     74           40           30.0          15.0    3490
# 38        114     78           43           30.0          21.0    3950
# 52        117     77           45           31.5          22.0    4055
# 71        111     74           42           31.5          17.0    3470
# 77        111     74           43           30.5          18.0    3495
#
#     Origin                     Make
#
# 7      USA            Buick LeSabre
# 8      USA         Buick Roadmaster
# 10     USA         Cadillac DeVille
# 18     USA        Chevrolet Caprice
# 20     USA        Chrylser Concorde
# 22     USA        Chrysler Imperial
# 30     USA             Eagle Vision
# 38     USA      Ford Crown_Victoria
# 52     USA         Lincoln Town_Car
# 71     USA  Oldsmobile Eighty-Eight
# 77     USA       Pontiac Bonneville
#
# [11 rows x 27 columns]

# %%
grupos_itens = carros2.groupby('Type')
print ( grupos_itens )
print ( grupos_itens.groups )
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x789b1a98d310>
# {'Compact': [3, 12, 13, 21, 25, 33, 43, 55, 58, 65, 68, 74, 78, 82, 90, 92], 'Large': [7, 8, 10, 18, 20, 22, 30, 38, 52, 71, 77], 'Midsize': [2, 4, 5, 6, 9, 11, 15, 27, 37, 47, 48, 49, 50, 51, 59, 61, 63, 67, 69, 76, 86, 93], 'Small': [1, 23, 24, 29, 31, 32, 39, 42, 44, 45, 53, 54, 62, 64, 73, 79, 80, 81, 83, 84, 88], 'Sporty': [14, 19, 28, 34, 35, 40, 41, 46, 57, 60, 72, 75, 85, 91], 'Van': [16, 17, 26, 36, 56, 66, 70, 87, 89]}

# %%
print ( grupos_itens.groups.keys() )
print ( grupos_itens.groups.values() )
# Out:
# dict_keys(['Compact', 'Large', 'Midsize', 'Small', 'Sporty', 'Van'])
# dict_values([Index([3, 12, 13, 21, 25, 33, 43, 55, 58, 65, 68, 74, 78, 82, 90, 92], dtype='int64', name=''), Index([7, 8, 10, 18, 20, 22, 30, 38, 52, 71, 77], dtype='int64', name=''), Index([ 2,  4,  5,  6,  9, 11, 15, 27, 37, 47, 48, 49, 50, 51, 59, 61, 63, 67,
#        69, 76, 86, 93],
#       dtype='int64', name=''), Index([ 1, 23, 24, 29, 31, 32, 39, 42, 44, 45, 53, 54, 62, 64, 73, 79, 80, 81,
#        83, 84, 88],
#       dtype='int64', name=''), Index([14, 19, 28, 34, 35, 40, 41, 46, 57, 60, 72, 75, 85, 91], dtype='int64', name=''), Index([16, 17, 26, 36, 56, 66, 70, 87, 89], dtype='int64', name='')])

# %%
grupos_itens15up = carros2.groupby('Type').filter(lambda x: len(x) > 15)
# grupos_itens15up
grupos_itens15up.groupby('Type').Type.count()
# Out:
# Type
# Compact    16
# Midsize    22
# Small      21
# Name: Type, dtype: int64

# %%
a = carros2.groupby('Type').Type.count() > 15
a[ a ].index
# Out:
# Index(['Compact', 'Midsize', 'Small'], dtype='object', name='Type')

# %%
for chave in pedidos.groupby('Itens').groups.keys():
  print(chave)

# que é o mesmo que,
#
# for chave in grupos_itens.groups.keys():
#  print(chave)
print("--------------------------")
for chave, grupo in pedidos.groupby('Itens'):
  print(chave)
  print(grupo)
# Out:
# Boné
# Camiseta
# Keds
# Tênis Caminhada
# Tênis Corrida
# --------------------------
# Boné
#    Pedido Itens  Preco Unidade  Quantidade
# 5       2  Boné             60           1
# Camiseta
#    Pedido     Itens  Preco Unidade  Quantidade
# 2       1  Camiseta             90           3
# 4       2  Camiseta             90           1
# 8       3  Camiseta             90           1
# Keds
#    Pedido Itens  Preco Unidade  Quantidade
# 6       2  Keds            250           3
# Tênis Caminhada
#    Pedido            Itens  Preco Unidade  Quantidade
# 1       1  Tênis Caminhada            250           2
# 3       2  Tênis Caminhada            250           2
# 7       3  Tênis Caminhada            250           2
# Tênis Corrida
#    Pedido          Itens  Preco Unidade  Quantidade
# 0       1  Tênis Corrida            300           1

# %% [markdown]
# ## Transformar agrupamento em df

# %%
df_do_agrupamento = pd.DataFrame( pedidos.groupby('Itens')[['Quantidade','Preco Unidade']].sum() ).reset_index()
df_do_agrupamento.head()
# Out:
#              Itens  Quantidade  Preco Unidade
# 0             Boné           1             60
# 1         Camiseta           5            270
# 2             Keds           3            250
# 3  Tênis Caminhada           6            750
# 4    Tênis Corrida           1            300

# %% [markdown]
# ## Apply

# %%
seguro.groupby('sex').charges.sum()
# Out:
# sex
# female    8.321061e+06
# male      9.434764e+06
# Name: charges, dtype: float64

# %%
'{:.2f}'.format(8.321061e+06)
# Out:
# '8321061.00'

# %%
seguro.groupby('sex').charges.sum().apply(lambda x: '{:.2f}'.format(x))
# Out:
# sex
# female    8321061.19
# male      9434763.80
# Name: charges, dtype: object

# %%
def converte_horas(minutos):
  return minutos / 60

filme.duration.apply(converte_horas)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
filme.duration.apply(lambda x: x/60)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
display('{:.2f}'.format(8.321061e+06))
print("__________________")
display(seguro.groupby('sex').charges.sum())
print("__________________")
display(seguro.groupby('sex').charges.sum().apply(lambda x: '{:.2f}'.format(x)))
# Out:
# '8321061.00'
# __________________
# sex
# female    8.321061e+06
# male      9.434764e+06
# Name: charges, dtype: float64
# __________________
# sex
# female    8321061.19
# male      9434763.80
# Name: charges, dtype: object

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
def pega_ano(lista):
  try:
    return lista[-1]
  except:
    return None
  
def pega_ano2(string):
  anos = set(["2016","2017","2018"])
  try:
    if string[-5:-1] in anos:
      return string[-5:-1]
  except:
    return None
  
filmes.title.apply(pega_ano2).count() #Qual a soma total dos títulos de 2016, 2017 e 2018?
# Out:
# np.int64(406)

# %%
filmes.title.apply(pega_ano2)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 9713    2017
# 9714    2017
# 9715    2017
# 9716    2018
# 9717    None
# Name: title, Length: 9718, dtype: object

# %%
filmes.title.str.split()
# Out:
# 0                                    [Toy, Story, (1995)]
# 1                                       [Jumanji, (1995)]
# 2                            [Grumpier, Old, Men, (1995)]
# 3                           [Waiting, to, Exhale, (1995)]
# 4              [Father, of, the, Bride, Part, II, (1995)]
#                               ...
# 9713    [Black, Butler:, Book, of, the, Atlantic, (2017)]
# 9714                  [No, Game, No, Life:, Zero, (2017)]
# 9715                                      [Flint, (2017)]
# 9716           [Bungo, Stray, Dogs:, Dead, Apple, (2018)]
# 9717           [Andrew, Dice, Clay:, Dice, Rules, (1991)]
# Name: title, Length: 9718, dtype: object

# %%
filmes.title.str.split().apply(pega_ano)
# Out:
# 0       (1995)
# 1       (1995)
# 2       (1995)
# 3       (1995)
# 4       (1995)
#          ...
# 9713    (2017)
# 9714    (2017)
# 9715    (2017)
# 9716    (2018)
# 9717    (1991)
# Name: title, Length: 9718, dtype: object

# %%
def decada(string):
  try:
    ano = int( string[-5:-1])
    divisaoInteira = ano//10
    return divisaoInteira*10
  except:
    return None

# %%
filmes["decada2"] = filmes.title.apply(decada)
filmes.groupby("decada2").count()
# Out:
#          movieId  title  genres
# decada2
# 1900           3      3       3
# 1910           7      7       7
# 1920          37     37      37
# 1930         136    136     136
# 1940         197    197     197
# 1950         279    279     279
# 1960         401    401     401
# 1970         499    499     499
# 1980        1177   1177    1177
# 1990        2209   2209    2209
# 2000        2846   2846    2846
# 2010        1927   1927    1927

# %%
def getYear(string):
    # return int( string[-5:-1])
    return string[-5:-1]
filmes["year"] = filmes.title.apply(getYear)
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995

# %% [markdown]
# ### Apply over row

# %%
filme.apply(lambda x: x.duration/60,axis=1)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Length: 4916, dtype: float64

# %%
def score_director(num_critic_for_reviews,director_facebook_likes):

  if director_facebook_likes > 0:
    return num_critic_for_reviews * director_facebook_likes
  else:
    return num_critic_for_reviews
  
filme.apply(lambda row: score_director(row.num_critic_for_reviews,row.director_facebook_likes), axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %%
def score_director(row):

  if row.director_facebook_likes > 0:
    return row.num_critic_for_reviews * row.director_facebook_likes
  else:
    return row.num_critic_for_reviews
  
filme.apply(lambda row: score_director(row), axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %%
filme.apply(score_director,axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %% [markdown]
# ##### gerar coluna do primeiro nome com apply

# %%
filme.director_name.str.split()
# Out:
# 0           [James, Cameron]
# 1          [Gore, Verbinski]
# 2              [Sam, Mendes]
# 3       [Christopher, Nolan]
# 4             [Doug, Walker]
#                 ...
# 4911          [Scott, Smith]
# 4912                     NaN
# 4913     [Benjamin, Roberds]
# 4914          [Daniel, Hsia]
# 4915             [Jon, Gunn]
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.split().isnull().sum()
# Out:
# np.int64(102)

# %%
def extrai_primeiro(lista):
  if isinstance(lista,list):
    return lista[0]
  else:
    return None
def extrai_primeiro(lista):
  try:
    return lista[0]
  except:
    return None
  
filme.director_name.str.split().apply(extrai_primeiro)
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912           None
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.split().apply(lambda lista: lista[0] if isinstance(lista, list) else None)
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912           None
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: director_name, Length: 4916, dtype: object

# %% [markdown]
# # Strings

# %%
filme.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
#
# [3 rows x 28 columns]

# %%
filme.director_name.str.upper()
# Out:
# 0           JAMES CAMERON
# 1          GORE VERBINSKI
# 2              SAM MENDES
# 3       CHRISTOPHER NOLAN
# 4             DOUG WALKER
#               ...
# 4911          SCOTT SMITH
# 4912                  NaN
# 4913     BENJAMIN ROBERDS
# 4914          DANIEL HSIA
# 4915             JON GUNN
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.len()
# Out:
# 0       13.0
# 1       14.0
# 2       10.0
# 3       17.0
# 4       11.0
#         ...
# 4911    11.0
# 4912     NaN
# 4913    16.0
# 4914    11.0
# 4915     8.0
# Name: director_name, Length: 4916, dtype: float64

# %%
texto= "ana|helena|Marcacini"
display(len(texto.split("|")))
texto.split("|")
# Out:
# 3
# ['ana', 'helena', 'Marcacini']

# %%
display(filmes.head(1))
# filmes['genres'].str.count("\|")
filmes['genres'].str.count("|")
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0       44
# 1       27
# 2       15
# 3       21
# 4        7
#         ..
# 9713    32
# 9714    25
# 9715     6
# 9716    17
# 9717     7
# Name: genres, Length: 9718, dtype: int64

# %% [markdown]
# ## Split

# %%
filme.director_name.str.split()
# Out:
# 0           [James, Cameron]
# 1          [Gore, Verbinski]
# 2              [Sam, Mendes]
# 3       [Christopher, Nolan]
# 4             [Doug, Walker]
#                 ...
# 4911          [Scott, Smith]
# 4912                     NaN
# 4913     [Benjamin, Roberds]
# 4914          [Daniel, Hsia]
# 4915             [Jon, Gunn]
# Name: director_name, Length: 4916, dtype: object

# %%
filme.director_name.str.split(expand=True)
# Out:
#                 0          1     2     3
# 0           James    Cameron  None  None
# 1            Gore  Verbinski  None  None
# 2             Sam     Mendes  None  None
# 3     Christopher      Nolan  None  None
# 4            Doug     Walker  None  None
# ...           ...        ...   ...   ...
# 4911        Scott      Smith  None  None
# 4912          NaN        NaN   NaN   NaN
# 4913     Benjamin    Roberds  None  None
# 4914       Daniel       Hsia  None  None
# 4915          Jon       Gunn  None  None
#
# [4916 rows x 4 columns]

# %%
filme['director_first_name'] = filme.director_name.str.split(expand=True)[0]
filme.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   language country  content_rating       budget title_year  \
# 0  English     USA           PG-13  237000000.0     2009.0
# 1  English     USA           PG-13  300000000.0     2007.0
# 2  English      UK           PG-13  245000000.0     2015.0
# 3  English     USA           PG-13  250000000.0     2012.0
# 4      NaN     NaN             NaN          NaN        NaN
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                   936.0        7.9         1.78                 33000
# 1                  5000.0        7.1         2.35                     0
# 2                   393.0        6.8         2.35                 85000
# 3                 23000.0        8.5         2.35                164000
# 4                    12.0        7.1          NaN                     0
#
#   director_first_name
# 0               James
# 1                Gore
# 2                 Sam
# 3         Christopher
# 4                Doug
#
# [5 rows x 29 columns]

# %%
filmes
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9713   193581  Black Butler: Book of the Atlantic (2017)
# 9714   193583               No Game No Life: Zero (2017)
# 9715   193585                               Flint (2017)
# 9716   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9717   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  decada2
# 0     Adventure|Animation|Children|Comedy|Fantasy     1990
# 1                      Adventure|Children|Fantasy     1990
# 2                                  Comedy|Romance     1990
# 3                            Comedy|Drama|Romance     1990
# 4                                          Comedy     1990
# ...                                           ...      ...
# 9713              Action|Animation|Comedy|Fantasy     2010
# 9714                     Animation|Comedy|Fantasy     2010
# 9715                                        Drama     2010
# 9716                             Action|Animation     2010
# 9717                                       Comedy     1990
#
# [9718 rows x 4 columns]

# %%
filmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9718 entries, 0 to 9717
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9718 non-null   int64
#  1   title    9718 non-null   object
#  2   genres   9718 non-null   object
#  3   decada2  9718 non-null   int64
#  4   year     9718 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 379.7+ KB

# %%
filmes["decade_jeito_Feio"] = filmes["year"].str[:3] + "0"
filmes["decade_jeito_Feio"].value_counts()
# Out:
# decade_jeito_Feio
# 2000    2846
# 1990    2209
# 2010    1927
# 1980    1177
# 1970     499
# 1960     401
# 1950     279
# 1940     197
# 1930     136
# 1920      37
# 1910       7
# 1900       3
# Name: count, dtype: int64

# %% [markdown]
# ## Consultas

# %%
filme[ filme.director_name.str.contains('Chris',na=False) ]
# Out:
#       color             director_name  num_critic_for_reviews  duration  \
# 3     Color         Christopher Nolan                   813.0     164.0
# 24    Color               Chris Weitz                   251.0     113.0
# 66    Color         Christopher Nolan                   645.0     152.0
# 96    Color         Christopher Nolan                   712.0     169.0
# 97    Color         Christopher Nolan                   642.0     148.0
# ...     ...                       ...                     ...       ...
# 4576  Color        Christopher Hutson                     8.0      95.0
# 4586  Color  Christopher Scott Cherot                    25.0      84.0
# 4589  Color              Chris Atkins                    21.0     103.0
# 4614  Color              Chris Kentis                   235.0      79.0
# 4791  Color              Chris Marker                    16.0      59.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 3                     22000.0                 23000.0        Christian Bale
# 24                      129.0                  1000.0             Eva Green
# 66                    22000.0                 11000.0          Heath Ledger
# 96                    22000.0                  6000.0         Anne Hathaway
# 97                    22000.0                 23000.0             Tom Hardy
# ...                       ...                     ...                   ...
# 4576                      3.0                   118.0  Jennifer Lee Wiggins
# 4586                     21.0                    48.0           Robinne Lee
# 4589                      2.0                   442.0      Harvey Weinstein
# 4614                      9.0                     7.0            Saul Stein
# 4791                    121.0                     0.0       Bertrand Cantat
#
#       actor_1_facebook_likes        gross  \
# 3                    27000.0  448130642.0
# 24                   16000.0   70083519.0
# 66                   23000.0  533316061.0
# 96                   11000.0  187991439.0
# 97                   29000.0  292568851.0
# ...                      ...          ...
# 4576                   717.0          NaN
# 4586                   465.0    2301777.0
# 4589                   628.0          NaN
# 4614                    48.0   30500882.0
# 4791                    27.0          NaN
#
#                                          genres  ... num_user_for_reviews  \
# 3                               Action|Thriller  ...               2701.0
# 24                     Adventure|Family|Fantasy  ...                666.0
# 66                  Action|Crime|Drama|Thriller  ...               4667.0
# 96                       Adventure|Drama|Sci-Fi  ...               2725.0
# 97             Action|Adventure|Sci-Fi|Thriller  ...               2803.0
# ...                                         ...  ...                  ...
# 4576                                     Horror  ...                 30.0
# 4586                                     Comedy  ...                 36.0
# 4589                                Documentary  ...                  8.0
# 4614  Adventure|Biography|Drama|Horror|Thriller  ...                916.0
# 4791                                Documentary  ...                  4.0
#
#      language  country  content_rating       budget  title_year  \
# 3     English      USA           PG-13  250000000.0      2012.0
# 24    English      USA           PG-13  180000000.0      2007.0
# 66    English      USA           PG-13  185000000.0      2008.0
# 96    English      USA           PG-13  165000000.0      2014.0
# 97    English      USA           PG-13  160000000.0      2010.0
# ...       ...      ...             ...          ...         ...
# 4576  English      USA               R     750000.0      2009.0
# 4586  English      USA               R     650000.0      1997.0
# 4589  English       UK             NaN     400000.0      2009.0
# 4614  English      USA               R     500000.0      2003.0
# 4791   French   France             NaN     150000.0      2004.0
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 3                   23000.0        8.5          2.35               164000
# 24                   6000.0        6.1          2.35                    0
# 66                  13000.0        9.0          2.35                37000
# 96                  11000.0        8.6          2.35               349000
# 97                  27000.0        8.8          2.35               175000
# ...                     ...        ...           ...                  ...
# 4576                  134.0        3.1          1.85                  128
# 4586                  170.0        6.5           NaN                  161
# 4589                  474.0        7.4           NaN                  203
# 4614                   10.0        5.7          1.85                    0
# 4791                    0.0        7.4          1.37                   44
#
# [91 rows x 28 columns]

# %%
filme.director_name.str.find('Chris')
# Out:
# 0      -1.0
# 1      -1.0
# 2      -1.0
# 3       0.0
# 4      -1.0
#        ...
# 4911   -1.0
# 4912    NaN
# 4913   -1.0
# 4914   -1.0
# 4915   -1.0
# Name: director_name, Length: 4916, dtype: float64

# %%
filme[ filme.director_name.str.find('Chris') >= 0 ]
# Out:
#       color             director_name  num_critic_for_reviews  duration  \
# 3     Color         Christopher Nolan                   813.0     164.0
# 24    Color               Chris Weitz                   251.0     113.0
# 66    Color         Christopher Nolan                   645.0     152.0
# 96    Color         Christopher Nolan                   712.0     169.0
# 97    Color         Christopher Nolan                   642.0     148.0
# ...     ...                       ...                     ...       ...
# 4576  Color        Christopher Hutson                     8.0      95.0
# 4586  Color  Christopher Scott Cherot                    25.0      84.0
# 4589  Color              Chris Atkins                    21.0     103.0
# 4614  Color              Chris Kentis                   235.0      79.0
# 4791  Color              Chris Marker                    16.0      59.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 3                     22000.0                 23000.0        Christian Bale
# 24                      129.0                  1000.0             Eva Green
# 66                    22000.0                 11000.0          Heath Ledger
# 96                    22000.0                  6000.0         Anne Hathaway
# 97                    22000.0                 23000.0             Tom Hardy
# ...                       ...                     ...                   ...
# 4576                      3.0                   118.0  Jennifer Lee Wiggins
# 4586                     21.0                    48.0           Robinne Lee
# 4589                      2.0                   442.0      Harvey Weinstein
# 4614                      9.0                     7.0            Saul Stein
# 4791                    121.0                     0.0       Bertrand Cantat
#
#       actor_1_facebook_likes        gross  \
# 3                    27000.0  448130642.0
# 24                   16000.0   70083519.0
# 66                   23000.0  533316061.0
# 96                   11000.0  187991439.0
# 97                   29000.0  292568851.0
# ...                      ...          ...
# 4576                   717.0          NaN
# 4586                   465.0    2301777.0
# 4589                   628.0          NaN
# 4614                    48.0   30500882.0
# 4791                    27.0          NaN
#
#                                          genres  ... num_user_for_reviews  \
# 3                               Action|Thriller  ...               2701.0
# 24                     Adventure|Family|Fantasy  ...                666.0
# 66                  Action|Crime|Drama|Thriller  ...               4667.0
# 96                       Adventure|Drama|Sci-Fi  ...               2725.0
# 97             Action|Adventure|Sci-Fi|Thriller  ...               2803.0
# ...                                         ...  ...                  ...
# 4576                                     Horror  ...                 30.0
# 4586                                     Comedy  ...                 36.0
# 4589                                Documentary  ...                  8.0
# 4614  Adventure|Biography|Drama|Horror|Thriller  ...                916.0
# 4791                                Documentary  ...                  4.0
#
#      language  country  content_rating       budget  title_year  \
# 3     English      USA           PG-13  250000000.0      2012.0
# 24    English      USA           PG-13  180000000.0      2007.0
# 66    English      USA           PG-13  185000000.0      2008.0
# 96    English      USA           PG-13  165000000.0      2014.0
# 97    English      USA           PG-13  160000000.0      2010.0
# ...       ...      ...             ...          ...         ...
# 4576  English      USA               R     750000.0      2009.0
# 4586  English      USA               R     650000.0      1997.0
# 4589  English       UK             NaN     400000.0      2009.0
# 4614  English      USA               R     500000.0      2003.0
# 4791   French   France             NaN     150000.0      2004.0
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 3                   23000.0        8.5          2.35               164000
# 24                   6000.0        6.1          2.35                    0
# 66                  13000.0        9.0          2.35                37000
# 96                  11000.0        8.6          2.35               349000
# 97                  27000.0        8.8          2.35               175000
# ...                     ...        ...           ...                  ...
# 4576                  134.0        3.1          1.85                  128
# 4586                  170.0        6.5           NaN                  161
# 4589                  474.0        7.4           NaN                  203
# 4614                   10.0        5.7          1.85                    0
# 4791                    0.0        7.4          1.37                   44
#
# [91 rows x 28 columns]

# %% [markdown]
# ## Expressão Regular

# %%
inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") # Selecionar somente os registros com date no formato 9999-99-99
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_44578/1607281902.py:1: SyntaxWarning: invalid escape sequence '\d'
#   inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") # Selecionar somente os registros com date no formato 9999-99-99
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Date, Length: 500, dtype: bool

# %%
inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$").unique()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_44578/2762057805.py:1: SyntaxWarning: invalid escape sequence '\d'
#   inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$").unique()
# array([ True, False])

# %%
inspecao[(inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") == False)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_44578/4287755677.py:1: SyntaxWarning: invalid escape sequence '\d'
#   inspecao[(inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") == False)]
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %%
inspecao[ inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ] # datas no formato correto
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_44578/2347971979.py:1: SyntaxWarning: invalid escape sequence '\d'
#   inspecao[ inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ] # datas no formato correto
#                               Name        Date         Info  \
# 0                E & E Grill House  2017-08-08      Borough
# 1                E & E Grill House  2017-08-08      Cuisine
# 2                E & E Grill House  2017-08-08  Description
# 3                E & E Grill House  2017-08-08        Grade
# 4                E & E Grill House  2017-08-08        Score
# ..                             ...         ...          ...
# 495  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01      Borough
# 496  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01      Cuisine
# 497  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01  Description
# 498  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01        Grade
# 499  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01        Score
#
#                                                  Value
# 0                                            MANHATTAN
# 1                                             American
# 2    Non-food contact surface improperly constructe...
# 3                                                    A
# 4                                                  9.0
# ..                                                 ...
# 495                                          MANHATTAN
# 496                                           American
# 497  Filth flies or food/refuse/sewage-associated (...
# 498                                                  Z
# 499                                               33.0
#
# [495 rows x 4 columns]

# %%
inspecao[ ~ inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ] # datas incorretas
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_44578/2922132663.py:1: SyntaxWarning: invalid escape sequence '\d'
#   inspecao[ ~ inspecao['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ] # datas incorretas
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %% [markdown]
# _______________________

# %%
year_regex_pattern = '([(])([0-9]{4})([)]$)'
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995
#
#   decade_jeito_Feio
# 0              1990
# 1              1990
# 2              1990
# 3              1990
# 4              1990

# %%
filmes['year2'] = filmes.title.str.extract(year_regex_pattern)[1]
filmes['year2'] = filmes['year'].astype('int')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995
#
#   decade_jeito_Feio  year2
# 0              1990   1995
# 1              1990   1995
# 2              1990   1995
# 3              1990   1995
# 4              1990   1995

# %%
filmes[filmes.year > 2015 ].groupby('year').year.count().sum() #Qual a soma total dos títulos de 2016, 2017 e 2018?
# Out:
# np.int64(406)

# %%
regex = r"(\d{4})"

filmes["year2"] = filmes["title"].str.extract(regex)

display(len(filmes[filmes['year2'].isin(["2016", "2017", "2018"])]))
filmes.head()
# Out:
# 404
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995
#
#   decade_jeito_Feio year2
# 0              1990  1995
# 1              1990  1995
# 2              1990  1995
# 3              1990  1995
# 4              1990  1995

# %%
filmes['title'].str.match(r"^\d{4}-\d{2}-\d{2}$").unique()
# Out:
# array([False])

# %% [markdown]
# ### Com `import re` e `apply`

# %%
### Com `import re` e `apply`
import re

def valida_data(data):
  regex = r"^\d{4}-\d{2}-\d{2}$"
  return re.match(regex, data) is not None
inspecao['Date'].apply(valida_data)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Date, Length: 500, dtype: bool

# %%
inspecao[ ~ inspecao['Date'].apply(valida_data) ]
# Out:
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %% [markdown]
# ### Validação de datas reais ( não colocar mes 13 por exemplo)

# %%
from datetime import datetime

# %%
datetime.strptime('1999-12-01','%Y-%m-%d')
# Out:
# datetime.datetime(1999, 12, 1, 0, 0)

# %%
# %%script echo skipping error
#
# datetime.strptime('1999-13-01','%Y-%m-%d')
# Out:
# skipping error

# %%
def valida_data(data):
  try:
    datetime.strptime(data,'%Y-%m-%d')
    return True
  except:
    return False

# %%
inspecao[ ~ inspecao['Date'].apply(valida_data) ] # vendo datas erradas
# Out:
#                                        Name        Date         Info  \
# 10                       NY SWEET SPOT CAFE  2023/13/33      Borough
# 11                       NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12                       NY SWEET SPOT CAFE  2023/13/33  Description
# 13                       NY SWEET SPOT CAFE  2023/13/33        Grade
# 14                       NY SWEET SPOT CAFE  2023/13/33        Score
# 22                       BRANDY'S PIANO BAR  2023-13-33  Description
# 23                       BRANDY'S PIANO BAR  2023-13-33        Grade
# 24                       BRANDY'S PIANO BAR  2023-13-33        Score
# 220              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33      Borough
# 221              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33      Cuisine
# 222              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33  Description
# 223              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33        Grade
# 224              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33        Score
# 225                              IL POSTINO  2023-13-33      Borough
# 226                              IL POSTINO  2023-13-33      Cuisine
# 227                              IL POSTINO  2023-13-33  Description
# 228                              IL POSTINO  2023-13-33        Grade
# 229                              IL POSTINO  2023-13-33        Score
# 230            COZY CORNER BAR & RESTAURANT  2023-13-33      Borough
# 231            COZY CORNER BAR & RESTAURANT  2023-13-33      Cuisine
# 232            COZY CORNER BAR & RESTAURANT  2023-13-33  Description
# 233            COZY CORNER BAR & RESTAURANT  2023-13-33        Grade
# 234            COZY CORNER BAR & RESTAURANT  2023-13-33        Score
# 235  CIBO EXPRESS GOURMET MARKET (VAGABOND)  2023-13-33      Borough
# 236  CIBO EXPRESS GOURMET MARKET (VAGABOND)  2023-13-33      Cuisine
# 237  CIBO EXPRESS GOURMET MARKET (VAGABOND)  2023-13-33  Description
# 238  CIBO EXPRESS GOURMET MARKET (VAGABOND)  2023-13-33        Grade
# 239  CIBO EXPRESS GOURMET MARKET (VAGABOND)  2023-13-33        Score
# 240                 ON THE ROX LOUNGE & BAR  2023-13-33      Borough
# 241                 ON THE ROX LOUNGE & BAR  2023-13-33      Cuisine
# 242                 ON THE ROX LOUNGE & BAR  2023-13-33  Description
# 243                 ON THE ROX LOUNGE & BAR  2023-13-33        Grade
# 244                 ON THE ROX LOUNGE & BAR  2023-13-33        Score
# 245                             TOWERS CAFE  2023-13-33      Borough
# 246                             TOWERS CAFE  2023-13-33      Cuisine
# 247                             TOWERS CAFE  2023-13-33  Description
# 248                             TOWERS CAFE  2023-13-33        Grade
# 249                             TOWERS CAFE  2023-13-33        Score
#
#                                                  Value
# 10                                            BROOKLYN
# 11                                    Eastern European
# 12   Plumbing not properly installed or maintained;...
# 13                                                   A
# 14                                                 7.0
# 22   Non-food contact surface improperly constructe...
# 23                                                   A
# 24                                                 9.0
# 220                                          MANHATTAN
# 221                                              Asian
# 222  Facility not vermin proof. Harborage or condit...
# 223                                                  A
# 224                                               10.0
# 225                                          MANHATTAN
# 226                                            Italian
# 227  Evidence of mice or live mice present in facil...
# 228                                                  A
# 229                                               12.0
# 230                                             QUEENS
# 231                                           American
# 232  Food not protected from potential source of co...
# 233                                                  A
# 234                                               12.0
# 235                                             QUEENS
# 236                                           American
# 237  Non-food contact surface improperly constructe...
# 238                                                  A
# 239                                                6.0
# 240                                             QUEENS
# 241                                           American
# 242  Food not protected from potential source of co...
# 243                                                  A
# 244                                               10.0
# 245                                           BROOKLYN
# 246                                           American
# 247  Food contact surface not properly washed, rins...
# 248                                                  A
# 249                                               12.0

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995
# 1                   Adventure|Children|Fantasy     1990  1995
# 2                               Comedy|Romance     1990  1995
# 3                         Comedy|Drama|Romance     1990  1995
# 4                                       Comedy     1990  1995

# %%
def decade(year):
 return (year // 10) * 10

filmes['decade'] = filmes.year.apply(decade)
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  decada2  year  decade
# 0  Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                   Adventure|Children|Fantasy     1990  1995    1990
# 2                               Comedy|Romance     1990  1995    1990
# 3                         Comedy|Drama|Romance     1990  1995    1990
# 4                                       Comedy     1990  1995    1990

# %% [markdown]
# # Calculos Estátisticos

# %%
f"{Affairs['education'].mean():.2f} - {Affairs['education'].sum()}"
# Out:
# '16.17 - 9716'

# %%
display(testeGroupby.groupby(testeGroupby.index).agg(['mean', 'std', 'min',"max",'count']))
display( testeGroupby.groupby(testeGroupby.index).mean() )
display( testeGroupby.groupby(testeGroupby.index).std() )
display( testeGroupby.groupby(testeGroupby.index).min() )
display( testeGroupby.groupby(testeGroupby.index).max() )
display( testeGroupby.groupby(testeGroupby.index).count() )
display(testeGroupby.groupby(testeGroupby.index).sum())
# Out:
#     data
#     mean      std min max count
# key
# A    2.5  2.12132   1   4     2
# B    3.5  2.12132   2   5     2
# C    4.5  2.12132   3   6     2
#      data
# key
# A     2.5
# B     3.5
# C     4.5
#         data
# key
# A    2.12132
# B    2.12132
# C    2.12132
#      data
# key
# A       1
# B       2
# C       3
#      data
# key
# A       4
# B       5
# C       6
#      data
# key
# A       2
# B       2
# C       2
#      data
# key
# A       5
# B       7
# C       9

# %%
Affairs
# Out:
#      rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 0           4        0    male  37.0         10.00       no              3
# 1           5        0  female  27.0          4.00       no              4
# 2          11        0  female  32.0         15.00      yes              1
# 3          16        0    male  57.0         15.00      yes              5
# 4          23        0    male  22.0          0.75       no              2
# ..        ...      ...     ...   ...           ...      ...            ...
# 596      1938        1    male  22.0          1.50      yes              1
# 597      1941        7  female  32.0         10.00      yes              2
# 598      1954        2    male  32.0         10.00      yes              2
# 599      1959        2    male  22.0          7.00      yes              3
# 600      9010        1  female  32.0         15.00      yes              3
#
#      education  occupation  rating
# 0           18           7       4
# 1           14           6       4
# 2           12           1       4
# 3           18           6       5
# 4           17           6       3
# ..         ...         ...     ...
# 596         12           2       5
# 597         18           5       4
# 598         17           6       5
# 599         18           6       2
# 600         14           1       5
#
# [601 rows x 10 columns]

# %%
Affairs[["rownames","age","yearsmarried"]].mean()  # .mean(axis=0)
# Out:
# rownames        1059.722130
# age               32.487521
# yearsmarried       8.177696
# dtype: float64

# %%
Affairs[["rownames","age","yearsmarried"]].mean(axis=1) # ('rownames' + 'age' + 'yearsmarried')/3
# Out:
# 0        17.000000
# 1        12.000000
# 2        19.333333
# 3        29.333333
# 4        15.250000
#           ...
# 596     653.833333
# 597     661.000000
# 598     665.333333
# 599     662.666667
# 600    3019.000000
# Length: 601, dtype: float64

# %% [markdown]
# # Combinações de Dados

# %%
# Printar tabelas bonitinhas
class displayN(object):
    # Adaptado de https://jakevdp.github.io/PythonDataScienceHandbook/index.html
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <hr>
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p><hr>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args

    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)

    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
# Escola 1
df = pd.DataFrame({'Nome': ['Adriana', 'Daniel', 'Henrique'],
                   'Curso': ['Graduação','Graduação','Ensino Médio'],
                   'Idade': [34, 25, 17]})

# Escola 2
df2 = pd.DataFrame({'Nome': ['Beatriz', 'Anna'],
                   'Curso': ['Graduação', 'Ensino Médio'],
                   'Idade': [34, 17],
                   'Ingresso': [2018, 2020]})

# Preferências
df3 = pd.DataFrame({'Nome': ['Adriana', 'Daniel', 'Henrique', 'Beatriz', 'Anna'],
                   'Musica': ['Rock', 'MPB', 'HipHop', 'Jazz', 'Jazz']})

displayN('df', 'df2', 'df3')
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# df3
#        Nome  Musica
# 0   Adriana    Rock
# 1    Daniel     MPB
# 2  Henrique  HipHop
# 3   Beatriz    Jazz
# 4      Anna    Jazz

# %% [markdown]
# ## Concatenação

# %% [markdown]
# ### `pd.concat([df1,df2], axis=0)`, concatena linhas

# %%
df4 = df2[['Nome','Curso','Idade']]

displayN('df', 'df4',
        "pd.concat([df,df4])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df4
#       Nome         Curso  Idade
# 0  Beatriz     Graduação     34
# 1     Anna  Ensino Médio     17
#
# pd.concat([df,df4])
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
# 0   Beatriz     Graduação     34
# 1      Anna  Ensino Médio     17

# %% [markdown]
# ### `pd.concat([df1,df2], axis=1)`, concatena colunas

# %%
df5 = df3[['Musica']].head(3)

displayN('df', 'df5',
        "pd.concat([df,df5],axis=1)")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df5
#    Musica
# 0    Rock
# 1     MPB
# 2  HipHop
#
# pd.concat([df,df5],axis=1)
#        Nome         Curso  Idade  Musica
# 0   Adriana     Graduação     34    Rock
# 1    Daniel     Graduação     25     MPB
# 2  Henrique  Ensino Médio     17  HipHop

# %%
displayN('df', 'df2',
        "pd.concat([df,df2])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# pd.concat([df,df2])
#        Nome         Curso  Idade  Ingresso
# 0   Adriana     Graduação     34       NaN
# 1    Daniel     Graduação     25       NaN
# 2  Henrique  Ensino Médio     17       NaN
# 0   Beatriz     Graduação     34    2018.0
# 1      Anna  Ensino Médio     17    2020.0

# %%
displayN('df', 'df2',
        "pd.concat([df,df2]).reset_index(drop=True)")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# pd.concat([df,df2]).reset_index(drop=True)
#        Nome         Curso  Idade  Ingresso
# 0   Adriana     Graduação     34       NaN
# 1    Daniel     Graduação     25       NaN
# 2  Henrique  Ensino Médio     17       NaN
# 3   Beatriz     Graduação     34    2018.0
# 4      Anna  Ensino Médio     17    2020.0

# %%
displayN('df', 'df2',
        "pd.concat([df,df2],axis=1)")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# df2
#       Nome         Curso  Idade  Ingresso
# 0  Beatriz     Graduação     34      2018
# 1     Anna  Ensino Médio     17      2020
#
# pd.concat([df,df2],axis=1)
#        Nome         Curso  Idade     Nome         Curso  Idade  Ingresso
# 0   Adriana     Graduação     34  Beatriz     Graduação   34.0    2018.0
# 1    Daniel     Graduação     25     Anna  Ensino Médio   17.0    2020.0
# 2  Henrique  Ensino Médio     17      NaN           NaN    NaN       NaN

# %%
df3 = pd.concat([df,df2],axis=1)
df3['Nome']
# Out:
#        Nome     Nome
# 0   Adriana  Beatriz
# 1    Daniel     Anna
# 2  Henrique      NaN

# %%
print(df3.loc[0][0])
print(df3.loc[0][3])
# Out:
# Adriana
# Beatriz

# %%
df3.columns = ['Nome', 'Curso', 'Idade', 'Nome2', 'Curso2', 'Idade2', 'Ingresso'] # renomeando as colunas
df3
# Out:
#        Nome         Curso  Idade    Nome2        Curso2  Idade2  Ingresso
# 0   Adriana     Graduação     34  Beatriz     Graduação    34.0    2018.0
# 1    Daniel     Graduação     25     Anna  Ensino Médio    17.0    2020.0
# 2  Henrique  Ensino Médio     17      NaN           NaN     NaN       NaN

# %% [markdown]
# ## Junções
#
# Temos 3 tipos de junções:
#
# > * **Inner**, incluímos somente linhas com *match* das chaves nas duas tabelas
# > * **Outter**, incluímos linhas independente do *match* das chaves nas duas tabelas
# >> * **Left**, incluímos linhas com *match* das chaves nas duas tabelas + linhas da tabela à esquerda independente de match
# >> * **Right**, incluímos linhas com *match* das chaves nas duas tabelas + linhas da tabela à direita independente de *match*

# %% [markdown]
# ### `Inner Joins`

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014]})
df3 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
                    'supervisor': ['Carly', 'Guido', 'Steve']})
displayN('df1', 'df2', 'df3')
# Out:
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#
# df2
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
#
# df3
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
df4 = pd.merge(df1, df2)
df4 = pd.merge(df1, df2, left_on='employee', right_on='employee')
df4 = pd.merge(df1, df2, on='employee')
displayN('df4','df2','df1')
# Out:
# df4
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014
#
# df2
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
#
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
displayN('df3', 'df4', 'pd.merge(df3, df4)')
# Out:
# df3
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve
#
# df4
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014
#
# pd.merge(df3, df4)
#          group supervisor employee  hire_date
# 0   Accounting      Carly      Bob       2008
# 1  Engineering      Guido     Jake       2012
# 2  Engineering      Guido     Lisa       2004
# 3           HR      Steve      Sue       2014

# %%
df5 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization']})
displayN('df1', 'df5', "pd.merge(df1, df5)")
# Out:
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#
# df5
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
#
# pd.merge(df1, df5)
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %% [markdown]
# ### Merge

# %%
df6 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'salary': [70000, 80000, 120000, 90000]})
pd.merge(df1, df6, left_on="employee", right_on="name").drop('name', axis=1)
# Out:
#   employee        group  salary
# 0      Bob   Accounting   70000
# 1     Jake  Engineering   80000
# 2     Lisa  Engineering  120000
# 3      Sue           HR   90000

# %%
displayN("filmes","ratings_mean", " pd.merge(filmes,ratings_mean,on='movieId')")
# Out:
# filmes
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9713   193581  Black Butler: Book of the Atlantic (2017)
# 9714   193583               No Game No Life: Zero (2017)
# 9715   193585                               Flint (2017)
# 9716   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9717   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  decada2  year  decade  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                      Adventure|Children|Fantasy     1990  1995    1990
# 2                                  Comedy|Romance     1990  1995    1990
# 3                            Comedy|Drama|Romance     1990  1995    1990
# 4                                          Comedy     1990  1995    1990
# ...                                           ...      ...   ...     ...
# 9713              Action|Animation|Comedy|Fantasy     2010  2017    2010
# 9714                     Animation|Comedy|Fantasy     2010  2017    2010
# 9715                                        Drama     2010  2017    2010
# 9716                             Action|Animation     2010  2018    2010
# 9717                                       Comedy     1990  1991    1990
#
#       decade_com_Map
# 0               1990
# 1               1990
# 2               1990
# 3               1990
# 4               1990
# ...              ...
# 9713            2010
# 9714            2010
# 9715            2010
# 9716            2010
# 9717            1990
#
# [9718 rows x 7 columns]
#
# ratings_mean
#       movieId    rating
# 0           1  3.920930
# 1           2  3.431818
# 2           3  3.259615
# 3           4  2.357143
# 4           5  3.071429
# ...       ...       ...
# 9719   193581  4.000000
# 9720   193583  3.500000
# 9721   193585  3.500000
# 9722   193587  3.500000
# 9723   193609  4.000000
#
# [9724 rows x 2 columns]
#
#  pd.merge(filmes,ratings_mean,on='movieId')
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9695   193581  Black Butler: Book of the Atlantic (2017)
# 9696   193583               No Game No Life: Zero (2017)
# 9697   193585                               Flint (2017)
# 9698   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9699   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  decada2  year  decade  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     1990  1995    1990
# 1                      Adventure|Children|Fantasy     1990  1995    1990
# 2                                  Comedy|Romance     1990  1995    1990
# 3                            Comedy|Drama|Romance     1990  1995    1990
# 4                                          Comedy     1990  1995    1990
# ...                                           ...      ...   ...     ...
# 9695              Action|Animation|Comedy|Fantasy     2010  2017    2010
# 9696                     Animation|Comedy|Fantasy     2010  2017    2010
# 9697                                        Drama     2010  2017    2010
# 9698                             Action|Animation     2010  2018    2010
# 9699                                       Comedy     1990  1991    1990
#
#       decade_com_Map    rating
# 0               1990  3.920930
# 1               1990  3.431818
# 2               1990  3.259615
# 3               1990  2.357143
# 4               1990  3.071429
# ...              ...       ...
# 9695            2010  4.000000
# 9696            2010  3.500000
# 9697            2010  3.500000
# 9698            2010  3.500000
# 9699            1990  4.000000
#
# [9700 rows x 8 columns]

# %% [markdown]
# ### `Right` `Left` ` Joins`
#
# `Right` e `Left` ` Joins` são empregados quando queremos adicionar à combinação dos dados elementos independentemente de fazerem *match* com as chaves de dados ou não.

# %%
df7 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue', 'Adriana'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR', 'Commercial']})

df8 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR', 'Research'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization', 'Data Science']})

# %%
displayN('df7','df8',
        'pd.merge(df7,df8)')
# Out:
# df7
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4  Adriana   Commercial
#
# df8
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
# 6     Research  Data Science
#
# pd.merge(df7,df8)
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
displayN('df7','df8',
        "pd.merge(df7,df8,how='left')")
# Out:
# df7
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4  Adriana   Commercial
#
# df8
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
# 6     Research  Data Science
#
# pd.merge(df7,df8,how='left')
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization
# 8  Adriana   Commercial           NaN

# %%
displayN('df7','df8',
        "pd.merge(df7,df8,how='right')")
# Out:
# df7
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4  Adriana   Commercial
#
# df8
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
# 6     Research  Data Science
#
# pd.merge(df7,df8,how='right')
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Lisa  Engineering        coding
# 4     Jake  Engineering         linux
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization
# 8      NaN     Research  Data Science

# %%
displayN('df1','df5',
        "pd.merge(df1,df5,how='outer')")
# Out:
# df1
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#
# df5
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
#
# pd.merge(df1,df5,how='outer')
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %% [markdown]
# # Reshape dos dados

# %% [markdown]
# ## Melt, `pd.melt(df, id_vars = , value_vars = )`
# (transforma colunas em linhas )

# %%
displayN('df',
        "pd.melt(df, id_vars =['Nome'], value_vars =['Curso'])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.melt(df, id_vars =['Nome'], value_vars =['Curso'])
#        Nome variable         value
# 0   Adriana    Curso     Graduação
# 1    Daniel    Curso     Graduação
# 2  Henrique    Curso  Ensino Médio

# %%
displayN('df',
        "pd.melt(df, id_vars =['Nome'], value_vars =['Curso','Idade'])")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.melt(df, id_vars =['Nome'], value_vars =['Curso','Idade'])
#        Nome variable         value
# 0   Adriana    Curso     Graduação
# 1    Daniel    Curso     Graduação
# 2  Henrique    Curso  Ensino Médio
# 3   Adriana    Idade            34
# 4    Daniel    Idade            25
# 5  Henrique    Idade            17

# %%
displayN('df',
        "pd.melt(df, id_vars =['Nome'], value_vars =['Idade'], var_name ='*Tipo_atributo*', value_name ='*Valor_atributo*')")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.melt(df, id_vars =['Nome'], value_vars =['Idade'], var_name ='*Tipo_atributo*', value_name ='*Valor_atributo*')
#        Nome *Tipo_atributo*  *Valor_atributo*
# 0   Adriana           Idade                34
# 1    Daniel           Idade                25
# 2  Henrique           Idade                17

# %% [markdown]
# ## `pd.pivot(df, index= , columns= , values= )`
# Esta função cria para cada valor de uma coluna uma linha com os valores correspondentes,
#
# Faz o inverso do melt
# transforma linhas em colunas

# %%
displayN('df',
        "pd.pivot(df, 'Nome', 'Curso', 'Idade')")
# Out:
# df
#        Nome         Curso  Idade
# 0   Adriana     Graduação     34
# 1    Daniel     Graduação     25
# 2  Henrique  Ensino Médio     17
#
# pd.pivot(df, 'Nome', 'Curso', 'Idade')
# Curso     Ensino Médio  Graduação
# Nome
# Adriana            NaN       34.0
# Daniel             NaN       25.0
# Henrique          17.0        NaN

# %%
df2 = pd.pivot(df, 'Nome', 'Curso', 'Idade')
df3 = pd.pivot(df, 'Nome', 'Curso', 'Idade').reset_index()
df3.columns.name = ''

print(df2.columns)
print(df3.columns)

displayN('df2','df3')
# Out:
# Index(['Ensino Médio', 'Graduação'], dtype='object', name='Curso')
# Index(['Nome', 'Ensino Médio', 'Graduação'], dtype='object', name='')
# df2
# Curso     Ensino Médio  Graduação
# Nome
# Adriana            NaN       34.0
# Daniel             NaN       25.0
# Henrique          17.0        NaN
#
# df3
#        Nome  Ensino Médio  Graduação
# 0   Adriana           NaN       34.0
# 1    Daniel           NaN       25.0
# 2  Henrique          17.0        NaN

# %% [markdown]
# # Comando shift (avança para a linha seguinte)

# %%
df_selected = financas[['BRL=X', 'ITUB4.SA', 'PETR4.SA', 'VALE3.SA', '^BVSP']]
display(df_selected.head())
display(df_selected.shift().head()) # df[i] = df[i-1], avança
# Out:
# Ticker         BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02  5.285500  118.671890   93.603439  425.388514  106376.0
# 2023-01-03  5.360131  117.841293   92.522995  430.622910  104166.0
# 2023-01-04  5.478500  120.795203   97.571673  440.921560  105334.0
# 2023-01-05  5.430100  123.461746  100.192050  444.358927  107518.0
# 2023-01-06  5.349800  123.745045   98.131722  444.722991  108836.0
# Ticker         BRL=X    ITUB4.SA    PETR4.SA    VALE3.SA     ^BVSP
# Date
# 2023-01-02       NaN         NaN         NaN         NaN       NaN
# 2023-01-03  5.285500  118.671890   93.603439  425.388514  106376.0
# 2023-01-04  5.360131  117.841293   92.522995  430.622910  104166.0
# 2023-01-05  5.478500  120.795203   97.571673  440.921560  105334.0
# 2023-01-06  5.430100  123.461746  100.192050  444.358927  107518.0
